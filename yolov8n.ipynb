# %% [markdown]
# ### References
# The codes in this notebook use reference from the following sources
# 1. https://github.com/jahongir7174/YOLOv8-dfl/tree/master
# 2. https://arxiv.org/html/2304.00501v6/#S16
# 3. https://github.com/ultralytics/ultralytics/tree/main/ultralytics/models/yolo

# %%
# import
import math, os, random, cv2, numpy, torch
import torch.nn as nn
from ultralytics import YOLO

# explore the original yolov8 model

# original yolov8n
model_n=YOLO('yolov8n.pt')
print(f"yolov8-nano: {sum(p.numel() for p in model_n.parameters())/1e6} million parameters")


# model_s=YOLO('yolov8s.pt')
# print(f"yolov8-small: {sum(p.numel() for p in model_s.parameters())/1e6} million parameters")

print(model_n.model)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.6MB/s]
# yolov8-nano: 3.1572 million parameters
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (3): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (4): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (5): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (6): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (7): Conv(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (8): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (9): SPPF(
#       (cv1): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (10): Upsample(scale_factor=2.0, mode='nearest')
#     (11): Concat()
#     (12): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (13): Upsample(scale_factor=2.0, mode='nearest')
#     (14): Concat()
#     (15): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (16): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (17): Concat()
#     (18): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (19): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (20): Concat()
#     (21): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (22): Detect(
#       (cv2): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (cv3): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Conv(
#             (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (dfl): DFL(
#         (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
# )

# %% [markdown]
# ## Yolov8 architecture
# The overall architecture is BackBone + Neck + Head
#
# <center>
# <img src="yolov8_architecture.png" width="700" height="700">

# %% [markdown]
# ## 1. Backbone
# The backbone is modified CSPDarknet53 which comprises of blocks Conv, C2f, SPPF
# 1. **Conv**: Conv2d + BatchNorm2d + SiLU
# 2. **C2f (cross-stage partial bottleneck with 2 convolutions)**: Conv + Bottlenecks + Conv <br>
# Combine high-level features with contextual information to improve detection accuracy.
# 3. **SPPF (spatial pyramid pooling fast)**: Conv + Maxpool2d + Conv <br>
# Process features at various scales and pool them into a fixed-size feature map.

# %% [markdown]
# ### (a) Conv

# %%
class Conv(nn.Module):
    def __init__(self,in_channels, out_channels,kernel_size=3,stride=1,padding=1,groups=1,activation=True):
        super().__init__()
        self.conv=nn.Conv2d(in_channels,out_channels,kernel_size,stride,padding,bias=False,groups=groups)
        self.bn=nn.BatchNorm2d(out_channels,eps=0.001,momentum=0.03)
        self.act=nn.SiLU(inplace=True) if activation else nn.Identity()

    def forward(self,x):
        return self.act(self.bn(self.conv(x)))

# %% [markdown]
# ### (b) C2f

# %%
# 2.1 Bottleneck: staack of 2 COnv with shortcut connnection (True/False)
class Bottleneck(nn.Module):
    def __init__(self,in_channels,out_channels,shortcut=True):
        super().__init__()
        self.conv1=Conv(in_channels,out_channels,kernel_size=3,stride=1,padding=1)
        self.conv2=Conv(out_channels,out_channels,kernel_size=3,stride=1,padding=1)
        self.shortcut=shortcut

    def forward(self,x):
        x_in=x # for residual connection
        x=self.conv1(x)
        x=self.conv2(x)
        if self.shortcut:
            x=x+x_in
        return x
    
# 2.2 C2f: Conv + bottleneck*N+ Conv
class C2f(nn.Module):
    def __init__(self,in_channels,out_channels, num_bottlenecks,shortcut=True):
        super().__init__()
        
        self.mid_channels=out_channels//2
        self.num_bottlenecks=num_bottlenecks

        self.conv1=Conv(in_channels,out_channels,kernel_size=1,stride=1,padding=0)
        
        # sequence of bottleneck layers
        self.m=nn.ModuleList([Bottleneck(self.mid_channels,self.mid_channels) for _ in range(num_bottlenecks)])

        self.conv2=Conv((num_bottlenecks+2)*out_channels//2,out_channels,kernel_size=1,stride=1,padding=0)
    
    def forward(self,x):
        x=self.conv1(x)

        # split x along channel dimension
        x1,x2=x[:,:x.shape[1]//2,:,:], x[:,x.shape[1]//2:,:,:]
        
        # list of outputs
        outputs=[x1,x2] # x1 is fed through the bottlenecks

        for i in range(self.num_bottlenecks):
            x1=self.m[i](x1)    # [bs,0.5c_out,w,h]
            outputs.insert(0,x1)

        outputs=torch.cat(outputs,dim=1) # [bs,0.5c_out(num_bottlenecks+2),w,h]
        out=self.conv2(outputs)

        return out
         
# sanity check
c2f=C2f(in_channels=64,out_channels=128,num_bottlenecks=2)
print(f"{sum(p.numel() for p in c2f.parameters())/1e6} million parameters")

dummy_input=torch.rand((1,64,244,244))
dummy_input=c2f(dummy_input)
print("Output shape: ", dummy_input.shape)
# Out:
# 0.18944 million parameters
# Output shape:  torch.Size([1, 128, 244, 244])

# %% [markdown]
# ### (c) SPPF

# %%
class SPPF(nn.Module):
    def __init__(self,in_channels,out_channels,kernel_size=5):
        #kernel_size= size of maxpool
        super().__init__()
        hidden_channels=in_channels//2
        self.conv1=Conv(in_channels,hidden_channels,kernel_size=1,stride=1,padding=0)
        # concatenate outputs of maxpool and feed to conv2
        self.conv2=Conv(4*hidden_channels,out_channels,kernel_size=1,stride=1,padding=0)

        # maxpool is applied at 3 different sacles
        self.m=nn.MaxPool2d(kernel_size=kernel_size,stride=1,padding=kernel_size//2,dilation=1,ceil_mode=False)
    
    def forward(self,x):
        x=self.conv1(x)

        # apply maxpooling at diffent scales
        y1=self.m(x)
        y2=self.m(y1)
        y3=self.m(y2)

        # concantenate 
        y=torch.cat([x,y1,y2,y3],dim=1)

        # final conv
        y=self.conv2(y)

        return y

# sanity check
sppf=SPPF(in_channels=128,out_channels=512)
print(f"{sum(p.numel() for p in sppf.parameters())/1e6} million parameters")

dummy_input=sppf(dummy_input)
print("Output shape: ", dummy_input.shape)
# Out:
# 0.140416 million parameters
# Output shape:  torch.Size([1, 512, 244, 244])

# %% [markdown]
# ### Putting things together

# %%
# backbone = DarkNet53

# return d,w,r based on version
def yolo_params(version):
    if version=='n':
        return 1/3,1/4,2.0
    elif version=='s':
        return 1/3,1/2,2.0
    elif version=='m':
        return 2/3,3/4,1.5
    elif version=='l':
        return 1.0,1.0,1.0
    elif version=='x':
        return 1.0,1.25,1.0
    
class Backbone(nn.Module):
    def __init__(self,version,in_channels=3,shortcut=True):
        super().__init__()
        d,w,r=yolo_params(version)

        # conv layers
        self.conv_0=Conv(in_channels,int(64*w),kernel_size=3,stride=2,padding=1)
        self.conv_1=Conv(int(64*w),int(128*w),kernel_size=3,stride=2,padding=1)
        self.conv_3=Conv(int(128*w),int(256*w),kernel_size=3,stride=2,padding=1)
        self.conv_5=Conv(int(256*w),int(512*w),kernel_size=3,stride=2,padding=1)
        self.conv_7=Conv(int(512*w),int(512*w*r),kernel_size=3,stride=2,padding=1)

        # c2f layers
        self.c2f_2=C2f(int(128*w),int(128*w),num_bottlenecks=int(3*d),shortcut=True)
        self.c2f_4=C2f(int(256*w),int(256*w),num_bottlenecks=int(6*d),shortcut=True)
        self.c2f_6=C2f(int(512*w),int(512*w),num_bottlenecks=int(6*d),shortcut=True)
        self.c2f_8=C2f(int(512*w*r),int(512*w*r),num_bottlenecks=int(3*d),shortcut=True)

        # sppf
        self.sppf=SPPF(int(512*w*r),int(512*w*r))
    
    def forward(self,x):
        x=self.conv_0(x)
        x=self.conv_1(x)

        x=self.c2f_2(x)

        x=self.conv_3(x)

        out1=self.c2f_4(x) # keep for output

        x=self.conv_5(out1)

        out2=self.c2f_6(x) # keep for output

        x=self.conv_7(out2)
        x=self.c2f_8(x)
        out3=self.sppf(x)

        return out1,out2,out3

print("----Nano model -----")
backbone_n=Backbone(version='n')
print(f"{sum(p.numel() for p in backbone_n.parameters())/1e6} million parameters")

print("----Small model -----")
backbone_s=Backbone(version='s')
print(f"{sum(p.numel() for p in backbone_s.parameters())/1e6} million parameters")
# Out:
# ----Nano model -----
# 1.272656 million parameters
# ----Small model -----
# 5.079712 million parameters

# %%
# sanity check
x=torch.rand((1,3,640,640))
out1,out2,out3=backbone_n(x)
print(out1.shape)
print(out2.shape)
print(out3.shape)
# Out:
# torch.Size([1, 64, 80, 80])
# torch.Size([1, 128, 40, 40])
# torch.Size([1, 256, 20, 20])

# %% [markdown]
# ## 2. Neck
# The neck comprises of Upsample + C2f with
#
# **Upsample** = nearest-neighbor interpolation with scale_factor=2. It doesn't have trainable paramaters.

# %%
# upsample = nearest-neighbor interpolation with scale_factor=2
#            doesn't have trainable paramaters
class Upsample(nn.Module):
    def __init__(self,scale_factor=2,mode='nearest'):
        super().__init__()
        self.scale_factor=scale_factor
        self.mode=mode

    def forward(self,x):
        return nn.functional.interpolate(x,scale_factor=self.scale_factor,mode=self.mode)

# %%
class Neck(nn.Module):
    def __init__(self,version):
        super().__init__()
        d,w,r=yolo_params(version)

        self.up=Upsample() # no trainable parameters
        self.c2f_1=C2f(in_channels=int(512*w*(1+r)), out_channels=int(512*w),num_bottlenecks=int(3*d),shortcut=False)
        self.c2f_2=C2f(in_channels=int(768*w), out_channels=int(256*w),num_bottlenecks=int(3*d),shortcut=False)
        self.c2f_3=C2f(in_channels=int(768*w), out_channels=int(512*w),num_bottlenecks=int(3*d),shortcut=False)
        self.c2f_4=C2f(in_channels=int(512*w*(1+r)), out_channels=int(512*w*r),num_bottlenecks=int(3*d),shortcut=False)

        self.cv_1=Conv(in_channels=int(256*w),out_channels=int(256*w),kernel_size=3,stride=2, padding=1)
        self.cv_2=Conv(in_channels=int(512*w),out_channels=int(512*w),kernel_size=3,stride=2, padding=1)


    def forward(self,x_res_1,x_res_2,x):    
        # x_res_1,x_res_2,x = output of backbone
        res_1=x              # for residual connection
        
        x=self.up(x)
        x=torch.cat([x,x_res_2],dim=1)

        res_2=self.c2f_1(x)  # for residual connection
        
        x=self.up(res_2)
        x=torch.cat([x,x_res_1],dim=1)

        out_1=self.c2f_2(x)

        x=self.cv_1(out_1)

        x=torch.cat([x,res_2],dim=1)
        out_2=self.c2f_3(x)

        x=self.cv_2(out_2)

        x=torch.cat([x,res_1],dim=1)
        out_3=self.c2f_4(x)

        return out_1,out_2,out_3
    
# sanity check
neck=Neck(version='n')
print(f"{sum(p.numel() for p in neck.parameters())/1e6} million parameters")

x=torch.rand((1,3,640,640))
out1,out2,out3=Backbone(version='n')(x)
out_1,out_2,out_3=neck(out1,out2,out3)
print(out_1.shape)
print(out_2.shape)
print(out_3.shape)
# Out:
# 0.98688 million parameters
# torch.Size([1, 64, 80, 80])
# torch.Size([1, 128, 40, 40])
# torch.Size([1, 256, 20, 20])

# %% [markdown]
# ## 3. Head
# Consist of 3 modules: (1) bbox coordinates, (2) classification scores, (3) distribution focal loss (DFL).
#
# **DFL** considers the predicted bbox coordinates as a probability distribution. At inference time, it samples from the distribution to get **refined coordinates** $(x,y,w,h)$. For example, to predict coordinate $x$ in the normalized range $[0,1]$:
# 1. DFL uses 16 bins which are equally spaced in $[0,1]$, bin length = 1/16.
# 2. The model outputs 16 numbers which corresponds to probabilities that x falls in these bins, for example, $[0,0,...,9/10,1/10]$.
# 3. Prediction for $x=$ mean value $= 9/10\cdot15/16+1/10\cdot 1=0.94375$

# %% [markdown]
# ### (a) DFL

# %%
# DFL
class DFL(nn.Module):
    def __init__(self,ch=16):
        super().__init__()
        
        self.ch=ch
        
        self.conv=nn.Conv2d(in_channels=ch,out_channels=1,kernel_size=1,bias=False).requires_grad_(False)
        
        # initialize conv with [0,...,ch-1]
        x=torch.arange(ch,dtype=torch.float).view(1,ch,1,1)
        self.conv.weight.data[:]=torch.nn.Parameter(x) # DFL only has ch parameters

    def forward(self,x):
        # x must have num_channels = 4*ch: x=[bs,4*ch,c]
        b,c,a=x.shape                           # c=4*ch
        x=x.view(b,4,self.ch,a).transpose(1,2)  # [bs,ch,4,a]

        # take softmax on channel dimension to get distribution probabilities
        x=x.softmax(1)                          # [b,ch,4,a]
        x=self.conv(x)                          # [b,1,4,a]
        return x.view(b,4,a)                    # [b,4,a]

# sanity check
dummy_input=torch.rand((1,64,128))
dfl=DFL()
print(f"{sum(p.numel() for p in dfl.parameters())} parameters")

dummy_output=dfl(dummy_input)
print(dummy_output.shape)

print(dfl)
# Out:
# 16 parameters
# torch.Size([1, 4, 128])
# DFL(
#   (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
# )

# %% [markdown]
# ### (b) Head

# %%
class Head(nn.Module):
    def __init__(self,version,ch=16,num_classes=80):

        super().__init__()
        self.ch=ch                          # dfl channels
        self.coordinates=self.ch*4          # number of bounding box coordinates 
        self.nc=num_classes                 # 80 for COCO
        self.no=self.coordinates+self.nc    # number of outputs per anchor box

        self.stride=torch.zeros(3)          # strides computed during build
        
        d,w,r=yolo_params(version=version)
        
        # for bounding boxes
        self.box=nn.ModuleList([
            nn.Sequential(Conv(int(256*w),self.coordinates,kernel_size=3,stride=1,padding=1),
                          Conv(self.coordinates,self.coordinates,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.coordinates,self.coordinates,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w),self.coordinates,kernel_size=3,stride=1,padding=1),
                          Conv(self.coordinates,self.coordinates,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.coordinates,self.coordinates,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w*r),self.coordinates,kernel_size=3,stride=1,padding=1),
                          Conv(self.coordinates,self.coordinates,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.coordinates,self.coordinates,kernel_size=1,stride=1))
        ])

        # for classification
        self.cls=nn.ModuleList([
            nn.Sequential(Conv(int(256*w),self.nc,kernel_size=3,stride=1,padding=1),
                          Conv(self.nc,self.nc,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.nc,self.nc,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w),self.nc,kernel_size=3,stride=1,padding=1),
                          Conv(self.nc,self.nc,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.nc,self.nc,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w*r),self.nc,kernel_size=3,stride=1,padding=1),
                          Conv(self.nc,self.nc,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.nc,self.nc,kernel_size=1,stride=1))
        ])

        # dfl
        self.dfl=DFL()

    def forward(self,x):
        # x = output of Neck = list of 3 tensors with different resolution and different channel dim
        #     x[0]=[bs, ch0, w0, h0], x[1]=[bs, ch1, w1, h1], x[2]=[bs,ch2, w2, h2] 

        for i in range(len(self.box)):       # detection head i
            box=self.box[i](x[i])            # [bs,num_coordinates,w,h]
            cls=self.cls[i](x[i])            # [bs,num_classes,w,h]
            x[i]=torch.cat((box,cls),dim=1)  # [bs,num_coordinates+num_classes,w,h]

        # in training, no dfl output
        if self.training:
            return x                         # [3,bs,num_coordinates+num_classes,w,h]
        
        # in inference time, dfl produces refined bounding box coordinates
        anchors, strides = (i.transpose(0, 1) for i in self.make_anchors(x, self.stride))

        # concatenate predictions from all detection layers
        x = torch.cat([i.view(x[0].shape[0], self.no, -1) for i in x], dim=2) #[bs, 4*self.ch + self.nc, sum_i(h[i]w[i])]
        
        # split out predictions for box and cls
        #           box=[bs,4×self.ch,sum_i(h[i]w[i])]
        #           cls=[bs,self.nc,sum_i(h[i]w[i])]
        box, cls = x.split(split_size=(4 * self.ch, self.nc), dim=1)


        a, b = self.dfl(box).chunk(2, 1)  # a=b=[bs,2×self.ch,sum_i(h[i]w[i])]
        a = anchors.unsqueeze(0) - a
        b = anchors.unsqueeze(0) + b
        box = torch.cat(tensors=((a + b) / 2, b - a), dim=1)
        
        return torch.cat(tensors=(box * strides, cls.sigmoid()), dim=1)


    def make_anchors(self, x, strides, offset=0.5):
        # x= list of feature maps: x=[x[0],...,x[N-1]], in our case N= num_detection_heads=3
        #                          each having shape [bs,ch,w,h]
        #    each feature map x[i] gives output[i] = w*h anchor coordinates + w*h stride values
        
        # strides = list of stride values indicating how much 
        #           the spatial resolution of the feature map is reduced compared to the original image

        assert x is not None
        anchor_tensor, stride_tensor = [], []
        dtype, device = x[0].dtype, x[0].device
        for i, stride in enumerate(strides):
            _, _, h, w = x[i].shape
            sx = torch.arange(end=w, device=device, dtype=dtype) + offset  # x coordinates of anchor centers
            sy = torch.arange(end=h, device=device, dtype=dtype) + offset  # y coordinates of anchor centers
            sy, sx = torch.meshgrid(sy, sx)                                # all anchor centers 
            anchor_tensor.append(torch.stack((sx, sy), -1).view(-1, 2))
            stride_tensor.append(torch.full((h * w, 1), stride, dtype=dtype, device=device))
        return torch.cat(anchor_tensor), torch.cat(stride_tensor)

# %%
detect=Head(version='n')
print(f"{sum(p.numel() for p in detect.parameters())/1e6} million parameters")

# out_1,out_2,out_3 are output of the neck
output=detect([out_1,out_2,out_3])
print(output[0].shape)
print(output[1].shape)
print(output[2].shape)

print(detect)
# Out:
# 0.897664 million parameters
# torch.Size([1, 144, 80, 80])
# torch.Size([1, 144, 40, 40])
# torch.Size([1, 144, 20, 20])
# Head(
#   (box): ModuleList(
#     (0): Sequential(
#       (0): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv(
#         (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Sequential(
#       (0): Conv(
#         (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (cls): ModuleList(
#     (0): Sequential(
#       (0): Conv(
#         (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv(
#         (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Sequential(
#       (0): Conv(
#         (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (dfl): DFL(
#     (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ## 4. Putting everything together

# %%
class MyYolo(nn.Module):
    def __init__(self,version):
        super().__init__()
        self.backbone=Backbone(version=version)
        self.neck=Neck(version=version)
        self.head=Head(version=version)

    def forward(self,x):
        x=self.backbone(x)              # return out1,out2,out3
        x=self.neck(x[0],x[1],x[2])     # return out_1, out_2,out_3
        return self.head(list(x))
    
model=MyYolo(version='n')
print(f"{sum(p.numel() for p in model.parameters())/1e6} million parameters")
print(model)
# Out:
# 3.1572 million parameters
# MyYolo(
#   (backbone): Backbone(
#     (conv_0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_3): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_5): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_7): Conv(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (c2f_2): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_4): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_6): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_8): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (sppf): SPPF(
#       (conv1): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#   )
#   (neck): Neck(
#     (up): Upsample()
#     (c2f_1): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_2): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_3): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_4): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv_1): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv_2): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (head): Head(
#     (box): ModuleList(
#       (0): Sequential(
#         (0): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv(
#           (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (cls): ModuleList(
#       (0): Sequential(
#         (0): Conv(
#           (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv(
#           (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv(
#           (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (dfl): DFL(
#       (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 5. Dataset and Train
# Due to computation constraint, we will only overfit 1 batch of data from YOLO2017. The loss in yolov8 consists  (1) box_loss, (2) classification_loss, (3) dfl_loss
# 1. **Box loss**: on bounding box coordinates
# 2. **Classification loss**: on classification logits
# 3. **DFL_Loss**: itegrated in box loss
#
# **How DFL loss works?**
# 1. Target distribution = single value over 16 bins, this value will be smooth between 2 bin centers. For example, if target value is in the middle of bin 1 and 2, target distribution $= [1/2,1/2,0,...,0]$
# 2. Predicted distribution is based on the output of bbox coordinates. These outputs can be used to compute the probabilities for each bin, say $[1/16,1/16,...,1/16]$
# 3. DFL = cross entropy between prediction and target
#
# The utils file for computing loss is taken from https://github.com/jahongir7174/YOLOv8-dfl/tree/master

# %%
def setNewPath(data_dir='./'):
    data_dir = data_dir
    # Initialize a list to store image and label file paths as tuples
    image_label_pairs = []
    # ... (rest of your code to get image file paths)
    # construct the full path to the file
    train2024_txt_path = os.path.join(data_dir, 'dset_train2024.txt')
    # check if the file exists, if not print an error message and exit
    if not os.path.exists(train2024_txt_path):
        print(f"Error: File not found: {train2024_txt_path}")
        # If necessary raise an exception or handle the error differently
        # raise FileNotFoundError(f"File not found: {train2017_txt_path}")
        exit()

    print(f"data_dir: {data_dir}")
    print(f"train2024_txt_path: {train2024_txt_path}")

    with open(train2024_txt_path, 'r') as reader:
      # Assuming label files are in a 'labels' subdirectory
      for filename in reader.readlines():
          filename = os.path.basename(filename.rstrip())

          # Debug: Print the filename to see what's being read
          print(f"Processing filename: {filename}")


          image_path = f'{data_dir}dataset/images/train/' + filename
          label_path = f'{data_dir}dataset/labels/train/' + filename.replace('.jpg', '.txt').replace('.png', '.txt').replace('.jpeg', '.txt')

          #print(f"image_path: {image_path}")
          #print(f"label_path: {label_path}")
           # Debug: Check if the image and label files exist
          if os.path.exists(image_path) and os.path.exists(label_path):
            image_label_pairs.append((image_path, label_path))
          else:
            print(f"Warning: Image or label file not found:\nImage: {image_path}\nLabel: {label_path}")
    print(f"Found {len(image_label_pairs)} image-label pairs.") # Print the length
    return image_label_pairs

# %%
images_labels = setNewPath(data_dir='./')
#print(images_labels)
# Out:
# data_dir: ./
# train2024_txt_path: ./dset_train2024.txt
# Processing filename: 000000001591_jpg.rf.6707cd1cdfcde959a680bbeae4d360a0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001591_jpg.rf.6707cd1cdfcde959a680bbeae4d360a0.jpg
# Label: ./dataset/labels/train/000000001591_jpg.rf.6707cd1cdfcde959a680bbeae4d360a0.txt
# Processing filename: 000000005340_jpg.rf.930ac45b0b9e7103562167dc8e408e1b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005340_jpg.rf.930ac45b0b9e7103562167dc8e408e1b.jpg
# Label: ./dataset/labels/train/000000005340_jpg.rf.930ac45b0b9e7103562167dc8e408e1b.txt
# Processing filename: 000000004244_jpg.rf.672775c4b8cf6a8d540dbb51f307e443.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004244_jpg.rf.672775c4b8cf6a8d540dbb51f307e443.jpg
# Label: ./dataset/labels/train/000000004244_jpg.rf.672775c4b8cf6a8d540dbb51f307e443.txt
# Processing filename: 000000004282_jpg.rf.0d469aaa6297b76cfa848b651b54ee27.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004282_jpg.rf.0d469aaa6297b76cfa848b651b54ee27.jpg
# Label: ./dataset/labels/train/000000004282_jpg.rf.0d469aaa6297b76cfa848b651b54ee27.txt
# Processing filename: 000000002495_jpg.rf.92f50e5a3159158ec187f12bc44946ec.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002495_jpg.rf.92f50e5a3159158ec187f12bc44946ec.jpg
# Label: ./dataset/labels/train/000000002495_jpg.rf.92f50e5a3159158ec187f12bc44946ec.txt
# Processing filename: 000000002434_jpg.rf.675090866b8f1963557c442172004fc0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002434_jpg.rf.675090866b8f1963557c442172004fc0.jpg
# Label: ./dataset/labels/train/000000002434_jpg.rf.675090866b8f1963557c442172004fc0.txt
# Processing filename: 000000000241_jpg.rf.0dcbc0cbe7c97f092fa56eb357454ab0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000241_jpg.rf.0dcbc0cbe7c97f092fa56eb357454ab0.jpg
# Label: ./dataset/labels/train/000000000241_jpg.rf.0dcbc0cbe7c97f092fa56eb357454ab0.txt
# Processing filename: 000000004386_jpg.rf.6751aa49279db3e6fdec92e23883142d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004386_jpg.rf.6751aa49279db3e6fdec92e23883142d.jpg
# Label: ./dataset/labels/train/000000004386_jpg.rf.6751aa49279db3e6fdec92e23883142d.txt
# Processing filename: 000000001774_jpg.rf.c03def0de042681cb75c9809196c1185.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001774_jpg.rf.c03def0de042681cb75c9809196c1185.jpg
# Label: ./dataset/labels/train/000000001774_jpg.rf.c03def0de042681cb75c9809196c1185.txt
# Processing filename: 000000005154_jpg.rf.3a54bcd90ded80c23814a7774a3168d8.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005154_jpg.rf.3a54bcd90ded80c23814a7774a3168d8.jpg
# Label: ./dataset/labels/train/000000005154_jpg.rf.3a54bcd90ded80c23814a7774a3168d8.txt
# Processing filename: 000000005180_jpg.rf.3a809a4d32cdfdf4b8178d2f59d6d5c0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005180_jpg.rf.3a809a4d32cdfdf4b8178d2f59d6d5c0.jpg
# Label: ./dataset/labels/train/000000005180_jpg.rf.3a809a4d32cdfdf4b8178d2f59d6d5c0.txt
# Processing filename: 000000002759_jpg.rf.c0a3dee4098564eac8092c6bad4302f1.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002759_jpg.rf.c0a3dee4098564eac8092c6bad4302f1.jpg
# Label: ./dataset/labels/train/000000002759_jpg.rf.c0a3dee4098564eac8092c6bad4302f1.txt
# Processing filename: 000000001522_jpg.rf.3a8c0c81b918a3071981e79484eafa3c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001522_jpg.rf.3a8c0c81b918a3071981e79484eafa3c.jpg
# Label: ./dataset/labels/train/000000001522_jpg.rf.3a8c0c81b918a3071981e79484eafa3c.txt
# Processing filename: 000000000699_jpg.rf.67a8c76d738a9e1111acd34b5f685efe.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000699_jpg.rf.67a8c76d738a9e1111acd34b5f685efe.jpg
# Label: ./dataset/labels/train/000000000699_jpg.rf.67a8c76d738a9e1111acd34b5f685efe.txt
# Processing filename: 000000000897_jpg.rf.6777908a16c4f75cbb4fb7cb5b198c36.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000897_jpg.rf.6777908a16c4f75cbb4fb7cb5b198c36.jpg
# Label: ./dataset/labels/train/000000000897_jpg.rf.6777908a16c4f75cbb4fb7cb5b198c36.txt
# Processing filename: 000000005394_jpg.rf.ee0eddf483df75f35628ab3bc9a1bcad.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005394_jpg.rf.ee0eddf483df75f35628ab3bc9a1bcad.jpg
# Label: ./dataset/labels/train/000000005394_jpg.rf.ee0eddf483df75f35628ab3bc9a1bcad.txt
# Processing filename: 000000001554_jpg.rf.67acc5ee43e961d100b956d50a1b947e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001554_jpg.rf.67acc5ee43e961d100b956d50a1b947e.jpg
# Label: ./dataset/labels/train/000000001554_jpg.rf.67acc5ee43e961d100b956d50a1b947e.txt
# Processing filename: 000000004157_jpg.rf.ee5e47170e7585421fac70223a1e3295.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004157_jpg.rf.ee5e47170e7585421fac70223a1e3295.jpg
# Label: ./dataset/labels/train/000000004157_jpg.rf.ee5e47170e7585421fac70223a1e3295.txt
# Processing filename: 000000002555_jpg.rf.0e23195b581858e5673e7f95aa3de415.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002555_jpg.rf.0e23195b581858e5673e7f95aa3de415.jpg
# Label: ./dataset/labels/train/000000002555_jpg.rf.0e23195b581858e5673e7f95aa3de415.txt
# Processing filename: 000000001739_jpg.rf.3a9e43306052bfa6af273b13bf14b6d5.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001739_jpg.rf.3a9e43306052bfa6af273b13bf14b6d5.jpg
# Label: ./dataset/labels/train/000000001739_jpg.rf.3a9e43306052bfa6af273b13bf14b6d5.txt
# Processing filename: 000000000828_jpg.rf.93e4a8c6b56ac879a30103dd6f433874.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000828_jpg.rf.93e4a8c6b56ac879a30103dd6f433874.jpg
# Label: ./dataset/labels/train/000000000828_jpg.rf.93e4a8c6b56ac879a30103dd6f433874.txt
# Processing filename: 000000001360_jpg.rf.93fb98149b84679542d39f394139ab56.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001360_jpg.rf.93fb98149b84679542d39f394139ab56.jpg
# Label: ./dataset/labels/train/000000001360_jpg.rf.93fb98149b84679542d39f394139ab56.txt
# Processing filename: 000000002752_jpg.rf.ee747ec531edbbe5856cfd6240737eb0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002752_jpg.rf.ee747ec531edbbe5856cfd6240737eb0.jpg
# Label: ./dataset/labels/train/000000002752_jpg.rf.ee747ec531edbbe5856cfd6240737eb0.txt
# Processing filename: 000000003935_jpg.rf.94112bfcfd0044af0d3af4c753cdae35.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003935_jpg.rf.94112bfcfd0044af0d3af4c753cdae35.jpg
# Label: ./dataset/labels/train/000000003935_jpg.rf.94112bfcfd0044af0d3af4c753cdae35.txt
# Processing filename: 000000000531_jpg.rf.ee9d89e649144b7d9bb0172001c7c77c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000531_jpg.rf.ee9d89e649144b7d9bb0172001c7c77c.jpg
# Label: ./dataset/labels/train/000000000531_jpg.rf.ee9d89e649144b7d9bb0172001c7c77c.txt
# Processing filename: 000000002782_jpg.rf.3b1797cd25dd1a3afb838fe4b232cb84.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002782_jpg.rf.3b1797cd25dd1a3afb838fe4b232cb84.jpg
# Label: ./dataset/labels/train/000000002782_jpg.rf.3b1797cd25dd1a3afb838fe4b232cb84.txt
# Processing filename: 000000000061_jpg.rf.eeaf447e1d2e603c13a451bdbaadf6cd.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000061_jpg.rf.eeaf447e1d2e603c13a451bdbaadf6cd.jpg
# Label: ./dataset/labels/train/000000000061_jpg.rf.eeaf447e1d2e603c13a451bdbaadf6cd.txt
# Processing filename: 000000001626_jpg.rf.688ccd0dcac9d9fc068a9ad37b571f16.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001626_jpg.rf.688ccd0dcac9d9fc068a9ad37b571f16.jpg
# Label: ./dataset/labels/train/000000001626_jpg.rf.688ccd0dcac9d9fc068a9ad37b571f16.txt
# Processing filename: 000000000982_jpg.rf.3b792be6ff75b543d9d0ae8c35a96677.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000982_jpg.rf.3b792be6ff75b543d9d0ae8c35a96677.jpg
# Label: ./dataset/labels/train/000000000982_jpg.rf.3b792be6ff75b543d9d0ae8c35a96677.txt
# Processing filename: 000000003947_jpg.rf.eed31184de003f46e5ce3835d258da84.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003947_jpg.rf.eed31184de003f46e5ce3835d258da84.jpg
# Label: ./dataset/labels/train/000000003947_jpg.rf.eed31184de003f46e5ce3835d258da84.txt
# Processing filename: 000000003378_jpg.rf.c19f9280904836d6cad8f8841e2d1393.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003378_jpg.rf.c19f9280904836d6cad8f8841e2d1393.jpg
# Label: ./dataset/labels/train/000000003378_jpg.rf.c19f9280904836d6cad8f8841e2d1393.txt
# Processing filename: 000000003862_jpg.rf.68adb2e862c41e366349f6f3d17e0e2f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003862_jpg.rf.68adb2e862c41e366349f6f3d17e0e2f.jpg
# Label: ./dataset/labels/train/000000003862_jpg.rf.68adb2e862c41e366349f6f3d17e0e2f.txt
# Processing filename: 000000000996_jpg.rf.948d5879e50e29db84a608b24d1ba8e9.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000996_jpg.rf.948d5879e50e29db84a608b24d1ba8e9.jpg
# Label: ./dataset/labels/train/000000000996_jpg.rf.948d5879e50e29db84a608b24d1ba8e9.txt
# Processing filename: 000000001790_jpg.rf.0efcae09659157f3e0c5ed85936c38e1.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001790_jpg.rf.0efcae09659157f3e0c5ed85936c38e1.jpg
# Label: ./dataset/labels/train/000000001790_jpg.rf.0efcae09659157f3e0c5ed85936c38e1.txt
# Processing filename: 000000001424_jpg.rf.0ee19759b4c1f2c760d7d62ee6362e70.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001424_jpg.rf.0ee19759b4c1f2c760d7d62ee6362e70.jpg
# Label: ./dataset/labels/train/000000001424_jpg.rf.0ee19759b4c1f2c760d7d62ee6362e70.txt
# Processing filename: 000000001472_jpg.rf.68ae74cec39ecd98c90e692c247cb69d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001472_jpg.rf.68ae74cec39ecd98c90e692c247cb69d.jpg
# Label: ./dataset/labels/train/000000001472_jpg.rf.68ae74cec39ecd98c90e692c247cb69d.txt
# Processing filename: 000000001912_jpg.rf.68e9df689e3dbdf9e49bd8240356b612.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001912_jpg.rf.68e9df689e3dbdf9e49bd8240356b612.jpg
# Label: ./dataset/labels/train/000000001912_jpg.rf.68e9df689e3dbdf9e49bd8240356b612.txt
# Processing filename: 000000003192_jpg.rf.68f2a65598679eebafdd88e9e2f3deb6.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003192_jpg.rf.68f2a65598679eebafdd88e9e2f3deb6.jpg
# Label: ./dataset/labels/train/000000003192_jpg.rf.68f2a65598679eebafdd88e9e2f3deb6.txt
# Processing filename: 000000005215_jpg.rf.68d90d7c6b8b4a65d6f12c1d833ac64d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005215_jpg.rf.68d90d7c6b8b4a65d6f12c1d833ac64d.jpg
# Label: ./dataset/labels/train/000000005215_jpg.rf.68d90d7c6b8b4a65d6f12c1d833ac64d.txt
# Processing filename: 000000005482_jpg.rf.3bcbccd1734d4e1214456fbaae93b95d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005482_jpg.rf.3bcbccd1734d4e1214456fbaae93b95d.jpg
# Label: ./dataset/labels/train/000000005482_jpg.rf.3bcbccd1734d4e1214456fbaae93b95d.txt
# Processing filename: 000000001144_jpg.rf.c1d97adaca756dea43c1c36953904a8a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001144_jpg.rf.c1d97adaca756dea43c1c36953904a8a.jpg
# Label: ./dataset/labels/train/000000001144_jpg.rf.c1d97adaca756dea43c1c36953904a8a.txt
# Processing filename: 000000004741_jpg.rf.ef275f652b57e299236e9d51c60beaec.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004741_jpg.rf.ef275f652b57e299236e9d51c60beaec.jpg
# Label: ./dataset/labels/train/000000004741_jpg.rf.ef275f652b57e299236e9d51c60beaec.txt
# Processing filename: 000000002614_jpg.rf.3bd36d56d520662d8550ef343aeec307.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002614_jpg.rf.3bd36d56d520662d8550ef343aeec307.jpg
# Label: ./dataset/labels/train/000000002614_jpg.rf.3bd36d56d520662d8550ef343aeec307.txt
# Processing filename: 000000001622_jpg.rf.c22463ecbaf9a4d024a49201c0936a50.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001622_jpg.rf.c22463ecbaf9a4d024a49201c0936a50.jpg
# Label: ./dataset/labels/train/000000001622_jpg.rf.c22463ecbaf9a4d024a49201c0936a50.txt
# Processing filename: 000000001014_jpg.rf.ef5ec15f61c11c48646441a31fe72600.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001014_jpg.rf.ef5ec15f61c11c48646441a31fe72600.jpg
# Label: ./dataset/labels/train/000000001014_jpg.rf.ef5ec15f61c11c48646441a31fe72600.txt
# Processing filename: 000000000634_jpg.rf.c21e9456a8fa5485b0421e8a9a4e80b3.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000634_jpg.rf.c21e9456a8fa5485b0421e8a9a4e80b3.jpg
# Label: ./dataset/labels/train/000000000634_jpg.rf.c21e9456a8fa5485b0421e8a9a4e80b3.txt
# Processing filename: 000000000450_jpg.rf.696ca9cbbc9d6a9d97764f270e18ddbf.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000450_jpg.rf.696ca9cbbc9d6a9d97764f270e18ddbf.jpg
# Label: ./dataset/labels/train/000000000450_jpg.rf.696ca9cbbc9d6a9d97764f270e18ddbf.txt
# Processing filename: 000000002742_jpg.rf.0faf272ff8418321d1eabd70ad8eb840.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002742_jpg.rf.0faf272ff8418321d1eabd70ad8eb840.jpg
# Label: ./dataset/labels/train/000000002742_jpg.rf.0faf272ff8418321d1eabd70ad8eb840.txt
# Processing filename: 000000004592_jpg.rf.0fac12be521664456e6d75f534733fc8.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004592_jpg.rf.0fac12be521664456e6d75f534733fc8.jpg
# Label: ./dataset/labels/train/000000004592_jpg.rf.0fac12be521664456e6d75f534733fc8.txt
# Processing filename: 000000005088_jpg.rf.ef9c9643b2a8452951ee09850f9e791b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005088_jpg.rf.ef9c9643b2a8452951ee09850f9e791b.jpg
# Label: ./dataset/labels/train/000000005088_jpg.rf.ef9c9643b2a8452951ee09850f9e791b.txt
# Processing filename: 000000004428_jpg.rf.c2656a8eb1ff2e5cea603db4f8038e6b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004428_jpg.rf.c2656a8eb1ff2e5cea603db4f8038e6b.jpg
# Label: ./dataset/labels/train/000000004428_jpg.rf.c2656a8eb1ff2e5cea603db4f8038e6b.txt
# Processing filename: 000000001298_jpg.rf.102394c4d8b79475d2fce2b5be9db4cd.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001298_jpg.rf.102394c4d8b79475d2fce2b5be9db4cd.jpg
# Label: ./dataset/labels/train/000000001298_jpg.rf.102394c4d8b79475d2fce2b5be9db4cd.txt
# Processing filename: 000000004426_jpg.rf.efdf93e1d0e41f851cb18cc44f0b178c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004426_jpg.rf.efdf93e1d0e41f851cb18cc44f0b178c.jpg
# Label: ./dataset/labels/train/000000004426_jpg.rf.efdf93e1d0e41f851cb18cc44f0b178c.txt
# Processing filename: 000000000675_jpg.rf.3cca450e484f6f4ce81079601a89422f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000675_jpg.rf.3cca450e484f6f4ce81079601a89422f.jpg
# Label: ./dataset/labels/train/000000000675_jpg.rf.3cca450e484f6f4ce81079601a89422f.txt
# Processing filename: 000000000625_jpg.rf.102a03bb9975278f3bbd68a01dc91333.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000625_jpg.rf.102a03bb9975278f3bbd68a01dc91333.jpg
# Label: ./dataset/labels/train/000000000625_jpg.rf.102a03bb9975278f3bbd68a01dc91333.txt
# Processing filename: 000000003483_jpg.rf.105990258fab25618a1e74cdda8672c0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003483_jpg.rf.105990258fab25618a1e74cdda8672c0.jpg
# Label: ./dataset/labels/train/000000003483_jpg.rf.105990258fab25618a1e74cdda8672c0.txt
# Processing filename: 000000000382_jpg.rf.3cd43afa879064a41e68b06e1e3b5f56.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000382_jpg.rf.3cd43afa879064a41e68b06e1e3b5f56.jpg
# Label: ./dataset/labels/train/000000000382_jpg.rf.3cd43afa879064a41e68b06e1e3b5f56.txt
# Processing filename: 000000000775_jpg.rf.106572494331e84ab65fbf62409d227c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000775_jpg.rf.106572494331e84ab65fbf62409d227c.jpg
# Label: ./dataset/labels/train/000000000775_jpg.rf.106572494331e84ab65fbf62409d227c.txt
# Processing filename: 000000000488_jpg.rf.107fdda6806ed9078ffbc17b83b39f5a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000488_jpg.rf.107fdda6806ed9078ffbc17b83b39f5a.jpg
# Label: ./dataset/labels/train/000000000488_jpg.rf.107fdda6806ed9078ffbc17b83b39f5a.txt
# Processing filename: 000000001036_jpg.rf.3d5276a84c6ad803736ef2acf9322880.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001036_jpg.rf.3d5276a84c6ad803736ef2acf9322880.jpg
# Label: ./dataset/labels/train/000000001036_jpg.rf.3d5276a84c6ad803736ef2acf9322880.txt
# Processing filename: 000000001407_jpg.rf.6a166d05b7fcafcb11d93a163480efc8.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001407_jpg.rf.6a166d05b7fcafcb11d93a163480efc8.jpg
# Label: ./dataset/labels/train/000000001407_jpg.rf.6a166d05b7fcafcb11d93a163480efc8.txt
# Processing filename: 000000001737_jpg.rf.c3407a1471a485132c5f98c062d0dd52.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001737_jpg.rf.c3407a1471a485132c5f98c062d0dd52.jpg
# Label: ./dataset/labels/train/000000001737_jpg.rf.c3407a1471a485132c5f98c062d0dd52.txt
# Processing filename: 000000002758_jpg.rf.c33a28e8f3e5a9878ed2cb86a9beef9b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002758_jpg.rf.c33a28e8f3e5a9878ed2cb86a9beef9b.jpg
# Label: ./dataset/labels/train/000000002758_jpg.rf.c33a28e8f3e5a9878ed2cb86a9beef9b.txt
# Processing filename: 000000002388_jpg.rf.107cdb72e22ee9bc6f674e6ede853aa7.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002388_jpg.rf.107cdb72e22ee9bc6f674e6ede853aa7.jpg
# Label: ./dataset/labels/train/000000002388_jpg.rf.107cdb72e22ee9bc6f674e6ede853aa7.txt
# Processing filename: 000000002693_jpg.rf.10c1215832835a5386f553f92897a37c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002693_jpg.rf.10c1215832835a5386f553f92897a37c.jpg
# Label: ./dataset/labels/train/000000002693_jpg.rf.10c1215832835a5386f553f92897a37c.txt
# Processing filename: 000000003321_jpg.rf.c39eacb05aa295c31252535dbbc97b74.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003321_jpg.rf.c39eacb05aa295c31252535dbbc97b74.jpg
# Label: ./dataset/labels/train/000000003321_jpg.rf.c39eacb05aa295c31252535dbbc97b74.txt
# Processing filename: 000000002619_jpg.rf.9649b7e69ae80dad710d83960e274c72.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002619_jpg.rf.9649b7e69ae80dad710d83960e274c72.jpg
# Label: ./dataset/labels/train/000000002619_jpg.rf.9649b7e69ae80dad710d83960e274c72.txt
# Processing filename: 000000002583_jpg.rf.f0aa8d23ec98cb28413a59847bf2d671.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002583_jpg.rf.f0aa8d23ec98cb28413a59847bf2d671.jpg
# Label: ./dataset/labels/train/000000002583_jpg.rf.f0aa8d23ec98cb28413a59847bf2d671.txt
# Processing filename: 000000003877_jpg.rf.10eca28e17ba0e1f03179414f77baa67.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003877_jpg.rf.10eca28e17ba0e1f03179414f77baa67.jpg
# Label: ./dataset/labels/train/000000003877_jpg.rf.10eca28e17ba0e1f03179414f77baa67.txt
# Processing filename: 000000004885_jpg.rf.f0ff38f78cf2062517df944953b21d0f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004885_jpg.rf.f0ff38f78cf2062517df944953b21d0f.jpg
# Label: ./dataset/labels/train/000000004885_jpg.rf.f0ff38f78cf2062517df944953b21d0f.txt
# Processing filename: 000000003860_jpg.rf.6a9a5ab5a900a70e6adb4496e0d9ccba.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003860_jpg.rf.6a9a5ab5a900a70e6adb4496e0d9ccba.jpg
# Label: ./dataset/labels/train/000000003860_jpg.rf.6a9a5ab5a900a70e6adb4496e0d9ccba.txt
# Processing filename: 000000003134_jpg.rf.10e8d39a68500bbb1fe146209cf97baa.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003134_jpg.rf.10e8d39a68500bbb1fe146209cf97baa.jpg
# Label: ./dataset/labels/train/000000003134_jpg.rf.10e8d39a68500bbb1fe146209cf97baa.txt
# Processing filename: 000000001869_jpg.rf.6ae346c424b6ff980e7f283d9e41a034.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001869_jpg.rf.6ae346c424b6ff980e7f283d9e41a034.jpg
# Label: ./dataset/labels/train/000000001869_jpg.rf.6ae346c424b6ff980e7f283d9e41a034.txt
# Processing filename: 000000002687_jpg.rf.96a6b3103be1dc9bf4cf0397b696962f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002687_jpg.rf.96a6b3103be1dc9bf4cf0397b696962f.jpg
# Label: ./dataset/labels/train/000000002687_jpg.rf.96a6b3103be1dc9bf4cf0397b696962f.txt
# Processing filename: 000000000074_jpg.rf.3ddcfeced70e1e7d28bfd0e3d08b0321.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000074_jpg.rf.3ddcfeced70e1e7d28bfd0e3d08b0321.jpg
# Label: ./dataset/labels/train/000000000074_jpg.rf.3ddcfeced70e1e7d28bfd0e3d08b0321.txt
# Processing filename: 000000000825_jpg.rf.6aebcac09483f6ec57963f05b6b12e16.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000825_jpg.rf.6aebcac09483f6ec57963f05b6b12e16.jpg
# Label: ./dataset/labels/train/000000000825_jpg.rf.6aebcac09483f6ec57963f05b6b12e16.txt
# Processing filename: 000000004571_jpg.rf.114206f09e1d45b3cd7c7f928f13be70.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004571_jpg.rf.114206f09e1d45b3cd7c7f928f13be70.jpg
# Label: ./dataset/labels/train/000000004571_jpg.rf.114206f09e1d45b3cd7c7f928f13be70.txt
# Processing filename: 000000001924_jpg.rf.1169f6db9afcf4d5e61cd60f5c0b7651.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001924_jpg.rf.1169f6db9afcf4d5e61cd60f5c0b7651.jpg
# Label: ./dataset/labels/train/000000001924_jpg.rf.1169f6db9afcf4d5e61cd60f5c0b7651.txt
# Processing filename: 000000004761_jpg.rf.3e01335cf22a416bba0780ce43184f34.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004761_jpg.rf.3e01335cf22a416bba0780ce43184f34.jpg
# Label: ./dataset/labels/train/000000004761_jpg.rf.3e01335cf22a416bba0780ce43184f34.txt
# Processing filename: 000000003735_jpg.rf.11622807032d988b5e8c80c7b9c53a35.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003735_jpg.rf.11622807032d988b5e8c80c7b9c53a35.jpg
# Label: ./dataset/labels/train/000000003735_jpg.rf.11622807032d988b5e8c80c7b9c53a35.txt
# Processing filename: 000000001392_jpg.rf.c47d79b8b49173063b8f654428a61c8e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001392_jpg.rf.c47d79b8b49173063b8f654428a61c8e.jpg
# Label: ./dataset/labels/train/000000001392_jpg.rf.c47d79b8b49173063b8f654428a61c8e.txt
# Processing filename: 000000001777_jpg.rf.c4476fd37f1f8b80ffe04d8bf332d166.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001777_jpg.rf.c4476fd37f1f8b80ffe04d8bf332d166.jpg
# Label: ./dataset/labels/train/000000001777_jpg.rf.c4476fd37f1f8b80ffe04d8bf332d166.txt
# Processing filename: 000000001907_jpg.rf.118379411d5eb83afecee22d9891fe71.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001907_jpg.rf.118379411d5eb83afecee22d9891fe71.jpg
# Label: ./dataset/labels/train/000000001907_jpg.rf.118379411d5eb83afecee22d9891fe71.txt
# Processing filename: 000000001580_jpg.rf.c4a3cc25d6c53eeefc61ae8d3ccc3dfe.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001580_jpg.rf.c4a3cc25d6c53eeefc61ae8d3ccc3dfe.jpg
# Label: ./dataset/labels/train/000000001580_jpg.rf.c4a3cc25d6c53eeefc61ae8d3ccc3dfe.txt
# Processing filename: 000000001611_jpg.rf.3ea0fc898280dea006d450ac27440332.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001611_jpg.rf.3ea0fc898280dea006d450ac27440332.jpg
# Label: ./dataset/labels/train/000000001611_jpg.rf.3ea0fc898280dea006d450ac27440332.txt
# Processing filename: 000000000564_jpg.rf.976ccecad8582602221101e139ff4d2b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000564_jpg.rf.976ccecad8582602221101e139ff4d2b.jpg
# Label: ./dataset/labels/train/000000000564_jpg.rf.976ccecad8582602221101e139ff4d2b.txt
# Processing filename: 000000002608_jpg.rf.c485caecb6fe4e5bb3d54206706ab15f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002608_jpg.rf.c485caecb6fe4e5bb3d54206706ab15f.jpg
# Label: ./dataset/labels/train/000000002608_jpg.rf.c485caecb6fe4e5bb3d54206706ab15f.txt
# Processing filename: 000000001706_jpg.rf.11db0066054859067d50647860accaeb.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001706_jpg.rf.11db0066054859067d50647860accaeb.jpg
# Label: ./dataset/labels/train/000000001706_jpg.rf.11db0066054859067d50647860accaeb.txt
# Processing filename: 000000005113_jpg.rf.9752cefa18ed9f0e6d3d9f4e1e15d2a4.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005113_jpg.rf.9752cefa18ed9f0e6d3d9f4e1e15d2a4.jpg
# Label: ./dataset/labels/train/000000005113_jpg.rf.9752cefa18ed9f0e6d3d9f4e1e15d2a4.txt
# Processing filename: 000000001822_jpg.rf.f1a57196e444a3a030f674fa61f8da05.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001822_jpg.rf.f1a57196e444a3a030f674fa61f8da05.jpg
# Label: ./dataset/labels/train/000000001822_jpg.rf.f1a57196e444a3a030f674fa61f8da05.txt
# Processing filename: 000000002007_jpg.rf.c4d568ea49c57dcc387d6b994e7a3aab.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002007_jpg.rf.c4d568ea49c57dcc387d6b994e7a3aab.jpg
# Label: ./dataset/labels/train/000000002007_jpg.rf.c4d568ea49c57dcc387d6b994e7a3aab.txt
# Processing filename: 000000001906_jpg.rf.3ed65ef4fbd0f62fe78c6cfc3de93543.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001906_jpg.rf.3ed65ef4fbd0f62fe78c6cfc3de93543.jpg
# Label: ./dataset/labels/train/000000001906_jpg.rf.3ed65ef4fbd0f62fe78c6cfc3de93543.txt
# Processing filename: 000000003964_jpg.rf.6bc9dc2b0ddc854b9c35a4c79ceede0f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003964_jpg.rf.6bc9dc2b0ddc854b9c35a4c79ceede0f.jpg
# Label: ./dataset/labels/train/000000003964_jpg.rf.6bc9dc2b0ddc854b9c35a4c79ceede0f.txt
# Processing filename: 000000005453_jpg.rf.6bf161136e5715de9e88a89666b6f08f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005453_jpg.rf.6bf161136e5715de9e88a89666b6f08f.jpg
# Label: ./dataset/labels/train/000000005453_jpg.rf.6bf161136e5715de9e88a89666b6f08f.txt
# Processing filename: 000000001355_jpg.rf.f25df1e885ebd8b6ec0928c0966977a4.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001355_jpg.rf.f25df1e885ebd8b6ec0928c0966977a4.jpg
# Label: ./dataset/labels/train/000000001355_jpg.rf.f25df1e885ebd8b6ec0928c0966977a4.txt
# Processing filename: 000000001145_jpg.rf.c5369267b63a7a413cde6579bb4517ca.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001145_jpg.rf.c5369267b63a7a413cde6579bb4517ca.jpg
# Label: ./dataset/labels/train/000000001145_jpg.rf.c5369267b63a7a413cde6579bb4517ca.txt
# Processing filename: 000000004981_jpg.rf.6c280b14dc4973a760c387d677852eb1.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004981_jpg.rf.6c280b14dc4973a760c387d677852eb1.jpg
# Label: ./dataset/labels/train/000000004981_jpg.rf.6c280b14dc4973a760c387d677852eb1.txt
# Processing filename: 000000001915_jpg.rf.f265fe2254e39f183b3624338ef65c6b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001915_jpg.rf.f265fe2254e39f183b3624338ef65c6b.jpg
# Label: ./dataset/labels/train/000000001915_jpg.rf.f265fe2254e39f183b3624338ef65c6b.txt
# Processing filename: 000000002209_jpg.rf.f2b81e4ebdff14af44638ce5d8a15afc.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002209_jpg.rf.f2b81e4ebdff14af44638ce5d8a15afc.jpg
# Label: ./dataset/labels/train/000000002209_jpg.rf.f2b81e4ebdff14af44638ce5d8a15afc.txt
# Processing filename: 000000005028_jpg.rf.f297e5f99d7b09db2659481515bd1818.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005028_jpg.rf.f297e5f99d7b09db2659481515bd1818.jpg
# Label: ./dataset/labels/train/000000005028_jpg.rf.f297e5f99d7b09db2659481515bd1818.txt
# Processing filename: 000000001323_jpg.rf.983a9c1427bcb63ff1c681591f997425.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001323_jpg.rf.983a9c1427bcb63ff1c681591f997425.jpg
# Label: ./dataset/labels/train/000000001323_jpg.rf.983a9c1427bcb63ff1c681591f997425.txt
# Processing filename: 000000002229_jpg.rf.9868e85f8b0d48a2f8d35180ef98be7c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002229_jpg.rf.9868e85f8b0d48a2f8d35180ef98be7c.jpg
# Label: ./dataset/labels/train/000000002229_jpg.rf.9868e85f8b0d48a2f8d35180ef98be7c.txt
# Processing filename: 000000000307_jpg.rf.f2d901fe9a908e162f3bd0942052b468.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000307_jpg.rf.f2d901fe9a908e162f3bd0942052b468.jpg
# Label: ./dataset/labels/train/000000000307_jpg.rf.f2d901fe9a908e162f3bd0942052b468.txt
# Processing filename: 000000001164_jpg.rf.3ff9f1aa5011dcbfcf02f53720a06135.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001164_jpg.rf.3ff9f1aa5011dcbfcf02f53720a06135.jpg
# Label: ./dataset/labels/train/000000001164_jpg.rf.3ff9f1aa5011dcbfcf02f53720a06135.txt
# Processing filename: 000000000326_jpg.rf.c5f4cb43884d56fb3b3420a192b8fcde.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000326_jpg.rf.c5f4cb43884d56fb3b3420a192b8fcde.jpg
# Label: ./dataset/labels/train/000000000326_jpg.rf.c5f4cb43884d56fb3b3420a192b8fcde.txt
# Processing filename: 000000001455_jpg.rf.1313ad7aa9f3ab16b021c89abbfe6c4a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001455_jpg.rf.1313ad7aa9f3ab16b021c89abbfe6c4a.jpg
# Label: ./dataset/labels/train/000000001455_jpg.rf.1313ad7aa9f3ab16b021c89abbfe6c4a.txt
# Processing filename: 000000004283_jpg.rf.c5d363ef110fe290f7768dda8d8d9916.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004283_jpg.rf.c5d363ef110fe290f7768dda8d8d9916.jpg
# Label: ./dataset/labels/train/000000004283_jpg.rf.c5d363ef110fe290f7768dda8d8d9916.txt
# Processing filename: 000000004988_jpg.rf.98e2ed65add3ce854c5a69ac171e86c9.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004988_jpg.rf.98e2ed65add3ce854c5a69ac171e86c9.jpg
# Label: ./dataset/labels/train/000000004988_jpg.rf.98e2ed65add3ce854c5a69ac171e86c9.txt
# Processing filename: 000000005032_jpg.rf.c6442e7f68fb327df5295a7a18f698d7.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005032_jpg.rf.c6442e7f68fb327df5295a7a18f698d7.jpg
# Label: ./dataset/labels/train/000000005032_jpg.rf.c6442e7f68fb327df5295a7a18f698d7.txt
# Processing filename: 000000001029_jpg.rf.4046b83b026c00a72c1001035fd0fb2a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001029_jpg.rf.4046b83b026c00a72c1001035fd0fb2a.jpg
# Label: ./dataset/labels/train/000000001029_jpg.rf.4046b83b026c00a72c1001035fd0fb2a.txt
# Processing filename: 000000002276_jpg.rf.c62b3523982144eefd573baf0eaa348f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002276_jpg.rf.c62b3523982144eefd573baf0eaa348f.jpg
# Label: ./dataset/labels/train/000000002276_jpg.rf.c62b3523982144eefd573baf0eaa348f.txt
# Processing filename: 000000002445_jpg.rf.6d05b27ee73ecf742d9e71019e721340.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002445_jpg.rf.6d05b27ee73ecf742d9e71019e721340.jpg
# Label: ./dataset/labels/train/000000002445_jpg.rf.6d05b27ee73ecf742d9e71019e721340.txt
# Processing filename: 000000004809_jpg.rf.c6696942ca46c9afb35962b9ed57bb09.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004809_jpg.rf.c6696942ca46c9afb35962b9ed57bb09.jpg
# Label: ./dataset/labels/train/000000004809_jpg.rf.c6696942ca46c9afb35962b9ed57bb09.txt
# Processing filename: 000000003745_jpg.rf.6d22930766e78b5f9a8693731227931b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003745_jpg.rf.6d22930766e78b5f9a8693731227931b.jpg
# Label: ./dataset/labels/train/000000003745_jpg.rf.6d22930766e78b5f9a8693731227931b.txt
# Processing filename: 000000002056_jpg.rf.408c0a8141e3f94101847e4d4124fcfc.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002056_jpg.rf.408c0a8141e3f94101847e4d4124fcfc.jpg
# Label: ./dataset/labels/train/000000002056_jpg.rf.408c0a8141e3f94101847e4d4124fcfc.txt
# Processing filename: 000000002570_jpg.rf.6d29028df83ddb98d76207482857525c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002570_jpg.rf.6d29028df83ddb98d76207482857525c.jpg
# Label: ./dataset/labels/train/000000002570_jpg.rf.6d29028df83ddb98d76207482857525c.txt
# Processing filename: 000000002983_jpg.rf.99158472dcbb8e1902c730368ff5cfab.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002983_jpg.rf.99158472dcbb8e1902c730368ff5cfab.jpg
# Label: ./dataset/labels/train/000000002983_jpg.rf.99158472dcbb8e1902c730368ff5cfab.txt
# Processing filename: 000000004880_jpg.rf.6dafe9e8ceca877c330f325600d77e25.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004880_jpg.rf.6dafe9e8ceca877c330f325600d77e25.jpg
# Label: ./dataset/labels/train/000000004880_jpg.rf.6dafe9e8ceca877c330f325600d77e25.txt
# Processing filename: 000000000987_jpg.rf.6d777e43273a8d8ffd8281aaadd80737.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000987_jpg.rf.6d777e43273a8d8ffd8281aaadd80737.jpg
# Label: ./dataset/labels/train/000000000987_jpg.rf.6d777e43273a8d8ffd8281aaadd80737.txt
# Processing filename: 000000001102_jpg.rf.f43360d111e2078830d17423a85c2d11.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001102_jpg.rf.f43360d111e2078830d17423a85c2d11.jpg
# Label: ./dataset/labels/train/000000001102_jpg.rf.f43360d111e2078830d17423a85c2d11.txt
# Processing filename: 000000005483_jpg.rf.13d782cb579bb85e750bfde3401d942e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005483_jpg.rf.13d782cb579bb85e750bfde3401d942e.jpg
# Label: ./dataset/labels/train/000000005483_jpg.rf.13d782cb579bb85e750bfde3401d942e.txt
# Processing filename: 000000000974_jpg.rf.6dc459a48c1ff260407156a35573adc9.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000974_jpg.rf.6dc459a48c1ff260407156a35573adc9.jpg
# Label: ./dataset/labels/train/000000000974_jpg.rf.6dc459a48c1ff260407156a35573adc9.txt
# Processing filename: 000000003310_jpg.rf.414f0ba2e866d268228479cf19ad3c04.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003310_jpg.rf.414f0ba2e866d268228479cf19ad3c04.jpg
# Label: ./dataset/labels/train/000000003310_jpg.rf.414f0ba2e866d268228479cf19ad3c04.txt
# Processing filename: 000000003348_jpg.rf.6e14effc7f7e28bcfeb6aa942308b9bd.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003348_jpg.rf.6e14effc7f7e28bcfeb6aa942308b9bd.jpg
# Label: ./dataset/labels/train/000000003348_jpg.rf.6e14effc7f7e28bcfeb6aa942308b9bd.txt
# Processing filename: 000000004201_jpg.rf.c72c0142f1310be76845d8c3e9bb84dc.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004201_jpg.rf.c72c0142f1310be76845d8c3e9bb84dc.jpg
# Label: ./dataset/labels/train/000000004201_jpg.rf.c72c0142f1310be76845d8c3e9bb84dc.txt
# Processing filename: 000000000831_jpg.rf.99edf6b6ef9792ddf2b575f0da410feb.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000831_jpg.rf.99edf6b6ef9792ddf2b575f0da410feb.jpg
# Label: ./dataset/labels/train/000000000831_jpg.rf.99edf6b6ef9792ddf2b575f0da410feb.txt
# Processing filename: 000000002124_jpg.rf.f4f520abac63d1f9d59290ffbbf28fd1.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002124_jpg.rf.f4f520abac63d1f9d59290ffbbf28fd1.jpg
# Label: ./dataset/labels/train/000000002124_jpg.rf.f4f520abac63d1f9d59290ffbbf28fd1.txt
# Processing filename: 000000003590_jpg.rf.14e32a071ee4eebe35e2ab4fdc7bf533.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003590_jpg.rf.14e32a071ee4eebe35e2ab4fdc7bf533.jpg
# Label: ./dataset/labels/train/000000003590_jpg.rf.14e32a071ee4eebe35e2ab4fdc7bf533.txt
# Processing filename: 000000005259_jpg.rf.c7565109b243df5cf249b577ee480b2e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005259_jpg.rf.c7565109b243df5cf249b577ee480b2e.jpg
# Label: ./dataset/labels/train/000000005259_jpg.rf.c7565109b243df5cf249b577ee480b2e.txt
# Processing filename: 000000001902_jpg.rf.41907ebceed74dc66c3b6485ddec8b2c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001902_jpg.rf.41907ebceed74dc66c3b6485ddec8b2c.jpg
# Label: ./dataset/labels/train/000000001902_jpg.rf.41907ebceed74dc66c3b6485ddec8b2c.txt
# Processing filename: 000000002477_jpg.rf.41e46274b46a75f8836f60975895d093.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002477_jpg.rf.41e46274b46a75f8836f60975895d093.jpg
# Label: ./dataset/labels/train/000000002477_jpg.rf.41e46274b46a75f8836f60975895d093.txt
# Processing filename: 000000005435_jpg.rf.c7c1e19cfe854c566bb6437aadffbf3c.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005435_jpg.rf.c7c1e19cfe854c566bb6437aadffbf3c.jpg
# Label: ./dataset/labels/train/000000005435_jpg.rf.c7c1e19cfe854c566bb6437aadffbf3c.txt
# Processing filename: 000000000370_jpg.rf.6e8ef091f8d488b297d2487084138d4a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000370_jpg.rf.6e8ef091f8d488b297d2487084138d4a.jpg
# Label: ./dataset/labels/train/000000000370_jpg.rf.6e8ef091f8d488b297d2487084138d4a.txt
# Processing filename: 000000001911_jpg.rf.f5763d2623e5c7acddeb7f139f82abba.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001911_jpg.rf.f5763d2623e5c7acddeb7f139f82abba.jpg
# Label: ./dataset/labels/train/000000001911_jpg.rf.f5763d2623e5c7acddeb7f139f82abba.txt
# Processing filename: 000000000764_jpg.rf.c7ff4d09b5ac971d6e047e805e641dd5.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000764_jpg.rf.c7ff4d09b5ac971d6e047e805e641dd5.jpg
# Label: ./dataset/labels/train/000000000764_jpg.rf.c7ff4d09b5ac971d6e047e805e641dd5.txt
# Processing filename: 000000000754_jpg.rf.c80aa02d763e29f99d801b8512142061.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000754_jpg.rf.c80aa02d763e29f99d801b8512142061.jpg
# Label: ./dataset/labels/train/000000000754_jpg.rf.c80aa02d763e29f99d801b8512142061.txt
# Processing filename: 000000002754_jpg.rf.156ae790014936bc266178c883dbf7e8.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002754_jpg.rf.156ae790014936bc266178c883dbf7e8.jpg
# Label: ./dataset/labels/train/000000002754_jpg.rf.156ae790014936bc266178c883dbf7e8.txt
# Processing filename: 000000003325_jpg.rf.9aad7ae322238f97131df60b11e812a3.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003325_jpg.rf.9aad7ae322238f97131df60b11e812a3.jpg
# Label: ./dataset/labels/train/000000003325_jpg.rf.9aad7ae322238f97131df60b11e812a3.txt
# Processing filename: 000000000960_jpg.rf.6ee9bc904c95a30f16a4c2b9f6e90c38.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000960_jpg.rf.6ee9bc904c95a30f16a4c2b9f6e90c38.jpg
# Label: ./dataset/labels/train/000000000960_jpg.rf.6ee9bc904c95a30f16a4c2b9f6e90c38.txt
# Processing filename: 000000001688_jpg.rf.1524a56c0e783fa989d8703e332930e5.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001688_jpg.rf.1524a56c0e783fa989d8703e332930e5.jpg
# Label: ./dataset/labels/train/000000001688_jpg.rf.1524a56c0e783fa989d8703e332930e5.txt
# Processing filename: 000000005430_jpg.rf.6f3a3312ae2dfa47b9b5f9c1e911645e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005430_jpg.rf.6f3a3312ae2dfa47b9b5f9c1e911645e.jpg
# Label: ./dataset/labels/train/000000005430_jpg.rf.6f3a3312ae2dfa47b9b5f9c1e911645e.txt
# Processing filename: 000000004739_jpg.rf.425e728a62326a3c086ffc3a69f82956.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004739_jpg.rf.425e728a62326a3c086ffc3a69f82956.jpg
# Label: ./dataset/labels/train/000000004739_jpg.rf.425e728a62326a3c086ffc3a69f82956.txt
# Processing filename: 000000001436_jpg.rf.c83d7ab13f2b8dd7698671eb8604af17.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001436_jpg.rf.c83d7ab13f2b8dd7698671eb8604af17.jpg
# Label: ./dataset/labels/train/000000001436_jpg.rf.c83d7ab13f2b8dd7698671eb8604af17.txt
# Processing filename: 000000001895_jpg.rf.15a4c1bc6e85bcea814b8a9b60540213.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001895_jpg.rf.15a4c1bc6e85bcea814b8a9b60540213.jpg
# Label: ./dataset/labels/train/000000001895_jpg.rf.15a4c1bc6e85bcea814b8a9b60540213.txt
# Processing filename: 000000004622_jpg.rf.f5a6400b0cb9a2f05ced80e921e26a89.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004622_jpg.rf.f5a6400b0cb9a2f05ced80e921e26a89.jpg
# Label: ./dataset/labels/train/000000004622_jpg.rf.f5a6400b0cb9a2f05ced80e921e26a89.txt
# Processing filename: 000000003242_jpg.rf.15ca1b78fb2b60acdc19b29df659da4e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003242_jpg.rf.15ca1b78fb2b60acdc19b29df659da4e.jpg
# Label: ./dataset/labels/train/000000003242_jpg.rf.15ca1b78fb2b60acdc19b29df659da4e.txt
# Processing filename: 000000005142_jpg.rf.15c624c0a269de259cf2da3b304f965e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005142_jpg.rf.15c624c0a269de259cf2da3b304f965e.jpg
# Label: ./dataset/labels/train/000000005142_jpg.rf.15c624c0a269de259cf2da3b304f965e.txt
# Processing filename: 000000001941_jpg.rf.f627b4ef8091563b549f3d3167babec0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001941_jpg.rf.f627b4ef8091563b549f3d3167babec0.jpg
# Label: ./dataset/labels/train/000000001941_jpg.rf.f627b4ef8091563b549f3d3167babec0.txt
# Processing filename: 000000000801_jpg.rf.9ba55575f68de72ed1a5df118073cf1b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000801_jpg.rf.9ba55575f68de72ed1a5df118073cf1b.jpg
# Label: ./dataset/labels/train/000000000801_jpg.rf.9ba55575f68de72ed1a5df118073cf1b.txt
# Processing filename: 000000003386_jpg.rf.9b818200ec2dc186d8a1b9f75091a563.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003386_jpg.rf.9b818200ec2dc186d8a1b9f75091a563.jpg
# Label: ./dataset/labels/train/000000003386_jpg.rf.9b818200ec2dc186d8a1b9f75091a563.txt
# Processing filename: 000000001558_jpg.rf.6fc3cac3667010fd985e4f0f41c1e0f3.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001558_jpg.rf.6fc3cac3667010fd985e4f0f41c1e0f3.jpg
# Label: ./dataset/labels/train/000000001558_jpg.rf.6fc3cac3667010fd985e4f0f41c1e0f3.txt
# Processing filename: 000000005336_jpg.rf.9b736fe965706f81195f20a7d9bf8380.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005336_jpg.rf.9b736fe965706f81195f20a7d9bf8380.jpg
# Label: ./dataset/labels/train/000000005336_jpg.rf.9b736fe965706f81195f20a7d9bf8380.txt
# Processing filename: 000000003837_jpg.rf.c8b8f8a32626e1b7df27eaa901bea7aa.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003837_jpg.rf.c8b8f8a32626e1b7df27eaa901bea7aa.jpg
# Label: ./dataset/labels/train/000000003837_jpg.rf.c8b8f8a32626e1b7df27eaa901bea7aa.txt
# Processing filename: 000000003003_jpg.rf.16366aa4d980a9e9fe06596761d57f9a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003003_jpg.rf.16366aa4d980a9e9fe06596761d57f9a.jpg
# Label: ./dataset/labels/train/000000003003_jpg.rf.16366aa4d980a9e9fe06596761d57f9a.txt
# Processing filename: 000000004642_jpg.rf.c925a329943eb4cc307a773e0c1714a6.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004642_jpg.rf.c925a329943eb4cc307a773e0c1714a6.jpg
# Label: ./dataset/labels/train/000000004642_jpg.rf.c925a329943eb4cc307a773e0c1714a6.txt
# Processing filename: 000000000908_jpg.rf.9bc136fa7e80d8ecae052b2555fec762.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000908_jpg.rf.9bc136fa7e80d8ecae052b2555fec762.jpg
# Label: ./dataset/labels/train/000000000908_jpg.rf.9bc136fa7e80d8ecae052b2555fec762.txt
# Processing filename: 000000001340_jpg.rf.9bef512c8b17ec75867d9a0a9361e5b8.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001340_jpg.rf.9bef512c8b17ec75867d9a0a9361e5b8.jpg
# Label: ./dataset/labels/train/000000001340_jpg.rf.9bef512c8b17ec75867d9a0a9361e5b8.txt
# Processing filename: 000000004876_jpg.rf.9bc3e85bb8c7c92d34e29e3830605132.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004876_jpg.rf.9bc3e85bb8c7c92d34e29e3830605132.jpg
# Label: ./dataset/labels/train/000000004876_jpg.rf.9bc3e85bb8c7c92d34e29e3830605132.txt
# Processing filename: 000000002624_jpg.rf.f66fef8912672a5050f26214d596d306.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002624_jpg.rf.f66fef8912672a5050f26214d596d306.jpg
# Label: ./dataset/labels/train/000000002624_jpg.rf.f66fef8912672a5050f26214d596d306.txt
# Processing filename: 000000003920_jpg.rf.f677e471ee0fe767318d25af848b78af.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003920_jpg.rf.f677e471ee0fe767318d25af848b78af.jpg
# Label: ./dataset/labels/train/000000003920_jpg.rf.f677e471ee0fe767318d25af848b78af.txt
# Processing filename: 000000005263_jpg.rf.42f5c7153347369081c69072b36c3909.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005263_jpg.rf.42f5c7153347369081c69072b36c3909.jpg
# Label: ./dataset/labels/train/000000005263_jpg.rf.42f5c7153347369081c69072b36c3909.txt
# Processing filename: 000000004984_jpg.rf.1686b9c75feb4311b866748fe28decdd.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004984_jpg.rf.1686b9c75feb4311b866748fe28decdd.jpg
# Label: ./dataset/labels/train/000000004984_jpg.rf.1686b9c75feb4311b866748fe28decdd.txt
# Processing filename: 000000004705_jpg.rf.1680f11ed3da9f27e98d2646c042025f.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004705_jpg.rf.1680f11ed3da9f27e98d2646c042025f.jpg
# Label: ./dataset/labels/train/000000004705_jpg.rf.1680f11ed3da9f27e98d2646c042025f.txt
# Processing filename: 000000001146_jpg.rf.16b6db31b180ab1d27621222735e5643.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001146_jpg.rf.16b6db31b180ab1d27621222735e5643.jpg
# Label: ./dataset/labels/train/000000001146_jpg.rf.16b6db31b180ab1d27621222735e5643.txt
# ...
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-05-12.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-05-12.txt
# Processing filename: Screenshot from 2024-10-11 11-06-18.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-06-18.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-06-18.txt
# Processing filename: Screenshot from 2024-10-11 11-06-23.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-06-23.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-06-23.txt
# Processing filename: Screenshot from 2024-10-11 11-06-44.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-06-44.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-06-44.txt
# Processing filename: Screenshot from 2024-10-11 11-06-54.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-06-54.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-06-54.txt
# Processing filename: Screenshot from 2024-10-11 11-07-20.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-07-20.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-07-20.txt
# Processing filename: Screenshot from 2024-10-11 11-07-29.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-07-29.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-07-29.txt
# Processing filename: Screenshot from 2024-10-11 11-07-54.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-07-54.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-07-54.txt
# Processing filename: Screenshot from 2024-10-11 11-09-36.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-09-36.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-09-36.txt
# Processing filename: Screenshot from 2024-10-11 11-09-52.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-09-52.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-09-52.txt
# Processing filename: Screenshot from 2024-10-11 11-10-12.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-10-12.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-10-12.txt
# Processing filename: Screenshot from 2024-10-11 11-10-23.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-10-23.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-10-23.txt
# Processing filename: Screenshot from 2024-10-11 11-10-34.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-10-34.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-10-34.txt
# Processing filename: Screenshot from 2024-10-11 11-10-44.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-10-44.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-10-44.txt
# Processing filename: Screenshot from 2024-10-11 11-10-59.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-10-59.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-10-59.txt
# Processing filename: Screenshot from 2024-10-11 11-11-14.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-11-14.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-11-14.txt
# Processing filename: Screenshot from 2024-10-11 11-11-33.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-11-33.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-11-33.txt
# Processing filename: Screenshot from 2024-10-11 11-12-32.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-12-32.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-12-32.txt
# Processing filename: Screenshot from 2024-10-11 11-12-41.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-12-41.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-12-41.txt
# Processing filename: Screenshot from 2024-10-11 11-12-56.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-12-56.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-12-56.txt
# Processing filename: Screenshot from 2024-10-11 11-13-08.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-13-08.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-13-08.txt
# Processing filename: Screenshot from 2024-10-11 11-13-17.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-13-17.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-13-17.txt
# Processing filename: Screenshot from 2024-10-11 11-15-21.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-15-21.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-15-21.txt
# Processing filename: Screenshot from 2024-10-11 11-28-36.png
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Screenshot from 2024-10-11 11-28-36.png
# Label: ./dataset/labels/train/Screenshot from 2024-10-11 11-28-36.txt
# Processing filename: 000000001813_jpg.rf.bdb2f481f90ec51a0954e5894e50eaa1.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001813_jpg.rf.bdb2f481f90ec51a0954e5894e50eaa1.jpg
# Label: ./dataset/labels/train/000000001813_jpg.rf.bdb2f481f90ec51a0954e5894e50eaa1.txt
# Processing filename: 000000000315_jpg.rf.bdb978cc93a6caf0f715642f699cbbfb.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000315_jpg.rf.bdb978cc93a6caf0f715642f699cbbfb.jpg
# Label: ./dataset/labels/train/000000000315_jpg.rf.bdb978cc93a6caf0f715642f699cbbfb.txt
# Processing filename: 000000000984_jpg.rf.909b52a57acaecdd782cec82af53253d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000984_jpg.rf.909b52a57acaecdd782cec82af53253d.jpg
# Label: ./dataset/labels/train/000000000984_jpg.rf.909b52a57acaecdd782cec82af53253d.txt
# Processing filename: 000000000731_jpg.rf.37cf59d0a75cc6249791d10677c05f5a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000731_jpg.rf.37cf59d0a75cc6249791d10677c05f5a.jpg
# Label: ./dataset/labels/train/000000000731_jpg.rf.37cf59d0a75cc6249791d10677c05f5a.txt
# Processing filename: 000000003272_jpg.rf.0ae922b5d5506a5c76282bf291ab6b6d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003272_jpg.rf.0ae922b5d5506a5c76282bf291ab6b6d.jpg
# Label: ./dataset/labels/train/000000003272_jpg.rf.0ae922b5d5506a5c76282bf291ab6b6d.txt
# Processing filename: 000000000761_jpg.rf.bdef8dd6c3edf66303a3340bb337c020.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000761_jpg.rf.bdef8dd6c3edf66303a3340bb337c020.jpg
# Label: ./dataset/labels/train/000000000761_jpg.rf.bdef8dd6c3edf66303a3340bb337c020.txt
# Processing filename: 000000002402_jpg.rf.383e543105c8d99db4ff6e6a5e66ef97.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002402_jpg.rf.383e543105c8d99db4ff6e6a5e66ef97.jpg
# Label: ./dataset/labels/train/000000002402_jpg.rf.383e543105c8d99db4ff6e6a5e66ef97.txt
# Processing filename: 000000005107_jpg.rf.eb8f9529df81d1863f8c5634f52de389.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000005107_jpg.rf.eb8f9529df81d1863f8c5634f52de389.jpg
# Label: ./dataset/labels/train/000000005107_jpg.rf.eb8f9529df81d1863f8c5634f52de389.txt
# Processing filename: 000000001799_jpg.rf.0b820ceb8520a0d493a5a36dc0bc8132.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001799_jpg.rf.0b820ceb8520a0d493a5a36dc0bc8132.jpg
# Label: ./dataset/labels/train/000000001799_jpg.rf.0b820ceb8520a0d493a5a36dc0bc8132.txt
# Processing filename: 000000001166_jpg.rf.eb8a3fd9f13bc7f67122f352f6118828.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001166_jpg.rf.eb8a3fd9f13bc7f67122f352f6118828.jpg
# Label: ./dataset/labels/train/000000001166_jpg.rf.eb8a3fd9f13bc7f67122f352f6118828.txt
# Processing filename: 000000000690_jpg.rf.eb9f8d40c1d8cf8a9b8533e015848f70.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000690_jpg.rf.eb9f8d40c1d8cf8a9b8533e015848f70.jpg
# Label: ./dataset/labels/train/000000000690_jpg.rf.eb9f8d40c1d8cf8a9b8533e015848f70.txt
# Processing filename: 000000001781_jpg.rf.0bab519a7f94ebe9d160d60a62ef8f0a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001781_jpg.rf.0bab519a7f94ebe9d160d60a62ef8f0a.jpg
# Label: ./dataset/labels/train/000000001781_jpg.rf.0bab519a7f94ebe9d160d60a62ef8f0a.txt
# Processing filename: 000000001562_jpg.rf.ebd36cfc47ab56bce434767de12ad45b.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001562_jpg.rf.ebd36cfc47ab56bce434767de12ad45b.jpg
# Label: ./dataset/labels/train/000000001562_jpg.rf.ebd36cfc47ab56bce434767de12ad45b.txt
# Processing filename: 000000004760_jpg.rf.be737ff9b9b2eb454a061b807db41347.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004760_jpg.rf.be737ff9b9b2eb454a061b807db41347.jpg
# Label: ./dataset/labels/train/000000004760_jpg.rf.be737ff9b9b2eb454a061b807db41347.txt
# Processing filename: 000000002544_jpg.rf.65a09071e350b7325de2705ccdeab35d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002544_jpg.rf.65a09071e350b7325de2705ccdeab35d.jpg
# Label: ./dataset/labels/train/000000002544_jpg.rf.65a09071e350b7325de2705ccdeab35d.txt
# Processing filename: 000000001183_jpg.rf.9166671c01605e666a0a4c7f8fe899d8.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001183_jpg.rf.9166671c01605e666a0a4c7f8fe899d8.jpg
# Label: ./dataset/labels/train/000000001183_jpg.rf.9166671c01605e666a0a4c7f8fe899d8.txt
# Processing filename: 000000003535_jpg.rf.0bbd712eebbe1564bbdb052f35bfcb96.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000003535_jpg.rf.0bbd712eebbe1564bbdb052f35bfcb96.jpg
# Label: ./dataset/labels/train/000000003535_jpg.rf.0bbd712eebbe1564bbdb052f35bfcb96.txt
# Processing filename: 000000001139_jpg.rf.38913d50dfed9c1450dae988be7045d4.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001139_jpg.rf.38913d50dfed9c1450dae988be7045d4.jpg
# Label: ./dataset/labels/train/000000001139_jpg.rf.38913d50dfed9c1450dae988be7045d4.txt
# Processing filename: 000000000250_jpg.rf.0bf9c5de161689cee94781527125c4db.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000250_jpg.rf.0bf9c5de161689cee94781527125c4db.jpg
# Label: ./dataset/labels/train/000000000250_jpg.rf.0bf9c5de161689cee94781527125c4db.txt
# Processing filename: 000000001264_jpg.rf.bed14d32dc09cb65520a2c276a15124d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001264_jpg.rf.bed14d32dc09cb65520a2c276a15124d.jpg
# Label: ./dataset/labels/train/000000001264_jpg.rf.bed14d32dc09cb65520a2c276a15124d.txt
# Processing filename: 000000004508_jpg.rf.65cfbaa4ae10ca712108937eac9e7949.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004508_jpg.rf.65cfbaa4ae10ca712108937eac9e7949.jpg
# Label: ./dataset/labels/train/000000004508_jpg.rf.65cfbaa4ae10ca712108937eac9e7949.txt
# Processing filename: 000000002178_jpg.rf.38b09b64b1a461b7bca1f7375f4cf62a.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002178_jpg.rf.38b09b64b1a461b7bca1f7375f4cf62a.jpg
# Label: ./dataset/labels/train/000000002178_jpg.rf.38b09b64b1a461b7bca1f7375f4cf62a.txt
# Processing filename: 000000004424_jpg.rf.bebe02bcb7eecc25dadf9d8e799a42a2.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004424_jpg.rf.bebe02bcb7eecc25dadf9d8e799a42a2.jpg
# Label: ./dataset/labels/train/000000004424_jpg.rf.bebe02bcb7eecc25dadf9d8e799a42a2.txt
# Processing filename: 000000004130_jpg.rf.bf213bf1c730e177858e78fd58334570.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004130_jpg.rf.bf213bf1c730e177858e78fd58334570.jpg
# Label: ./dataset/labels/train/000000004130_jpg.rf.bf213bf1c730e177858e78fd58334570.txt
# Processing filename: 000000000839_jpg.rf.0c470f50bd85093b9551d58d49d10434.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000839_jpg.rf.0c470f50bd85093b9551d58d49d10434.jpg
# Label: ./dataset/labels/train/000000000839_jpg.rf.0c470f50bd85093b9551d58d49d10434.txt
# Processing filename: 000000000723_jpg.rf.9200f27d68dfe916798dcb0aaaded93e.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000723_jpg.rf.9200f27d68dfe916798dcb0aaaded93e.jpg
# Label: ./dataset/labels/train/000000000723_jpg.rf.9200f27d68dfe916798dcb0aaaded93e.txt
# Processing filename: 000000000722_jpg.rf.ec400c3571c1cbb1b1794af001d806a5.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000722_jpg.rf.ec400c3571c1cbb1b1794af001d806a5.jpg
# Label: ./dataset/labels/train/000000000722_jpg.rf.ec400c3571c1cbb1b1794af001d806a5.txt
# Processing filename: 000000000395_jpg.rf.662d1159a86b0dcd834bcd6483c02368.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000395_jpg.rf.662d1159a86b0dcd834bcd6483c02368.jpg
# Label: ./dataset/labels/train/000000000395_jpg.rf.662d1159a86b0dcd834bcd6483c02368.txt
# Processing filename: 000000002154_jpg.rf.39234664e29c23308ac3dc2d02c62d81.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002154_jpg.rf.39234664e29c23308ac3dc2d02c62d81.jpg
# Label: ./dataset/labels/train/000000002154_jpg.rf.39234664e29c23308ac3dc2d02c62d81.txt
# Processing filename: 000000000757_jpg.rf.0c4c0248799a5ade7615e690e46f6352.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000757_jpg.rf.0c4c0248799a5ade7615e690e46f6352.jpg
# Label: ./dataset/labels/train/000000000757_jpg.rf.0c4c0248799a5ade7615e690e46f6352.txt
# Processing filename: 000000000781_jpg.rf.ecb32a0a9b42cb322753092f8e35ae84.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000000781_jpg.rf.ecb32a0a9b42cb322753092f8e35ae84.jpg
# Label: ./dataset/labels/train/000000000781_jpg.rf.ecb32a0a9b42cb322753092f8e35ae84.txt
# Processing filename: 000000002621_jpg.rf.ecfdcd15f1ee60b16b448331a0e563d5.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002621_jpg.rf.ecfdcd15f1ee60b16b448331a0e563d5.jpg
# Label: ./dataset/labels/train/000000002621_jpg.rf.ecfdcd15f1ee60b16b448331a0e563d5.txt
# Processing filename: 000000004688_jpg.rf.0cc48c60714388d0abad8fc597e731f4.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004688_jpg.rf.0cc48c60714388d0abad8fc597e731f4.jpg
# Label: ./dataset/labels/train/000000004688_jpg.rf.0cc48c60714388d0abad8fc597e731f4.txt
# Processing filename: 000000004173_jpg.rf.0cca545bb264648ff23aa008562744b7.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000004173_jpg.rf.0cca545bb264648ff23aa008562744b7.jpg
# Label: ./dataset/labels/train/000000004173_jpg.rf.0cca545bb264648ff23aa008562744b7.txt
# Processing filename: 000000002270_jpg.rf.66ee19da24a1d3d9853e13350abf228d.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000002270_jpg.rf.66ee19da24a1d3d9853e13350abf228d.jpg
# Label: ./dataset/labels/train/000000002270_jpg.rf.66ee19da24a1d3d9853e13350abf228d.txt
# Found 0 image-label pairs.

# %%
import yaml
import os
import torch.utils.data as data
from utils.datasetClass import *


# get params from yaml file
with open('utils/args.yaml', errors='ignore') as f:
    params_dict = yaml.safe_load(f)  # Store original params in params_dict

# Access label names using params_dict
params_names = params_dict["names"]
# **Check if 'mosaic' key exists and handle it**
if 'mosaic' not in params_dict:
    # If 'mosaic' key is missing, set it to a default value (e.g., False)
    params_dict['mosaic'] = False  # Or any other default value you prefer
    print("Warning: 'mosaic' key not found in YAML. Setting it to False.")

labelnames = []
imagenames = []
image_label_pairs = images_labels
#print(f"Image-label pairs: {image_label_pairs}")  # Print the output of setNewPath

# Check if image_label_pairs is empty and handle the case
if not image_label_pairs:
    print("Error: No image-label pairs found. Check data_dir and setNewPath function.")
    # You might want to raise an exception here to stop execution
    raise ValueError("No image-label pairs found.") # Raise a ValueError to halt execution
else:
    for image_path, label_path in image_label_pairs:
        labelnames.append(label_path)
        imagenames.append(image_path)

print(f"Number of image names: {len(imagenames)}")
print(f"Number of label names: {len(labelnames)}")
input_size = 640
# Ensure that 'filenames' is being correctly assigned within your Mydataset class
train_data = Dataset(input_size=input_size, params=params_dict, augment=False, filenames=imagenames)
# Assuming 'filenames' is an attribute of Mydataset, make sure it's initialized

# Print the value of train_data.filenames to check if it's empty  -- Changed from train_datas to train_data
print(f"train_data.filenames: {train_data.filenames}")

# Check if the 'filenames' attribute of train_data is empty -- Changed from train_datas to train_data
if not train_data.filenames:
    print("Error: 'filenames' in train_data is empty. Check setNewPath or Dataset initialization.")
    # This will help pinpoint if the issue is with the file paths themselves
    # Print the first few elements of 'imagenames' for debugging
    print(f"First few imagenames: {imagenames[:5]}")  # Print first 5 for brevity
    raise ValueError("'filenames' in train_data is empty")

# Check if train_data has any samples before creating DataLoader -- Changed from train_datas to train_data
if len(train_data) == 0:
    print("Error: train_data is empty. Check your Dataset implementation.")
    # Consider raising an exception or fixing the Mydataset class
    raise ValueError("train_data is empty") # Raise a ValueError to halt execution if the dataset is empty
else:
    train_loader = data.DataLoader(train_data, batch_size=64, shuffle=True, num_workers=0, pin_memory=True, collate_fn=Dataset.collate_fn)
    print(f"Train_loader : {len(train_loader)} batches")
# Out:
# Error: No image-label pairs found. Check data_dir and setNewPath function.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 28
#      26     print("Error: No image-label pairs found. Check data_dir and setNewPath function.")
#      27     # You might want to raise an exception here to stop execution
# ---> 28     raise ValueError("No image-label pairs found.") # Raise a ValueError to halt execution
#      29 else:
#      30     for image_path, label_path in image_label_pairs:
#
# ValueError: No image-label pairs found.

# %%
import yaml
from utils.dataset import *
from torch.utils import data

# get all file names
data_dir= 'coco'
filenames_train = []
with open(f'{data_dir}/train2017.txt') as reader:
    for filename in reader.readlines():
        filename = os.path.basename(filename.rstrip())
        filenames_train.append(f'{data_dir}/images/train2017/' + filename)

# input_size for the model
input_size=640

# get params from yaml file
with open('utils/args.yaml', errors='ignore') as f:
        params = yaml.safe_load(f)

train_data=Dataset(filenames_train,input_size,params,augment=True)
train_loader = data.DataLoader(train_data, batch_size=64, num_workers=0, pin_memory=True, collate_fn=Dataset.collate_fn)
print(f"Train_loader : {len(train_loader)} batches")
# Out:
# Train_loader : 1849 batches

# %%
batch=next(iter(train_loader))
print("All keys in batch      : ", batch[1].keys())
print(f"Input batch shape      : ", batch[0].shape)
print(f"Classification scores  : {batch[1]['cls'].shape}")
print(f"Box coordinates        : {batch[1]['box'].shape}")
print(f"Index identifier (which score belongs to which image): {batch[1]['idx'].shape}")
# Out:
# [ WARN:0@181.193] global loadsave.cpp:241 findDecoder imread_('coco/images/train2017/000000211830.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 batch=next(iter(train_loader))
#       2 print("All keys in batch      : ", batch[1].keys())
#       3 print(f"Input batch shape      : ", batch[0].shape)
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/yolov8_detection/utils/dataset.py:38, in Dataset.__getitem__(self, index)
#      34 mosaic = self.mosaic and random.random() < params['mosaic']
#      36 if mosaic:
#      37     # Load MOSAIC
# ---> 38     image, label = self.load_mosaic(index, params)
#      39     # MixUp augmentation
#      40     if random.random() < params['mix_up']:
#
# File ~/Documents/yolov8_detection/utils/dataset.py:122, in Dataset.load_mosaic(self, index, params)
#     118 random.shuffle(indices)
#     120 for i, index in enumerate(indices):
#     121     # Load image
# --> 122     image, _ = self.load_image(index)
#     123     shape = image.shape
#     124     if i == 0:  # top left
#
# File ~/Documents/yolov8_detection/utils/dataset.py:100, in Dataset.load_image(self, i)
#      98 def load_image(self, i):
#      99     image = cv2.imread(self.filenames[i])
# --> 100     h, w = image.shape[:2]
#     101     r = self.input_size / max(h, w)
#     102     if r != 1:
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
from utils import util
torch.manual_seed(1337)

# model, loss and optimizer
model=MyYolo(version='n')
print(f"{sum(p.numel() for p in model.parameters())/1e6} million parameters")

criterion=util.ComputeLoss(model, params)
optimizer=torch.optim.AdamW(model.parameters(), lr=0.5)

num_epochs=5

imgs,targets=batch[0],batch[1]
imgs=imgs.float()
model.train()
for epoch in range(num_epochs):
    outputs=model(imgs)
    loss=sum(criterion(outputs,targets)) # cls_loss+box_loss+dfl_loss
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(f"Epoch : {epoch} | loss : {loss.item()}")
# Out:
# 3.1572 million parameters
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch : 0 | loss : 15265294.0
# Epoch : 1 | loss : 2260031.0
# Epoch : 2 | loss : 1407.5379638671875
# Epoch : 3 | loss : 0.0
# Epoch : 4 | loss : 0.0
