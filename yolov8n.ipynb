# %% [markdown]
# ### References
# The codes in this notebook use reference from the following sources
# 1. https://github.com/jahongir7174/YOLOv8-dfl/tree/master
# 2. https://arxiv.org/html/2304.00501v6/#S16
# 3. https://github.com/ultralytics/ultralytics/tree/main/ultralytics/models/yolo

# %%
# import
import math, os, random, cv2, numpy, torch
import torch.nn as nn
from ultralytics import YOLO

# explore the original yolov8 model

# original yolov8n
model_n=YOLO('yolov8n.pt')
print(f"yolov8-nano: {sum(p.numel() for p in model_n.parameters())/1e6} million parameters")


# model_s=YOLO('yolov8s.pt')
# print(f"yolov8-small: {sum(p.numel() for p in model_s.parameters())/1e6} million parameters")

print(model_n.model)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.7MB/s]
# yolov8-nano: 3.1572 million parameters
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (3): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (4): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (5): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (6): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (7): Conv(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (8): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (9): SPPF(
#       (cv1): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (10): Upsample(scale_factor=2.0, mode='nearest')
#     (11): Concat()
#     (12): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (13): Upsample(scale_factor=2.0, mode='nearest')
#     (14): Concat()
#     (15): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (16): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (17): Concat()
#     (18): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (19): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (20): Concat()
#     (21): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (22): Detect(
#       (cv2): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (cv3): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Conv(
#             (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (dfl): DFL(
#         (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
# )

# %% [markdown]
# ## Yolov8 architecture
# The overall architecture is BackBone + Neck + Head
#
# <center>
# <img src="yolov8_architecture.png" width="700" height="700">

# %% [markdown]
# ## 1. Backbone
# The backbone is modified CSPDarknet53 which comprises of blocks Conv, C2f, SPPF
# 1. **Conv**: Conv2d + BatchNorm2d + SiLU
# 2. **C2f (cross-stage partial bottleneck with 2 convolutions)**: Conv + Bottlenecks + Conv <br>
# Combine high-level features with contextual information to improve detection accuracy.
# 3. **SPPF (spatial pyramid pooling fast)**: Conv + Maxpool2d + Conv <br>
# Process features at various scales and pool them into a fixed-size feature map.

# %% [markdown]
# ### (a) Conv

# %%
class Conv(nn.Module):
    def __init__(self,in_channels, out_channels,kernel_size=3,stride=1,padding=1,groups=1,activation=True):
        super().__init__()
        self.conv=nn.Conv2d(in_channels,out_channels,kernel_size,stride,padding,bias=False,groups=groups)
        self.bn=nn.BatchNorm2d(out_channels,eps=0.001,momentum=0.03)
        self.act=nn.SiLU(inplace=True) if activation else nn.Identity()

    def forward(self,x):
        return self.act(self.bn(self.conv(x)))

# %% [markdown]
# ### (b) C2f

# %%
# 2.1 Bottleneck: staack of 2 COnv with shortcut connnection (True/False)
class Bottleneck(nn.Module):
    def __init__(self,in_channels,out_channels,shortcut=True):
        super().__init__()
        self.conv1=Conv(in_channels,out_channels,kernel_size=3,stride=1,padding=1)
        self.conv2=Conv(out_channels,out_channels,kernel_size=3,stride=1,padding=1)
        self.shortcut=shortcut

    def forward(self,x):
        x_in=x # for residual connection
        x=self.conv1(x)
        x=self.conv2(x)
        if self.shortcut:
            x=x+x_in
        return x
    
# 2.2 C2f: Conv + bottleneck*N+ Conv
class C2f(nn.Module):
    def __init__(self,in_channels,out_channels, num_bottlenecks,shortcut=True):
        super().__init__()
        
        self.mid_channels=out_channels//2
        self.num_bottlenecks=num_bottlenecks

        self.conv1=Conv(in_channels,out_channels,kernel_size=1,stride=1,padding=0)
        
        # sequence of bottleneck layers
        self.m=nn.ModuleList([Bottleneck(self.mid_channels,self.mid_channels) for _ in range(num_bottlenecks)])

        self.conv2=Conv((num_bottlenecks+2)*out_channels//2,out_channels,kernel_size=1,stride=1,padding=0)
    
    def forward(self,x):
        x=self.conv1(x)

        # split x along channel dimension
        x1,x2=x[:,:x.shape[1]//2,:,:], x[:,x.shape[1]//2:,:,:]
        
        # list of outputs
        outputs=[x1,x2] # x1 is fed through the bottlenecks

        for i in range(self.num_bottlenecks):
            x1=self.m[i](x1)    # [bs,0.5c_out,w,h]
            outputs.insert(0,x1)

        outputs=torch.cat(outputs,dim=1) # [bs,0.5c_out(num_bottlenecks+2),w,h]
        out=self.conv2(outputs)

        return out
         
# sanity check
c2f=C2f(in_channels=64,out_channels=128,num_bottlenecks=2)
print(f"{sum(p.numel() for p in c2f.parameters())/1e6} million parameters")

dummy_input=torch.rand((1,64,244,244))
dummy_input=c2f(dummy_input)
print("Output shape: ", dummy_input.shape)
# Out:
# 0.18944 million parameters
# Output shape:  torch.Size([1, 128, 244, 244])

# %% [markdown]
# ### (c) SPPF

# %%
class SPPF(nn.Module):
    def __init__(self,in_channels,out_channels,kernel_size=5):
        #kernel_size= size of maxpool
        super().__init__()
        hidden_channels=in_channels//2
        self.conv1=Conv(in_channels,hidden_channels,kernel_size=1,stride=1,padding=0)
        # concatenate outputs of maxpool and feed to conv2
        self.conv2=Conv(4*hidden_channels,out_channels,kernel_size=1,stride=1,padding=0)

        # maxpool is applied at 3 different sacles
        self.m=nn.MaxPool2d(kernel_size=kernel_size,stride=1,padding=kernel_size//2,dilation=1,ceil_mode=False)
    
    def forward(self,x):
        x=self.conv1(x)

        # apply maxpooling at diffent scales
        y1=self.m(x)
        y2=self.m(y1)
        y3=self.m(y2)

        # concantenate 
        y=torch.cat([x,y1,y2,y3],dim=1)

        # final conv
        y=self.conv2(y)

        return y

# sanity check
sppf=SPPF(in_channels=128,out_channels=512)
print(f"{sum(p.numel() for p in sppf.parameters())/1e6} million parameters")

dummy_input=sppf(dummy_input)
print("Output shape: ", dummy_input.shape)
# Out:
# 0.140416 million parameters
# Output shape:  torch.Size([1, 512, 244, 244])

# %% [markdown]
# ### Putting things together

# %%
# backbone = DarkNet53

# return d,w,r based on version
def yolo_params(version):
    if version=='n':
        return 1/3,1/4,2.0
    elif version=='s':
        return 1/3,1/2,2.0
    elif version=='m':
        return 2/3,3/4,1.5
    elif version=='l':
        return 1.0,1.0,1.0
    elif version=='x':
        return 1.0,1.25,1.0
    
class Backbone(nn.Module):
    def __init__(self,version,in_channels=3,shortcut=True):
        super().__init__()
        d,w,r=yolo_params(version)

        # conv layers
        self.conv_0=Conv(in_channels,int(64*w),kernel_size=3,stride=2,padding=1)
        self.conv_1=Conv(int(64*w),int(128*w),kernel_size=3,stride=2,padding=1)
        self.conv_3=Conv(int(128*w),int(256*w),kernel_size=3,stride=2,padding=1)
        self.conv_5=Conv(int(256*w),int(512*w),kernel_size=3,stride=2,padding=1)
        self.conv_7=Conv(int(512*w),int(512*w*r),kernel_size=3,stride=2,padding=1)

        # c2f layers
        self.c2f_2=C2f(int(128*w),int(128*w),num_bottlenecks=int(3*d),shortcut=True)
        self.c2f_4=C2f(int(256*w),int(256*w),num_bottlenecks=int(6*d),shortcut=True)
        self.c2f_6=C2f(int(512*w),int(512*w),num_bottlenecks=int(6*d),shortcut=True)
        self.c2f_8=C2f(int(512*w*r),int(512*w*r),num_bottlenecks=int(3*d),shortcut=True)

        # sppf
        self.sppf=SPPF(int(512*w*r),int(512*w*r))
    
    def forward(self,x):
        x=self.conv_0(x)
        x=self.conv_1(x)

        x=self.c2f_2(x)

        x=self.conv_3(x)

        out1=self.c2f_4(x) # keep for output

        x=self.conv_5(out1)

        out2=self.c2f_6(x) # keep for output

        x=self.conv_7(out2)
        x=self.c2f_8(x)
        out3=self.sppf(x)

        return out1,out2,out3

print("----Nano model -----")
backbone_n=Backbone(version='n')
print(f"{sum(p.numel() for p in backbone_n.parameters())/1e6} million parameters")

print("----Small model -----")
backbone_s=Backbone(version='s')
print(f"{sum(p.numel() for p in backbone_s.parameters())/1e6} million parameters")
# Out:
# ----Nano model -----
# 1.272656 million parameters
# ----Small model -----
# 5.079712 million parameters

# %%
# sanity check
x=torch.rand((1,3,640,640))
out1,out2,out3=backbone_n(x)
print(out1.shape)
print(out2.shape)
print(out3.shape)
# Out:
# torch.Size([1, 64, 80, 80])
# torch.Size([1, 128, 40, 40])
# torch.Size([1, 256, 20, 20])

# %% [markdown]
# ## 2. Neck
# The neck comprises of Upsample + C2f with
#
# **Upsample** = nearest-neighbor interpolation with scale_factor=2. It doesn't have trainable paramaters.

# %%
# upsample = nearest-neighbor interpolation with scale_factor=2
#            doesn't have trainable paramaters
class Upsample(nn.Module):
    def __init__(self,scale_factor=2,mode='nearest'):
        super().__init__()
        self.scale_factor=scale_factor
        self.mode=mode

    def forward(self,x):
        return nn.functional.interpolate(x,scale_factor=self.scale_factor,mode=self.mode)

# %%
class Neck(nn.Module):
    def __init__(self,version):
        super().__init__()
        d,w,r=yolo_params(version)

        self.up=Upsample() # no trainable parameters
        self.c2f_1=C2f(in_channels=int(512*w*(1+r)), out_channels=int(512*w),num_bottlenecks=int(3*d),shortcut=False)
        self.c2f_2=C2f(in_channels=int(768*w), out_channels=int(256*w),num_bottlenecks=int(3*d),shortcut=False)
        self.c2f_3=C2f(in_channels=int(768*w), out_channels=int(512*w),num_bottlenecks=int(3*d),shortcut=False)
        self.c2f_4=C2f(in_channels=int(512*w*(1+r)), out_channels=int(512*w*r),num_bottlenecks=int(3*d),shortcut=False)

        self.cv_1=Conv(in_channels=int(256*w),out_channels=int(256*w),kernel_size=3,stride=2, padding=1)
        self.cv_2=Conv(in_channels=int(512*w),out_channels=int(512*w),kernel_size=3,stride=2, padding=1)


    def forward(self,x_res_1,x_res_2,x):    
        # x_res_1,x_res_2,x = output of backbone
        res_1=x              # for residual connection
        
        x=self.up(x)
        x=torch.cat([x,x_res_2],dim=1)

        res_2=self.c2f_1(x)  # for residual connection
        
        x=self.up(res_2)
        x=torch.cat([x,x_res_1],dim=1)

        out_1=self.c2f_2(x)

        x=self.cv_1(out_1)

        x=torch.cat([x,res_2],dim=1)
        out_2=self.c2f_3(x)

        x=self.cv_2(out_2)

        x=torch.cat([x,res_1],dim=1)
        out_3=self.c2f_4(x)

        return out_1,out_2,out_3
    
# sanity check
neck=Neck(version='n')
print(f"{sum(p.numel() for p in neck.parameters())/1e6} million parameters")

x=torch.rand((1,3,640,640))
out1,out2,out3=Backbone(version='n')(x)
out_1,out_2,out_3=neck(out1,out2,out3)
print(out_1.shape)
print(out_2.shape)
print(out_3.shape)
# Out:
# 0.98688 million parameters
# torch.Size([1, 64, 80, 80])
# torch.Size([1, 128, 40, 40])
# torch.Size([1, 256, 20, 20])

# %% [markdown]
# ## 3. Head
# Consist of 3 modules: (1) bbox coordinates, (2) classification scores, (3) distribution focal loss (DFL).
#
# **DFL** considers the predicted bbox coordinates as a probability distribution. At inference time, it samples from the distribution to get **refined coordinates** $(x,y,w,h)$. For example, to predict coordinate $x$ in the normalized range $[0,1]$:
# 1. DFL uses 16 bins which are equally spaced in $[0,1]$, bin length = 1/16.
# 2. The model outputs 16 numbers which corresponds to probabilities that x falls in these bins, for example, $[0,0,...,9/10,1/10]$.
# 3. Prediction for $x=$ mean value $= 9/10\cdot15/16+1/10\cdot 1=0.94375$

# %% [markdown]
# ### (a) DFL

# %%
# DFL
class DFL(nn.Module):
    def __init__(self,ch=16):
        super().__init__()
        
        self.ch=ch
        
        self.conv=nn.Conv2d(in_channels=ch,out_channels=1,kernel_size=1,bias=False).requires_grad_(False)
        
        # initialize conv with [0,...,ch-1]
        x=torch.arange(ch,dtype=torch.float).view(1,ch,1,1)
        self.conv.weight.data[:]=torch.nn.Parameter(x) # DFL only has ch parameters

    def forward(self,x):
        # x must have num_channels = 4*ch: x=[bs,4*ch,c]
        b,c,a=x.shape                           # c=4*ch
        x=x.view(b,4,self.ch,a).transpose(1,2)  # [bs,ch,4,a]

        # take softmax on channel dimension to get distribution probabilities
        x=x.softmax(1)                          # [b,ch,4,a]
        x=self.conv(x)                          # [b,1,4,a]
        return x.view(b,4,a)                    # [b,4,a]

# sanity check
dummy_input=torch.rand((1,64,128))
dfl=DFL()
print(f"{sum(p.numel() for p in dfl.parameters())} parameters")

dummy_output=dfl(dummy_input)
print(dummy_output.shape)

print(dfl)
# Out:
# 16 parameters
# torch.Size([1, 4, 128])
# DFL(
#   (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
# )

# %% [markdown]
# ### (b) Head

# %%
class Head(nn.Module):
    def __init__(self,version,ch=16,num_classes=80):

        super().__init__()
        self.ch=ch                          # dfl channels
        self.coordinates=self.ch*4          # number of bounding box coordinates 
        self.nc=num_classes                 # 80 for COCO
        self.no=self.coordinates+self.nc    # number of outputs per anchor box

        self.stride=torch.zeros(3)          # strides computed during build
        
        d,w,r=yolo_params(version=version)
        
        # for bounding boxes
        self.box=nn.ModuleList([
            nn.Sequential(Conv(int(256*w),self.coordinates,kernel_size=3,stride=1,padding=1),
                          Conv(self.coordinates,self.coordinates,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.coordinates,self.coordinates,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w),self.coordinates,kernel_size=3,stride=1,padding=1),
                          Conv(self.coordinates,self.coordinates,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.coordinates,self.coordinates,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w*r),self.coordinates,kernel_size=3,stride=1,padding=1),
                          Conv(self.coordinates,self.coordinates,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.coordinates,self.coordinates,kernel_size=1,stride=1))
        ])

        # for classification
        self.cls=nn.ModuleList([
            nn.Sequential(Conv(int(256*w),self.nc,kernel_size=3,stride=1,padding=1),
                          Conv(self.nc,self.nc,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.nc,self.nc,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w),self.nc,kernel_size=3,stride=1,padding=1),
                          Conv(self.nc,self.nc,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.nc,self.nc,kernel_size=1,stride=1)),

            nn.Sequential(Conv(int(512*w*r),self.nc,kernel_size=3,stride=1,padding=1),
                          Conv(self.nc,self.nc,kernel_size=3,stride=1,padding=1),
                          nn.Conv2d(self.nc,self.nc,kernel_size=1,stride=1))
        ])

        # dfl
        self.dfl=DFL()

    def forward(self,x):
        # x = output of Neck = list of 3 tensors with different resolution and different channel dim
        #     x[0]=[bs, ch0, w0, h0], x[1]=[bs, ch1, w1, h1], x[2]=[bs,ch2, w2, h2] 

        for i in range(len(self.box)):       # detection head i
            box=self.box[i](x[i])            # [bs,num_coordinates,w,h]
            cls=self.cls[i](x[i])            # [bs,num_classes,w,h]
            x[i]=torch.cat((box,cls),dim=1)  # [bs,num_coordinates+num_classes,w,h]

        # in training, no dfl output
        if self.training:
            return x                         # [3,bs,num_coordinates+num_classes,w,h]
        
        # in inference time, dfl produces refined bounding box coordinates
        anchors, strides = (i.transpose(0, 1) for i in self.make_anchors(x, self.stride))

        # concatenate predictions from all detection layers
        x = torch.cat([i.view(x[0].shape[0], self.no, -1) for i in x], dim=2) #[bs, 4*self.ch + self.nc, sum_i(h[i]w[i])]
        
        # split out predictions for box and cls
        #           box=[bs,4×self.ch,sum_i(h[i]w[i])]
        #           cls=[bs,self.nc,sum_i(h[i]w[i])]
        box, cls = x.split(split_size=(4 * self.ch, self.nc), dim=1)


        a, b = self.dfl(box).chunk(2, 1)  # a=b=[bs,2×self.ch,sum_i(h[i]w[i])]
        a = anchors.unsqueeze(0) - a
        b = anchors.unsqueeze(0) + b
        box = torch.cat(tensors=((a + b) / 2, b - a), dim=1)
        
        return torch.cat(tensors=(box * strides, cls.sigmoid()), dim=1)


    def make_anchors(self, x, strides, offset=0.5):
        # x= list of feature maps: x=[x[0],...,x[N-1]], in our case N= num_detection_heads=3
        #                          each having shape [bs,ch,w,h]
        #    each feature map x[i] gives output[i] = w*h anchor coordinates + w*h stride values
        
        # strides = list of stride values indicating how much 
        #           the spatial resolution of the feature map is reduced compared to the original image

        assert x is not None
        anchor_tensor, stride_tensor = [], []
        dtype, device = x[0].dtype, x[0].device
        for i, stride in enumerate(strides):
            _, _, h, w = x[i].shape
            sx = torch.arange(end=w, device=device, dtype=dtype) + offset  # x coordinates of anchor centers
            sy = torch.arange(end=h, device=device, dtype=dtype) + offset  # y coordinates of anchor centers
            sy, sx = torch.meshgrid(sy, sx)                                # all anchor centers 
            anchor_tensor.append(torch.stack((sx, sy), -1).view(-1, 2))
            stride_tensor.append(torch.full((h * w, 1), stride, dtype=dtype, device=device))
        return torch.cat(anchor_tensor), torch.cat(stride_tensor)

# %%
detect=Head(version='n')
print(f"{sum(p.numel() for p in detect.parameters())/1e6} million parameters")

# out_1,out_2,out_3 are output of the neck
output=detect([out_1,out_2,out_3])
print(output[0].shape)
print(output[1].shape)
print(output[2].shape)

print(detect)
# Out:
# 0.897664 million parameters
# torch.Size([1, 144, 80, 80])
# torch.Size([1, 144, 40, 40])
# torch.Size([1, 144, 20, 20])
# Head(
#   (box): ModuleList(
#     (0): Sequential(
#       (0): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv(
#         (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Sequential(
#       (0): Conv(
#         (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (cls): ModuleList(
#     (0): Sequential(
#       (0): Conv(
#         (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv(
#         (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Sequential(
#       (0): Conv(
#         (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (dfl): DFL(
#     (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ## 4. Putting everything together

# %%
class MyYolo(nn.Module):
    def __init__(self,version):
        super().__init__()
        self.backbone=Backbone(version=version)
        self.neck=Neck(version=version)
        self.head=Head(version=version)

    def forward(self,x):
        x=self.backbone(x)              # return out1,out2,out3
        x=self.neck(x[0],x[1],x[2])     # return out_1, out_2,out_3
        return self.head(list(x))
    
model=MyYolo(version='n')
print(f"{sum(p.numel() for p in model.parameters())/1e6} million parameters")
print(model)
# Out:
# 3.1572 million parameters
# MyYolo(
#   (backbone): Backbone(
#     (conv_0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_3): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_5): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (conv_7): Conv(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (c2f_2): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_4): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_6): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_8): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (sppf): SPPF(
#       (conv1): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#   )
#   (neck): Neck(
#     (up): Upsample()
#     (c2f_1): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_2): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_3): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (c2f_4): C2f(
#       (conv1): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (conv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#       (conv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv_1): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv_2): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (head): Head(
#     (box): ModuleList(
#       (0): Sequential(
#         (0): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv(
#           (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (cls): ModuleList(
#       (0): Sequential(
#         (0): Conv(
#           (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): Sequential(
#         (0): Conv(
#           (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Sequential(
#         (0): Conv(
#           (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (dfl): DFL(
#       (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 5. Dataset and Train
# Due to computation constraint, we will only overfit 1 batch of data from YOLO2017. The loss in yolov8 consists  (1) box_loss, (2) classification_loss, (3) dfl_loss
# 1. **Box loss**: on bounding box coordinates
# 2. **Classification loss**: on classification logits
# 3. **DFL_Loss**: itegrated in box loss
#
# **How DFL loss works?**
# 1. Target distribution = single value over 16 bins, this value will be smooth between 2 bin centers. For example, if target value is in the middle of bin 1 and 2, target distribution $= [1/2,1/2,0,...,0]$
# 2. Predicted distribution is based on the output of bbox coordinates. These outputs can be used to compute the probabilities for each bin, say $[1/16,1/16,...,1/16]$
# 3. DFL = cross entropy between prediction and target
#
# The utils file for computing loss is taken from https://github.com/jahongir7174/YOLOv8-dfl/tree/master

# %%
import google
# Or specific modules within the namespace:
from google.colab import drive
drive.mount('/content/drive')
# !ln -s /content/drive/My\ Drive/ /mydrive
# !ls /mydrive
#
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import google
#       2 # Or specific modules within the namespace:
#       3 from google.colab import drive
#
# ModuleNotFoundError: No module named 'google'

# %%
def setNewPath(data_dir='./'):
    data_dir = data_dir
    # Initialize a list to store image and label file paths as tuples
    image_label_pairs = []
    # ... (rest of your code to get image file paths)
    # construct the full path to the file
    train2024_txt_path = os.path.join(data_dir, 'dset_train2024.txt')
    # check if the file exists, if not print an error message and exit
    if not os.path.exists(train2024_txt_path):
        print(f"Error: File not found: {train2024_txt_path}")
        # If necessary raise an exception or handle the error differently
        # raise FileNotFoundError(f"File not found: {train2017_txt_path}")
        exit()

    print(f"data_dir: {data_dir}")
    print(f"train2024_txt_path: {train2024_txt_path}")

    with open(train2024_txt_path, 'r') as reader:
      # Assuming label files are in a 'labels' subdirectory
      for filename in reader.readlines():
          filename = os.path.basename(filename.rstrip())

          # Debug: Print the filename to see what's being read
          print(f"Processing filename: {filename}")


          image_path = f'{data_dir}dataset/images/train/' + filename
          label_path = f'{data_dir}dataset/labels/train/' + filename.replace('.jpg', '.txt').replace('.png', '.txt').replace('.jpeg', '.txt')

          #print(f"image_path: {image_path}")
          #print(f"label_path: {label_path}")
           # Debug: Check if the image and label files exist
          if os.path.exists(image_path) and os.path.exists(label_path):
            image_label_pairs.append((image_path, label_path))
          else:
            print(f"Warning: Image or label file not found:\nImage: {image_path}\nLabel: {label_path}")
    print(f"Found {len(image_label_pairs)} image-label pairs.") # Print the length
    return image_label_pairs

# %%
images_labels = setNewPath(data_dir='./')
#print(images_labels)
# Out:
# data_dir: ./
# train2024_txt_path: ./dset_train2024.txt
# Processing filename: 000000001591_jpg.rf.6707cd1cdfcde959a680bbeae4d360a0.jpg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/000000001591_jpg.rf.6707cd1cdfcde959a680bbeae4d360a0.jpg
# Label: ./dataset/labels/train/000000001591_jpg.rf.6707cd1cdfcde959a680bbeae4d360a0.txt
# Processing filename: 000000005340_jpg.rf.930ac45b0b9e7103562167dc8e408e1b.jpg
# Processing filename: 000000004244_jpg.rf.672775c4b8cf6a8d540dbb51f307e443.jpg
# Processing filename: 000000004282_jpg.rf.0d469aaa6297b76cfa848b651b54ee27.jpg
# Processing filename: 000000002495_jpg.rf.92f50e5a3159158ec187f12bc44946ec.jpg
# Processing filename: 000000002434_jpg.rf.675090866b8f1963557c442172004fc0.jpg
# Processing filename: 000000000241_jpg.rf.0dcbc0cbe7c97f092fa56eb357454ab0.jpg
# Processing filename: 000000004386_jpg.rf.6751aa49279db3e6fdec92e23883142d.jpg
# Processing filename: 000000001774_jpg.rf.c03def0de042681cb75c9809196c1185.jpg
# Processing filename: 000000005154_jpg.rf.3a54bcd90ded80c23814a7774a3168d8.jpg
# Processing filename: 000000005180_jpg.rf.3a809a4d32cdfdf4b8178d2f59d6d5c0.jpg
# Processing filename: 000000002759_jpg.rf.c0a3dee4098564eac8092c6bad4302f1.jpg
# Processing filename: 000000001522_jpg.rf.3a8c0c81b918a3071981e79484eafa3c.jpg
# Processing filename: 000000000699_jpg.rf.67a8c76d738a9e1111acd34b5f685efe.jpg
# Processing filename: 000000000897_jpg.rf.6777908a16c4f75cbb4fb7cb5b198c36.jpg
# Processing filename: 000000005394_jpg.rf.ee0eddf483df75f35628ab3bc9a1bcad.jpg
# Processing filename: 000000001554_jpg.rf.67acc5ee43e961d100b956d50a1b947e.jpg
# Processing filename: 000000004157_jpg.rf.ee5e47170e7585421fac70223a1e3295.jpg
# Processing filename: 000000002555_jpg.rf.0e23195b581858e5673e7f95aa3de415.jpg
# Processing filename: 000000001739_jpg.rf.3a9e43306052bfa6af273b13bf14b6d5.jpg
# Processing filename: 000000000828_jpg.rf.93e4a8c6b56ac879a30103dd6f433874.jpg
# Processing filename: 000000001360_jpg.rf.93fb98149b84679542d39f394139ab56.jpg
# Processing filename: 000000002752_jpg.rf.ee747ec531edbbe5856cfd6240737eb0.jpg
# Processing filename: 000000003935_jpg.rf.94112bfcfd0044af0d3af4c753cdae35.jpg
# Processing filename: 000000000531_jpg.rf.ee9d89e649144b7d9bb0172001c7c77c.jpg
# Processing filename: 000000002782_jpg.rf.3b1797cd25dd1a3afb838fe4b232cb84.jpg
# Processing filename: 000000000061_jpg.rf.eeaf447e1d2e603c13a451bdbaadf6cd.jpg
# Processing filename: 000000001626_jpg.rf.688ccd0dcac9d9fc068a9ad37b571f16.jpg
# Processing filename: 000000000982_jpg.rf.3b792be6ff75b543d9d0ae8c35a96677.jpg
# Processing filename: 000000003947_jpg.rf.eed31184de003f46e5ce3835d258da84.jpg
# Processing filename: 000000003378_jpg.rf.c19f9280904836d6cad8f8841e2d1393.jpg
# Processing filename: 000000003862_jpg.rf.68adb2e862c41e366349f6f3d17e0e2f.jpg
# Processing filename: 000000000996_jpg.rf.948d5879e50e29db84a608b24d1ba8e9.jpg
# Processing filename: 000000001790_jpg.rf.0efcae09659157f3e0c5ed85936c38e1.jpg
# Processing filename: 000000001424_jpg.rf.0ee19759b4c1f2c760d7d62ee6362e70.jpg
# Processing filename: 000000001472_jpg.rf.68ae74cec39ecd98c90e692c247cb69d.jpg
# Processing filename: 000000001912_jpg.rf.68e9df689e3dbdf9e49bd8240356b612.jpg
# Processing filename: 000000003192_jpg.rf.68f2a65598679eebafdd88e9e2f3deb6.jpg
# Processing filename: 000000005215_jpg.rf.68d90d7c6b8b4a65d6f12c1d833ac64d.jpg
# Processing filename: 000000005482_jpg.rf.3bcbccd1734d4e1214456fbaae93b95d.jpg
# Processing filename: 000000001144_jpg.rf.c1d97adaca756dea43c1c36953904a8a.jpg
# Processing filename: 000000004741_jpg.rf.ef275f652b57e299236e9d51c60beaec.jpg
# Processing filename: 000000002614_jpg.rf.3bd36d56d520662d8550ef343aeec307.jpg
# Processing filename: 000000001622_jpg.rf.c22463ecbaf9a4d024a49201c0936a50.jpg
# Processing filename: 000000001014_jpg.rf.ef5ec15f61c11c48646441a31fe72600.jpg
# Processing filename: 000000000634_jpg.rf.c21e9456a8fa5485b0421e8a9a4e80b3.jpg
# Processing filename: 000000000450_jpg.rf.696ca9cbbc9d6a9d97764f270e18ddbf.jpg
# Processing filename: 000000002742_jpg.rf.0faf272ff8418321d1eabd70ad8eb840.jpg
# Processing filename: 000000004592_jpg.rf.0fac12be521664456e6d75f534733fc8.jpg
# Processing filename: 000000005088_jpg.rf.ef9c9643b2a8452951ee09850f9e791b.jpg
# Processing filename: 000000004428_jpg.rf.c2656a8eb1ff2e5cea603db4f8038e6b.jpg
# Processing filename: 000000001298_jpg.rf.102394c4d8b79475d2fce2b5be9db4cd.jpg
# Processing filename: 000000004426_jpg.rf.efdf93e1d0e41f851cb18cc44f0b178c.jpg
# Processing filename: 000000000675_jpg.rf.3cca450e484f6f4ce81079601a89422f.jpg
# Processing filename: 000000000625_jpg.rf.102a03bb9975278f3bbd68a01dc91333.jpg
# Processing filename: 000000003483_jpg.rf.105990258fab25618a1e74cdda8672c0.jpg
# Processing filename: 000000000382_jpg.rf.3cd43afa879064a41e68b06e1e3b5f56.jpg
# Processing filename: 000000000775_jpg.rf.106572494331e84ab65fbf62409d227c.jpg
# Processing filename: 000000000488_jpg.rf.107fdda6806ed9078ffbc17b83b39f5a.jpg
# Processing filename: 000000001036_jpg.rf.3d5276a84c6ad803736ef2acf9322880.jpg
# Processing filename: 000000001407_jpg.rf.6a166d05b7fcafcb11d93a163480efc8.jpg
# Processing filename: 000000001737_jpg.rf.c3407a1471a485132c5f98c062d0dd52.jpg
# Processing filename: 000000002758_jpg.rf.c33a28e8f3e5a9878ed2cb86a9beef9b.jpg
# Processing filename: 000000002388_jpg.rf.107cdb72e22ee9bc6f674e6ede853aa7.jpg
# Processing filename: 000000002693_jpg.rf.10c1215832835a5386f553f92897a37c.jpg
# Processing filename: 000000003321_jpg.rf.c39eacb05aa295c31252535dbbc97b74.jpg
# Processing filename: 000000002619_jpg.rf.9649b7e69ae80dad710d83960e274c72.jpg
# Processing filename: 000000002583_jpg.rf.f0aa8d23ec98cb28413a59847bf2d671.jpg
# Processing filename: 000000003877_jpg.rf.10eca28e17ba0e1f03179414f77baa67.jpg
# Processing filename: 000000004885_jpg.rf.f0ff38f78cf2062517df944953b21d0f.jpg
# Processing filename: 000000003860_jpg.rf.6a9a5ab5a900a70e6adb4496e0d9ccba.jpg
# Processing filename: 000000003134_jpg.rf.10e8d39a68500bbb1fe146209cf97baa.jpg
# Processing filename: 000000001869_jpg.rf.6ae346c424b6ff980e7f283d9e41a034.jpg
# Processing filename: 000000002687_jpg.rf.96a6b3103be1dc9bf4cf0397b696962f.jpg
# Processing filename: 000000000074_jpg.rf.3ddcfeced70e1e7d28bfd0e3d08b0321.jpg
# Processing filename: 000000000825_jpg.rf.6aebcac09483f6ec57963f05b6b12e16.jpg
# Processing filename: 000000004571_jpg.rf.114206f09e1d45b3cd7c7f928f13be70.jpg
# Processing filename: 000000001924_jpg.rf.1169f6db9afcf4d5e61cd60f5c0b7651.jpg
# Processing filename: 000000004761_jpg.rf.3e01335cf22a416bba0780ce43184f34.jpg
# Processing filename: 000000003735_jpg.rf.11622807032d988b5e8c80c7b9c53a35.jpg
# Processing filename: 000000001392_jpg.rf.c47d79b8b49173063b8f654428a61c8e.jpg
# Processing filename: 000000001777_jpg.rf.c4476fd37f1f8b80ffe04d8bf332d166.jpg
# Processing filename: 000000001907_jpg.rf.118379411d5eb83afecee22d9891fe71.jpg
# Processing filename: 000000001580_jpg.rf.c4a3cc25d6c53eeefc61ae8d3ccc3dfe.jpg
# Processing filename: 000000001611_jpg.rf.3ea0fc898280dea006d450ac27440332.jpg
# Processing filename: 000000000564_jpg.rf.976ccecad8582602221101e139ff4d2b.jpg
# Processing filename: 000000002608_jpg.rf.c485caecb6fe4e5bb3d54206706ab15f.jpg
# Processing filename: 000000001706_jpg.rf.11db0066054859067d50647860accaeb.jpg
# Processing filename: 000000005113_jpg.rf.9752cefa18ed9f0e6d3d9f4e1e15d2a4.jpg
# Processing filename: 000000001822_jpg.rf.f1a57196e444a3a030f674fa61f8da05.jpg
# Processing filename: 000000002007_jpg.rf.c4d568ea49c57dcc387d6b994e7a3aab.jpg
# Processing filename: 000000001906_jpg.rf.3ed65ef4fbd0f62fe78c6cfc3de93543.jpg
# Processing filename: 000000003964_jpg.rf.6bc9dc2b0ddc854b9c35a4c79ceede0f.jpg
# Processing filename: 000000005453_jpg.rf.6bf161136e5715de9e88a89666b6f08f.jpg
# Processing filename: 000000001355_jpg.rf.f25df1e885ebd8b6ec0928c0966977a4.jpg
# Processing filename: 000000001145_jpg.rf.c5369267b63a7a413cde6579bb4517ca.jpg
# Processing filename: 000000004981_jpg.rf.6c280b14dc4973a760c387d677852eb1.jpg
# Processing filename: 000000001915_jpg.rf.f265fe2254e39f183b3624338ef65c6b.jpg
# Processing filename: 000000002209_jpg.rf.f2b81e4ebdff14af44638ce5d8a15afc.jpg
# Processing filename: 000000005028_jpg.rf.f297e5f99d7b09db2659481515bd1818.jpg
# Processing filename: 000000001323_jpg.rf.983a9c1427bcb63ff1c681591f997425.jpg
# Processing filename: 000000002229_jpg.rf.9868e85f8b0d48a2f8d35180ef98be7c.jpg
# Processing filename: 000000000307_jpg.rf.f2d901fe9a908e162f3bd0942052b468.jpg
# Processing filename: 000000001164_jpg.rf.3ff9f1aa5011dcbfcf02f53720a06135.jpg
# Processing filename: 000000000326_jpg.rf.c5f4cb43884d56fb3b3420a192b8fcde.jpg
# Processing filename: 000000001455_jpg.rf.1313ad7aa9f3ab16b021c89abbfe6c4a.jpg
# Processing filename: 000000004283_jpg.rf.c5d363ef110fe290f7768dda8d8d9916.jpg
# Processing filename: 000000004988_jpg.rf.98e2ed65add3ce854c5a69ac171e86c9.jpg
# Processing filename: 000000005032_jpg.rf.c6442e7f68fb327df5295a7a18f698d7.jpg
# Processing filename: 000000001029_jpg.rf.4046b83b026c00a72c1001035fd0fb2a.jpg
# Processing filename: 000000002276_jpg.rf.c62b3523982144eefd573baf0eaa348f.jpg
# Processing filename: 000000002445_jpg.rf.6d05b27ee73ecf742d9e71019e721340.jpg
# Processing filename: 000000004809_jpg.rf.c6696942ca46c9afb35962b9ed57bb09.jpg
# Processing filename: 000000003745_jpg.rf.6d22930766e78b5f9a8693731227931b.jpg
# Processing filename: 000000002056_jpg.rf.408c0a8141e3f94101847e4d4124fcfc.jpg
# Processing filename: 000000002570_jpg.rf.6d29028df83ddb98d76207482857525c.jpg
# Processing filename: 000000002983_jpg.rf.99158472dcbb8e1902c730368ff5cfab.jpg
# Processing filename: 000000004880_jpg.rf.6dafe9e8ceca877c330f325600d77e25.jpg
# Processing filename: 000000000987_jpg.rf.6d777e43273a8d8ffd8281aaadd80737.jpg
# Processing filename: 000000001102_jpg.rf.f43360d111e2078830d17423a85c2d11.jpg
# Processing filename: 000000005483_jpg.rf.13d782cb579bb85e750bfde3401d942e.jpg
# Processing filename: 000000000974_jpg.rf.6dc459a48c1ff260407156a35573adc9.jpg
# Processing filename: 000000003310_jpg.rf.414f0ba2e866d268228479cf19ad3c04.jpg
# Processing filename: 000000003348_jpg.rf.6e14effc7f7e28bcfeb6aa942308b9bd.jpg
# Processing filename: 000000004201_jpg.rf.c72c0142f1310be76845d8c3e9bb84dc.jpg
# Processing filename: 000000000831_jpg.rf.99edf6b6ef9792ddf2b575f0da410feb.jpg
# Processing filename: 000000002124_jpg.rf.f4f520abac63d1f9d59290ffbbf28fd1.jpg
# Processing filename: 000000003590_jpg.rf.14e32a071ee4eebe35e2ab4fdc7bf533.jpg
# Processing filename: 000000005259_jpg.rf.c7565109b243df5cf249b577ee480b2e.jpg
# Processing filename: 000000001902_jpg.rf.41907ebceed74dc66c3b6485ddec8b2c.jpg
# Processing filename: 000000002477_jpg.rf.41e46274b46a75f8836f60975895d093.jpg
# Processing filename: 000000005435_jpg.rf.c7c1e19cfe854c566bb6437aadffbf3c.jpg
# Processing filename: 000000000370_jpg.rf.6e8ef091f8d488b297d2487084138d4a.jpg
# Processing filename: 000000001911_jpg.rf.f5763d2623e5c7acddeb7f139f82abba.jpg
# Processing filename: 000000000764_jpg.rf.c7ff4d09b5ac971d6e047e805e641dd5.jpg
# Processing filename: 000000000754_jpg.rf.c80aa02d763e29f99d801b8512142061.jpg
# Processing filename: 000000002754_jpg.rf.156ae790014936bc266178c883dbf7e8.jpg
# Processing filename: 000000003325_jpg.rf.9aad7ae322238f97131df60b11e812a3.jpg
# Processing filename: 000000000960_jpg.rf.6ee9bc904c95a30f16a4c2b9f6e90c38.jpg
# Processing filename: 000000001688_jpg.rf.1524a56c0e783fa989d8703e332930e5.jpg
# Processing filename: 000000005430_jpg.rf.6f3a3312ae2dfa47b9b5f9c1e911645e.jpg
# Processing filename: 000000004739_jpg.rf.425e728a62326a3c086ffc3a69f82956.jpg
# Processing filename: 000000001436_jpg.rf.c83d7ab13f2b8dd7698671eb8604af17.jpg
# Processing filename: 000000001895_jpg.rf.15a4c1bc6e85bcea814b8a9b60540213.jpg
# Processing filename: 000000004622_jpg.rf.f5a6400b0cb9a2f05ced80e921e26a89.jpg
# Processing filename: 000000003242_jpg.rf.15ca1b78fb2b60acdc19b29df659da4e.jpg
# Processing filename: 000000005142_jpg.rf.15c624c0a269de259cf2da3b304f965e.jpg
# Processing filename: 000000001941_jpg.rf.f627b4ef8091563b549f3d3167babec0.jpg
# Processing filename: 000000000801_jpg.rf.9ba55575f68de72ed1a5df118073cf1b.jpg
# Processing filename: 000000003386_jpg.rf.9b818200ec2dc186d8a1b9f75091a563.jpg
# Processing filename: 000000001558_jpg.rf.6fc3cac3667010fd985e4f0f41c1e0f3.jpg
# Processing filename: 000000005336_jpg.rf.9b736fe965706f81195f20a7d9bf8380.jpg
# Processing filename: 000000003837_jpg.rf.c8b8f8a32626e1b7df27eaa901bea7aa.jpg
# Processing filename: 000000003003_jpg.rf.16366aa4d980a9e9fe06596761d57f9a.jpg
# Processing filename: 000000004642_jpg.rf.c925a329943eb4cc307a773e0c1714a6.jpg
# Processing filename: 000000000908_jpg.rf.9bc136fa7e80d8ecae052b2555fec762.jpg
# Processing filename: 000000001340_jpg.rf.9bef512c8b17ec75867d9a0a9361e5b8.jpg
# Processing filename: 000000004876_jpg.rf.9bc3e85bb8c7c92d34e29e3830605132.jpg
# Processing filename: 000000002624_jpg.rf.f66fef8912672a5050f26214d596d306.jpg
# Processing filename: 000000003920_jpg.rf.f677e471ee0fe767318d25af848b78af.jpg
# Processing filename: 000000005263_jpg.rf.42f5c7153347369081c69072b36c3909.jpg
# Processing filename: 000000004984_jpg.rf.1686b9c75feb4311b866748fe28decdd.jpg
# Processing filename: 000000004705_jpg.rf.1680f11ed3da9f27e98d2646c042025f.jpg
# Processing filename: 000000001146_jpg.rf.16b6db31b180ab1d27621222735e5643.jpg
# Processing filename: 000000001712_jpg.rf.43827ba17154feb64a9f27e6cdcf3e2b.jpg
# Processing filename: 000000005325_jpg.rf.43a4d856609b937173e90c5ce325860c.jpg
# Processing filename: 000000000094_jpg.rf.438894ca14ff20e9e9bea07666295605.jpg
# Processing filename: 000000004385_jpg.rf.9c74703b26b1b4ef7f5ddc3275eb0986.jpg
# Processing filename: 000000002001_jpg.rf.70b81f2b4adbdad2c23bca3dc30bc4d7.jpg
# Processing filename: 000000002466_jpg.rf.9cb5b7e7b4986a5bb0e6c12190216a47.jpg
# Processing filename: 000000002992_jpg.rf.f73104d1a9a791b9941d956796ee149e.jpg
# Processing filename: 000000000136_jpg.rf.9cb07748c7961570f6ddfd69573b1b70.jpg
# Processing filename: 000000001994_jpg.rf.4426b9e6b177bf48ee39bba777175a1f.jpg
# Processing filename: 000000004289_jpg.rf.f7a4bcc1d85aad5d6826f85160715e49.jpg
# Processing filename: 000000002886_jpg.rf.4423e280b008c5faf1a516a2747fd1e0.jpg
# Processing filename: 000000000201_jpg.rf.f7d66a194b20618ad141ce15bca9be92.jpg
# Processing filename: 000000005210_jpg.rf.4478b7f16e55d18f0634c5c074b6a5d5.jpg
# Processing filename: 000000001374_jpg.rf.44693d0c2e15ac66a5e71aabd2cd6c38.jpg
# Processing filename: 000000004893_jpg.rf.ca827d572e02d2b2a33a1ec847f0d940.jpg
# Processing filename: 000000002988_jpg.rf.ca895ea898a087eb362ecbfd070e7191.jpg
# Processing filename: 000000002239_jpg.rf.9d5ca8644aaf2876021b1353e6ea9ef5.jpg
# Processing filename: 000000000151_jpg.rf.9d46c71003fd911c1b03dbcc45229f87.jpg
# Processing filename: 000000005247_jpg.rf.ca8b61f47a2c531f4839f52b784e1d75.jpg
# Processing filename: 000000001224_jpg.rf.9da96527195176b63174836e853ca51e.jpg
# Processing filename: 000000005151_jpg.rf.44d99a7a7540b1c5b025342fa2b1b598.jpg
# Processing filename: 000000002150_jpg.rf.cb1a86e52f16047e6ede5431c90ea120.jpg
# Processing filename: 000000000536_jpg.rf.cb15ef1fd245ae9e584f4254fd33765e.jpg
# Processing filename: 000000005064_jpg.rf.18050cd357e6df7463d17c06d5edbdf4.jpg
# Processing filename: 000000000025_jpg.rf.cb2625a696b94cca5fa505b2e5c511ae.jpg
# Processing filename: 000000001306_jpg.rf.451882f104cd8a2cbc6c0144add9e0a0.jpg
# Processing filename: 000000000384_jpg.rf.cb585f30ed17cf5810e3ad0afe28ca64.jpg
# Processing filename: 000000001599_jpg.rf.f882fa8caddfefc6072a719d2278c213.jpg
# Processing filename: 000000001451_jpg.rf.71f33f0374a895189ec0ec5ba3dcbdd2.jpg
# Processing filename: 000000004444_jpg.rf.18931c460b7253f1d76bc4b864af1c0d.jpg
# Processing filename: 000000002755_jpg.rf.45246fcdb48f6438a1a83daa929f98d1.jpg
# Processing filename: 000000005165_jpg.rf.f883768ea418495c8ec5e26ff81bd3d9.jpg
# Processing filename: 000000004979_jpg.rf.7223c56310c5b220e7824888924aea55.jpg
# Processing filename: 000000000194_jpg.rf.9e55a2b9686a9858b2a40927dcf1ae7a.jpg
# Processing filename: 000000000357_jpg.rf.9e3ea45dadeb9020f1d2ea4faa1f6031.jpg
# Processing filename: 000000005396_jpg.rf.f8e0c910479ec144c5fd75824847d4f2.jpg
# Processing filename: 000000001347_jpg.rf.9e4acfe3ccd2f63673e48c3b5b71ee46.jpg
# Processing filename: 000000001084_jpg.rf.9e40e45061702ce1add8a16d2aff38d7.jpg
# Processing filename: 000000001448_jpg.rf.7242c8c91117cb9eedc471b56e60a764.jpg
# Processing filename: 000000001903_jpg.rf.f91c4085acc01ee2c546da4fee800d64.jpg
# Processing filename: 000000000955_jpg.rf.9eaf5ad448fd0385bcfe2944f91e4774.jpg
# Processing filename: 000000004549_jpg.rf.7293842d904425fab706614722b7e51f.jpg
# Processing filename: 000000003320_jpg.rf.9e6db2d79bb4603a4175fa0ad28fa50f.jpg
# Processing filename: 000000000328_jpg.rf.18f938217a9f63f196639a887225e19b.jpg
# Processing filename: 000000000312_jpg.rf.cba26e976bd85f1ce2cc2c36d8288ffd.jpg
# Processing filename: 000000000599_jpg.rf.cb9d69b3ce20f5c15f609a700664f84b.jpg
# Processing filename: 000000005472_jpg.rf.f95f99e20170b5d5597f78af327f7f79.jpg
# Processing filename: 000000003014_jpg.rf.9f040eb53f9023e7ab366bd346f07ac8.jpg
# Processing filename: 000000001237_jpg.rf.731873936efebbfcf037af07c4950a0c.jpg
# Processing filename: 000000000941_jpg.rf.f9a4d7d0b586837f77984382c8f440d5.jpg
# Processing filename: 000000004975_jpg.rf.465d954a3ca3953dbe61d26c46dfffaf.jpg
# Processing filename: 000000000064_jpg.rf.f985ec736cc89e6e3ec55df8650caa61.jpg
# Processing filename: 000000004555_jpg.rf.cc760ae848ea8c9079e7873dd3ff67c4.jpg
# Processing filename: 000000003812_jpg.rf.467dad225c8f915e6f0b5822afa03bfd.jpg
# Processing filename: 000000005018_jpg.rf.73623b44ca3c570db7648a659db979a7.jpg
# Processing filename: 000000000397_jpg.rf.733779e4fa4fb8e430b25d73df839d9d.jpg
# Processing filename: 000000003149_jpg.rf.cc78da7ca220791cc2bca9cdbe9a3839.jpg
# Processing filename: 000000000673_jpg.rf.46db319f8ab5eb55eb253785d7e03d5f.jpg
# Processing filename: 000000002193_jpg.rf.46c42e6a5218f301b2aaef8a335adaa8.jpg
# Processing filename: 000000001841_jpg.rf.9fbcdb674d7c9512b40d03b14aaaf697.jpg
# Processing filename: 000000004410_jpg.rf.ccaaba8b5d53d2be80cf0095377084fb.jpg
# Processing filename: 000000005312_jpg.rf.ccddcf1ae4bbec7b09b98af08f15a370.jpg
# Processing filename: 000000003897_jpg.rf.9fbfcfe7170c5385f2194ea490a1f6f5.jpg
# Processing filename: 000000001403_jpg.rf.ccd359a09b778b3f5359f1cb25f6eae5.jpg
# Processing filename: 000000002982_jpg.rf.740b121a64d6be837273aada7af367a6.jpg
# Processing filename: 000000004212_jpg.rf.73c7bc22220aa49dc134bd6b21f6aceb.jpg
# Processing filename: 000000002690_jpg.rf.9ff5c802ce12a784e88381101307bac0.jpg
# Processing filename: 000000003442_jpg.rf.46fcc51ee18f380167637fa7189ab3f2.jpg
# Processing filename: 000000002066_jpg.rf.73ec5985cc83d8613b4904d5cda057f1.jpg
# Processing filename: 000000000656_jpg.rf.7406c470507092d29950cfbb6c9a3dde.jpg
# Processing filename: 000000004574_jpg.rf.ccfdf645b4e66146b4cfdf3ea6ffb9fb.jpg
# Processing filename: 000000000208_jpg.rf.a053d8cef6c86dcf5f09e76667cdb205.jpg
# Processing filename: 000000001888_jpg.rf.cd75a636abecb02f16838fb8351893eb.jpg
# Processing filename: 000000003939_jpg.rf.47361ff5b0be0e50b317a06b99536f25.jpg
# Processing filename: 000000000540_jpg.rf.a02b7644dfbcd1630e4de7ca6df0e2eb.jpg
# Processing filename: 000000004068_jpg.rf.cd500fc220b7297f5aa859b2219c6d60.jpg
# Processing filename: 000000004318_jpg.rf.7443424cda451dd1514a8627e56c213c.jpg
# Processing filename: 000000001785_jpg.rf.1ad4010bb80433a5ff701dec49603da4.jpg
# Processing filename: 000000004243_jpg.rf.a03bc5723c45d87043c1fc7823b20190.jpg
# Processing filename: 000000004827_jpg.rf.fadc3c3b2584b71bf7176990daaf77f1.jpg
# Processing filename: 000000005123_jpg.rf.cdefe7142542d36763cab112f85124fb.jpg
# Processing filename: 000000004711_jpg.rf.cdc754b3e5d8f0984754b19911ea10ec.jpg
# Processing filename: 000000005140_jpg.rf.a0ba5d1a04f793f0d937d7bef34b7856.jpg
# Processing filename: 000000002545_jpg.rf.ce21b333dda7124ec4a1e7c1b99a8e79.jpg
# Processing filename: 000000004079_jpg.rf.74e27c5542f62560a4827ed53407b9e4.jpg
# Processing filename: 000000002892_jpg.rf.1b64a7ca69efa126e83c425316d72cb8.jpg
# Processing filename: 000000004764_jpg.rf.ce77cbe246e3a5bf2904aef79153a6d2.jpg
# Processing filename: 000000004312_jpg.rf.755e2ae5ded897b33e059c6a3227e650.jpg
# Processing filename: 000000003217_jpg.rf.1bc4e9e030a361f29f8b9c9ada04e6e8.jpg
# Processing filename: 000000000529_jpg.rf.75494fb25d2adefdc8660cee491bb7e2.jpg
# Processing filename: 000000002867_jpg.rf.fc03819a2c78c1a157c568a3213aa33d.jpg
# Processing filename: 000000001505_jpg.rf.759109c394080a5cdfb412f2cb8bbeb5.jpg
# Processing filename: 000000002142_jpg.rf.ceb85ce8eb87e9adeb588975ae748fc2.jpg
# Processing filename: 000000002349_jpg.rf.a194248182f36e1981bdc7ee7628c8b4.jpg
# Processing filename: 000000001155_jpg.rf.a1a948e4f3fa4909111520f96febd134.jpg
# Processing filename: 000000000332_jpg.rf.fbdc2fe734e71b57bcce218fa0d8c267.jpg
# Processing filename: 000000000322_jpg.rf.48ab769d22bc603b25ea269f387814f1.jpg
# Processing filename: 000000005076_jpg.rf.fbe2dcf5ac17098913ec144d6cf2e990.jpg
# Processing filename: 000000005146_jpg.rf.cecd0ead6311204af0e7c89eb3a19c7d.jpg
# Processing filename: 000000003926_jpg.rf.757fb006d075ea242690e13e00c99fc9.jpg
# Processing filename: 000000000127_jpg.rf.fc150ae668db95c92fcf19ceff9ee15f.jpg
# Processing filename: 000000000753_jpg.rf.a1d963434947efadf7204d0c8f5b381a.jpg
# Processing filename: 000000000821_jpg.rf.4918679c306d7d8adc834bcb58ab3574.jpg
# Processing filename: 000000002686_jpg.rf.fca2285df9676c38da506227ab370e85.jpg
# Processing filename: 000000000827_jpg.rf.760907e51cafde6b041215ebc16420b9.jpg
# Processing filename: 000000001282_jpg.rf.cf43e5b1d103880927d7c75d5ea6fce3.jpg
# Processing filename: 000000004980_jpg.rf.cf2c69f5d27a504758834a766e8901ac.jpg
# Processing filename: 000000001526_jpg.rf.1c6c7bcb9d670a1053fe828ea17299f4.jpg
# Processing filename: 000000003690_jpg.rf.1c8747e878ac39037a22c5c3c52e74ec.jpg
# Processing filename: 000000001647_jpg.rf.cfa32e17f90f3d8e83f1a3cdef5b4341.jpg
# Processing filename: 000000001625_jpg.rf.a27022a1413358415e55231544432bd6.jpg
# Processing filename: 000000004978_jpg.rf.76a044188cd475050a515d30bd6e41ac.jpg
# Processing filename: 000000000836_jpg.rf.49a5f49d0c5ffe9d082b449618b08013.jpg
# Processing filename: 000000004716_jpg.rf.a2bb980962bf9449fed2e359ed5d2b42.jpg
# Processing filename: 000000000715_jpg.rf.fd1936ed0e3302049e170c4cdc2b6bd5.jpg
# Processing filename: 000000002839_jpg.rf.769c77073af152a2f3e56313f4db3f78.jpg
# Processing filename: 000000004396_jpg.rf.fd1839cd56c32d012b0dc0cbfeed784f.jpg
# Processing filename: 000000005260_jpg.rf.1d0744dcccfde8e92b02777045177a73.jpg
# Processing filename: 000000000036_jpg.rf.76d2ae130b609243026e3fbfdfdbd335.jpg
# Processing filename: 000000001510_jpg.rf.1d858a8293bc6cb3e1c1e9e96d2f65ee.jpg
# Processing filename: 000000005377_jpg.rf.76e3d8ce7de4153feff28fe1e4391b9e.jpg
# Processing filename: 000000002429_jpg.rf.76e556822f7b64facbc7c0c9468b6a50.jpg
# Processing filename: 000000001090_jpg.rf.fd3fd7ff4cb669a007bddfcf5e956ccf.jpg
# Processing filename: 000000000711_jpg.rf.4a304a911d14bf4dc92e7eedacd8eba0.jpg
# Processing filename: 000000000404_jpg.rf.4a73a407f09f253ca3e38955549286ca.jpg
# Processing filename: 000000001681_jpg.rf.a3290fbe124a8f0bfad90b3eb294f9c5.jpg
# Processing filename: 000000000934_jpg.rf.772d34901790d2ccc2e60c37ecfc0881.jpg
# Processing filename: 000000005172_jpg.rf.a39ad6cbc3cad2e8559ca100461a6aea.jpg
# Processing filename: 000000005418_jpg.rf.fdd1b39f114a23ff3ff2d3ae429446f1.jpg
# Processing filename: 000000004595_jpg.rf.775e85f3d9508a42f8002107f299c67c.jpg
# Processing filename: 000000002280_jpg.rf.d0d763e2103ba31f9fb35f6ec9b5c86a.jpg
# Processing filename: 000000005152_jpg.rf.1e340f48407d137367fa7b9dee40a624.jpg
# Processing filename: 000000001926_jpg.rf.d0c4b647c108d5c7355f88622a7e3656.jpg
# Processing filename: 000000002776_jpg.rf.fe6c31e91f1b8879b58d36b28427832d.jpg
# Processing filename: 000000002691_jpg.rf.77f71d2a5b1e77e8b7401ff0ab2f1fc6.jpg
# Processing filename: 000000001947_jpg.rf.4b33ed6236be728347e7f9eaf95d48cb.jpg
# Processing filename: 000000001697_jpg.rf.fe5dfd674b5452f28a9f5d97a8fad993.jpg
# Processing filename: 000000000030_jpg.rf.d10bf2aa9494ccb9ae33f311a26abf48.jpg
# Processing filename: 000000000394_jpg.rf.d13d8e54f0d5ef26f80d86f38d454030.jpg
# Processing filename: 000000004823_jpg.rf.a46553621023af6a9df491bddd85d18a.jpg
# Processing filename: 000000001586_jpg.rf.1ed8e995d11e53a7e76c79de558cd0bf.jpg
# Processing filename: 000000005278_jpg.rf.4bae4cb60b15603cd9ace8cbc53cbdae.jpg
# Processing filename: 000000005383_jpg.rf.fe96c4d12ad1efb242b876f81af14597.jpg
# Processing filename: 000000001997_jpg.rf.4b6ab4497245dff255b2b60d7ac2769d.jpg
# Processing filename: 000000003342_jpg.rf.4bbcb979dc4fbc433611ef130c0eff42.jpg
# Processing filename: 000000000196_jpg.rf.1ef4e2826eae89a4b72fb3d0d01a568d.jpg
# Processing filename: 000000003915_jpg.rf.a4c8a1f34b27779f14148627e779a00c.jpg
# Processing filename: 000000001709_jpg.rf.1efe1c56755153d0cb07d09d4179e230.jpg
# Processing filename: 000000003466_jpg.rf.78a5d6223f1ef1aa2fb749ddda8438b8.jpg
# Processing filename: 000000001107_jpg.rf.ff263941371e580d0f7174bda7071d25.jpg
# Processing filename: 000000001381_jpg.rf.4bfe7c344ff046013ce6a0504fcc0310.jpg
# Processing filename: 000000001059_jpg.rf.ff9d61df70406d0f9a74e3da9f2997da.jpg
# Processing filename: 000000000706_jpg.rf.4c6a99ef48078d08aeed257fe5b9e762.jpg
# Processing filename: 000000005376_jpg.rf.4c3fa7027dff4dd2cb11a5fc876317b6.jpg
# Processing filename: 000000004020_jpg.rf.4c9bba16e9d0347646ed0b29575285c7.jpg
# Processing filename: 000000002606_jpg.rf.1fd8883e975f3fe32ce40319b37635e7.jpg
# Processing filename: 000000002672_jpg.rf.4c7667fe19e981871dcbfc284ed4f43b.jpg
# Processing filename: 000000000620_jpg.rf.4cbac06aad36681f44165d1c388b896b.jpg
# Processing filename: 000000003481_jpg.rf.ffcc1fb7566bd91e4271e22c9a191e10.jpg
# Processing filename: 000000002849_jpg.rf.ffed4222c829b3402242593de629f305.jpg
# Processing filename: 000000003457_jpg.rf.4cf1a38533178c662fe478c76f0b6117.jpg
# Processing filename: 000000003000_jpg.rf.a5cdb9a2fcc15e4a1a36e2aaa414fa6e.jpg
# Processing filename: 000000001103_jpg.rf.d2b2324f162933d64fd0b48892e06119.jpg
# Processing filename: 000000000257_jpg.rf.204993c5161966c4ccc4c159cda5d0db.jpg
# Processing filename: 000000004497_jpg.rf.4cd9efeecba1bd412d7ac2c2e87c7f97.jpg
# Processing filename: 000000003751_jpg.rf.4cd9eee08fef96c33bafaa6aa0b2c26b.jpg
# Processing filename: 000000002843_jpg.rf.a5b8f51a34f42e08c419c2b0033a03c4.jpg
# Processing filename: 000000002471_jpg.rf.d2981b4637523cb4d4247f43fa8edf56.jpg
# Processing filename: 000000002562_jpg.rf.79959a649987935b440b8d3e5b57a009.jpg
# Processing filename: 000000001561_jpg.rf.2056cc63581be5c30b54b1f48b21aff1.jpg
# Processing filename: 000000001955_jpg.rf.a63b63ef20ad88b9bdf1d0547d6fa70f.jpg
# Processing filename: 000000004843_jpg.rf.d35f7516160ebb87dd788cd927df011f.jpg
# Processing filename: 000000004916_jpg.rf.20b944ee73a619a283130588c052ddb9.jpg
# Processing filename: 000000004517_jpg.rf.d3612a16ae1b5f8fa95cf534755377b6.jpg
# Processing filename: 000000000071_jpg.rf.4d53d5e5937860f2096b88d41a176ab8.jpg
# Processing filename: 000000001722_jpg.rf.a6763ba7e8b012e94c4e70bd30e59617.jpg
# Processing filename: 000000003048_jpg.rf.d348cfb6814c8b16c6e64210e786bb30.jpg
# Processing filename: 000000002411_jpg.rf.4d93f80beedcf2649450b246f0d9b40f.jpg
# Processing filename: 000000001900_jpg.rf.a693d96ced996a88cb88432961b319dd.jpg
# Processing filename: 000000004968_jpg.rf.d3b8b4ee1b4af394b173aca6165ae199.jpg
# Processing filename: 000000002197_jpg.rf.4dfae94ee054d8905518e97b17fec003.jpg
# Processing filename: 000000003148_jpg.rf.213b09f469b9c073cda2f8c29f5138d5.jpg
# Processing filename: 000000000283_jpg.rf.d3ef7f456281dbe14f9bd1802a72535e.jpg
# Processing filename: 000000004509_jpg.rf.4e22094f6d0111dc54e6eed0ef050b9f.jpg
# Processing filename: 000000003220_jpg.rf.216af09f3acb2785fe8069018b4494b3.jpg
# Processing filename: 000000005471_jpg.rf.7b32d18347e86e5ab41bcfa7adea16b3.jpg
# Processing filename: 000000003035_jpg.rf.a76d47c84e809946bbc52c3151e5d0f8.jpg
# Processing filename: 000000004042_jpg.rf.a79840986abd0c88d438ff3b39eb5e6b.jpg
# Processing filename: 000000004331_jpg.rf.4e92f4c297959fe9d7bc0ec80399da1e.jpg
# Processing filename: 000000000901_jpg.rf.d50e674fd08a3d0a2706171f8d28a07f.jpg
# Processing filename: 000000001563_jpg.rf.d4e58f57cd550e3c10990fad24b2ade7.jpg
# Processing filename: 000000004608_jpg.rf.22b06efc138cdb70d064a3cb72b673ea.jpg
# Processing filename: 000000001332_jpg.rf.a8262ca511501076a4c96923f1f8c15f.jpg
# Processing filename: 000000002645_jpg.rf.d569128d270f30329aa1ec4d57896280.jpg
# Processing filename: 000000002896_jpg.rf.d56615b213c840bd83bb58bdcc57e171.jpg
# Processing filename: 000000003335_jpg.rf.7c0db706ce1937bfd7095719ee51ca46.jpg
# Processing filename: 000000000089_jpg.rf.22ce5bc9343333744fac9dca9530d408.jpg
# Processing filename: 000000001072_jpg.rf.d5b35efca15742998f211fef0632bd5c.jpg
# Processing filename: 000000005424_jpg.rf.7c30a5e11083bd69eb96ef9be3d08f3e.jpg
# Processing filename: 000000004576_jpg.rf.7c2e6b949e7cab53d11c896252fa41db.jpg
# Processing filename: 000000001099_jpg.rf.d5e90d2e7fc149b1c56e13f7bdba2e28.jpg
# Processing filename: 000000005388_jpg.rf.a8bbc03848f6a6f6cf326eeddd717d20.jpg
# Processing filename: 000000001596_jpg.rf.22fc2d5f726cd4e4e8003c817e5834da.jpg
# Processing filename: 000000002184_jpg.rf.a8db58fce98c8d240c41e75acfb16576.jpg
# Processing filename: 000000004051_jpg.rf.d616bb89ca5c77bd46f574c19aec3797.jpg
# Processing filename: 000000000985_jpg.rf.235218b36af50f86f30292c106bebebc.jpg
# Processing filename: 000000003995_jpg.rf.d60b3ac6953d634c3bf3a8cc7ba8a84d.jpg
# Processing filename: 000000005352_jpg.rf.d66d3fc0166f71e29f20bd2b022587b5.jpg
# Processing filename: 000000004021_jpg.rf.d673b31c0f58dc7ee874e9555bc2b1de.jpg
# Processing filename: 000000001515_jpg.rf.7ce4e37e1dc6305332d9674dc3681416.jpg
# Processing filename: 000000005288_jpg.rf.7d395792e83d3f3539b6a07eebdb9f9d.jpg
# Processing filename: 000000005328_jpg.rf.d6c5544bc97128f32eb9c9a2df7fe3c7.jpg
# Processing filename: 000000004375_jpg.rf.2404133e4cf102f2f6c7c546a9869058.jpg
# Processing filename: 000000003982_jpg.rf.7d33030e38703cc24f498b9ab13f7473.jpg
# Processing filename: 000000001948_jpg.rf.243211adff89172129f37c3e3c26cfe5.jpg
# Processing filename: 000000002732_jpg.rf.d708531145feba9899f10903fdf68107.jpg
# Processing filename: 000000004246_jpg.rf.d6eac29717a4a2d1bb1c3a2000bba50d.jpg
# Processing filename: 000000000138_jpg.rf.7d651d61e63f07f90843c5e60161a08e.jpg
# Processing filename: 000000004714_jpg.rf.245563857eb12dd4b53765a7cd6a76c6.jpg
# Processing filename: 000000004662_jpg.rf.7de8d17535c21c43f728ebe15e384d76.jpg
# Processing filename: 000000004038_jpg.rf.7dd7a919b55709ae9a3dc753fe5ca202.jpg
# Processing filename: 000000004785_jpg.rf.247102b362ba0f022e5562d1dd9bd8e8.jpg
# Processing filename: 000000003124_jpg.rf.7dbfafc9ce485edd91f29ae93b9e4cc7.jpg
# Processing filename: 000000004208_jpg.rf.7dcd9425e8da951fbf5c8b2497b2c38c.jpg
# Processing filename: 000000001700_jpg.rf.7dee578f7806dcb408360e462ad53f27.jpg
# Processing filename: 000000004229_jpg.rf.aaa7684c632eaed7a405877379b56f55.jpg
# Processing filename: 000000001639_jpg.rf.aa96673ebc70e935b67a7e2a62fc5942.jpg
# Processing filename: 000000005434_jpg.rf.7e0566e590f131478b84995cd7ff59c1.jpg
# Processing filename: 000000003580_jpg.rf.d7919f7a345d395e627efc2171ae49b7.jpg
# Processing filename: 000000003538_jpg.rf.d7a0b433f6bb3052c495a72d63836a67.jpg
# Processing filename: 000000002602_jpg.rf.aade4cf1acc9a21f383657a7ebfe7163.jpg
# Processing filename: 000000001359_jpg.rf.25026db63521d480a11065f311a4df65.jpg
# Processing filename: 000000002014_jpg.rf.7e69f6b58addac032713ccd2c638b0bf.jpg
# Processing filename: 000000000514_jpg.rf.7e9018bc4d0694e6e982435ee5e08dd7.jpg
# Processing filename: 000000000999_jpg.rf.7e6e5c85ea5fb347ee73ce332a31dc22.jpg
# Processing filename: 000000000562_jpg.rf.ab0a4c00f01631f5dae3418887243ee2.jpg
# Processing filename: 000000002640_jpg.rf.d8484d025dd8a012e208490ae842a763.jpg
# Processing filename: 000000001171_jpg.rf.d863fe01c00f0a1efe747522efe97ccc.jpg
# Processing filename: 000000004080_jpg.rf.5288e113b02ccaeca01ce145717e59de.jpg
# Processing filename: 000000002774_jpg.rf.abb751423320b48d18294792451ae9d9.jpg
# Processing filename: 000000001350_jpg.rf.7f44ef5b3aba58d4a1dff44c2637ee53.jpg
# Processing filename: 000000005314_jpg.rf.525d954c6d9c06cfb95c59257ae06290.jpg
# Processing filename: 000000005139_jpg.rf.d8ebebc866ddba686ee90b0dcf0123c9.jpg
# Processing filename: 000000000072_jpg.rf.267f3e9004226103d214334e5521177f.jpg
# Processing filename: 000000000969_jpg.rf.ac2ecff2f571df498ecc5e57e818bca6.jpg
# Processing filename: 000000004794_jpg.rf.ac35aa5237348afb2070e65d0d4eba69.jpg
# Processing filename: 000000005111_jpg.rf.52c18894fabc2c7483866ce3956fb2a8.jpg
# Processing filename: 000000001507_jpg.rf.d8fe09ff03fd732192c392d6b5fa5b42.jpg
# Processing filename: 000000001527_jpg.rf.7fa4802faf6fd35b3714e996fe40e776.jpg
# Processing filename: 000000002235_jpg.rf.532083bb25a13bbea2d94ab56e72a759.jpg
# Processing filename: 000000001589_jpg.rf.5353feb07e73eaf56519040dafbc7d47.jpg
# Processing filename: 000000000400_jpg.rf.26ff7a74c1319d98d24b81fa1aba4c3b.jpg
# Processing filename: 000000001786_jpg.rf.ac96943433d5f041a3bab329ee059b46.jpg
# Processing filename: 000000003613_jpg.rf.26e85fb62a87dd56991e75501f5352dc.jpg
# Processing filename: 000000004132_jpg.rf.80523c008b4c5455422741921844aa21.jpg
# Processing filename: 000000001811_jpg.rf.8015b054dca618de92cece67b2922a2e.jpg
# Processing filename: 000000000641_jpg.rf.da0669ce00217bc37889ef6413c93a0e.jpg
# Processing filename: 000000004537_jpg.rf.accbc33396ac59ad187cd64b33c61870.jpg
# Processing filename: 000000000389_jpg.rf.8021772f2a7f0d044db716db9bd5dab1.jpg
# Processing filename: 000000004069_jpg.rf.ad02a7b595dbdc0a34575ac61f763a05.jpg
# Processing filename: 000000002347_jpg.rf.8087462e856c157282dcaf77c7d8a807.jpg
# Processing filename: 000000001315_jpg.rf.53d25f4bfc6f3671c743b869f123fddf.jpg
# Processing filename: 000000004462_jpg.rf.80af9ba71d822a5ae7d4b363affb8580.jpg
# Processing filename: 000000004901_jpg.rf.da5c06f901ffd86a80595224f544e053.jpg
# Processing filename: 000000001232_jpg.rf.27b99dd3e211493160820a6b4488cad3.jpg
# Processing filename: 000000002061_jpg.rf.dac2887ce90f61be1f28aaff99897474.jpg
# Processing filename: 000000001292_jpg.rf.281d7656be7930517a7363f347506533.jpg
# Processing filename: 000000003761_jpg.rf.548c101c0803b8832e6d23dea0efe686.jpg
# Processing filename: 000000002860_jpg.rf.adbdd445c72f4d324d5253d371f0687d.jpg
# Processing filename: 000000002446_jpg.rf.812416864bbf40247211b002fc086433.jpg
# Processing filename: 000000005339_jpg.rf.db0782a1ee2699ddf0468c2446902cf0.jpg
# Processing filename: 000000001270_jpg.rf.812ae25a08e2801da78c8dba3dc6d20e.jpg
# Processing filename: 000000001168_jpg.rf.db0e5307360332bb13e88e3102b56ff8.jpg
# Processing filename: 000000002258_jpg.rf.dae7252bef44636fc0acf49ae2af344e.jpg
# Processing filename: 000000001122_jpg.rf.dad80d17482468d352b7d2b8d56bc5b3.jpg
# Processing filename: 000000001771_jpg.rf.ae2e72fbc5b6012898a65835f4d2684e.jpg
# Processing filename: 000000001228_jpg.rf.8168168133927c1dfea24ab2753b40a2.jpg
# Processing filename: 000000001393_jpg.rf.28bd7fb15e957da83c0b5435e0073ac9.jpg
# Processing filename: 000000001244_jpg.rf.db45324eea5b1f1d77af92bfe469713b.jpg
# Processing filename: 000000002083_jpg.rf.ae557db8e41c33ee8457cc7f44c683d2.jpg
# Processing filename: 000000000471_jpg.rf.289a9cbb8a7d38aefb330082c6e104dc.jpg
# Processing filename: 000000004684_jpg.rf.81d605d52e43cf263c59c6362c51dd41.jpg
# Processing filename: 000000005437_jpg.rf.81c4bea47d5b26cc593b2be23e9e0aaa.jpg
# Processing filename: 000000003716_jpg.rf.5550216062a95fdf71886a1737a53295.jpg
# Processing filename: 000000002055_jpg.rf.293c194a9ed13cd625226d4880499503.jpg
# Processing filename: 000000000762_jpg.rf.dc0503b3591e019920188468662c2952.jpg
# Processing filename: 000000005373_jpg.rf.55cd6db98b2b8aeaee711f86b353ff01.jpg
# Processing filename: 000000000909_jpg.rf.55e82319a316f535832a8eae7313731f.jpg
# Processing filename: 000000001960_jpg.rf.827a1ae4c9ab9a1a9711e04abb3064d1.jpg
# Processing filename: 000000002139_jpg.rf.2a0546a7487040ec6404f3cc2818ac36.jpg
# Processing filename: 000000004546_jpg.rf.56ae811c212d81d57b49d7794136e28c.jpg
# Processing filename: 000000000853_jpg.rf.56d818d6e13fed40cd2776b44317397a.jpg
# Processing filename: 000000002068_jpg.rf.dd335c803f046f3f77e1ebf9d7723955.jpg
# Processing filename: 000000004394_jpg.rf.dd334b996f03780a6e9f5dce69af5812.jpg
# Processing filename: 000000004189_jpg.rf.b0595bb568907e7d6a47a816b4e5ff03.jpg
# Processing filename: 000000000714_jpg.rf.2a938fa241a3cebaa9817ca9449daa0f.jpg
# Processing filename: 000000005005_jpg.rf.b06d8999cb1321db935326445e165e28.jpg
# Processing filename: 000000004972_jpg.rf.dd37d8792f95e01ad7d6facd469a12b1.jpg
# Processing filename: 000000000965_jpg.rf.dd1ae1e3727dcae128c0b15ca15c2e5c.jpg
# Processing filename: 000000003353_jpg.rf.b09c883fe616a5d2de26597bd651fa1f.jpg
# Processing filename: 000000001999_jpg.rf.57356089d28a67def95ac8783f8ce30f.jpg
# Processing filename: 000000004903_jpg.rf.dd544f8dabebbc4cb0fabb135075a245.jpg
# Processing filename: 000000003389_jpg.rf.573edbf7f4eb58d9e75d54c1442fea02.jpg
# Processing filename: 000000002521_jpg.rf.83a9c154754d181f232654fa00c9fe28.jpg
# Processing filename: 000000001089_jpg.rf.dd923930c3848291b287ae6c9ab57e92.jpg
# Processing filename: 000000005115_jpg.rf.57c75c31b2411c80e2200b63894433a9.jpg
# Processing filename: 000000002089_jpg.rf.b11e5aff9f3676aea3694ec9970a62d3.jpg
# Processing filename: 000000003365_jpg.rf.58199e09936a5f8117ad6fe976635a65.jpg
# Processing filename: 000000000575_jpg.rf.8472ceb36861574c04ace70e20a59d7d.jpg
# Processing filename: 000000002697_jpg.rf.b17fded8a36ff81904c9fa8b7b986028.jpg
# Processing filename: 000000002232_jpg.rf.2c34ecf881c0e8fac4386d12058445ce.jpg
# Processing filename: 000000001108_jpg.rf.84c8249980abfc0782da63a255bb2365.jpg
# Processing filename: 000000003941_jpg.rf.58aec3d216a687b6a967c67364690b2c.jpg
# Processing filename: 000000000260_jpg.rf.853853d7154afa1fe9985890cd3fac56.jpg
# Processing filename: 000000001792_jpg.rf.df28783c888d6561c634447bf626980a.jpg
# Processing filename: 000000001330_jpg.rf.b23965c6daf4ebd8c37454a25c4e40d9.jpg
# Processing filename: 000000002171_jpg.rf.b2301c5762f630895a22959dd4275b86.jpg
# Processing filename: 000000003461_jpg.rf.58dfa470c346ce62df4bcd5313eff212.jpg
# Processing filename: 000000001453_jpg.rf.8559a7d6bb489f25095dcafd0afb252c.jpg
# Processing filename: 000000005205_jpg.rf.df4dabefff7052dda9cd62b6282c4b64.jpg
# Processing filename: 000000003382_jpg.rf.b25cc9afd7ef9fe00234486eb160d498.jpg
# Processing filename: 000000003375_jpg.rf.b2978a851d4979b7dc10e0e8c41c718c.jpg
# Processing filename: 000000003983_jpg.rf.b2bb16a0a56cc3c06607c092be6eb673.jpg
# Processing filename: 000000005282_jpg.rf.85a4e97fa8abc55cdb26c6abe1e48d0d.jpg
# Processing filename: 000000005412_jpg.rf.5974d6cf74f9ee0b606471c79e24a864.jpg
# Processing filename: 000000002902_jpg.rf.dfe7aff09f3185db9da8b6b9b9b47316.jpg
# Processing filename: 000000004834_jpg.rf.85d5249c3a94d3eaf65ebf4fb2745c1e.jpg
# Processing filename: 000000001655_jpg.rf.2d4ff1de727c37c09fd75820d9de1c5c.jpg
# Processing filename: 000000001311_jpg.rf.59df90a7087accf338ac51923c17dffd.jpg
# Processing filename: 000000004567_jpg.rf.5a5346989ee25ec135c25d8b4041a5f9.jpg
# Processing filename: 000000000584_jpg.rf.00eb34e2117a08074a5cf3588dde26d0.jpg
# Processing filename: 000000002212_jpg.rf.b3ad23fb71516446b1aec1560d8c4fd7.jpg
# Processing filename: 000000002072_jpg.rf.b3cba3ec28b041e9cf1206328ebe5100.jpg
# Processing filename: 000000001958_jpg.rf.5a87f17e91ce9c54d3bd49ffc0f13942.jpg
# Processing filename: 000000005156_jpg.rf.2e7579722f592e77d4e5ea906aa0601d.jpg
# Processing filename: 000000005038_jpg.rf.b3e0270ef4a9cbeedd4c524acd367f38.jpg
# Processing filename: 000000001942_jpg.rf.5ac2d72ba38fbcb553c1bff9364fa2f0.jpg
# Processing filename: 000000004772_jpg.rf.5acb4a15c77e0b823f1a38b187e13863.jpg
# Processing filename: 000000002217_jpg.rf.01b606de9e7fcf1ce60e36e1a5e80761.jpg
# Processing filename: 000000002951_jpg.rf.2eb2cde4e0a6d9145df7c80f08a75ba7.jpg
# Processing filename: 000000000643_jpg.rf.2edc159a6ad38fa4fa519a69d577b102.jpg
# Processing filename: 000000003764_jpg.rf.e148e074fec0d2205b2aa75a7dc16e38.jpg
# Processing filename: 000000003488_jpg.rf.02183fc946c7e44c7839834a622f86ec.jpg
# Processing filename: 000000003511_jpg.rf.877095012d104efef003b0d9337c4131.jpg
# Processing filename: 000000002964_jpg.rf.b489740b1c5e30ec6c60974e95986e52.jpg
# Processing filename: 000000004488_jpg.rf.2f72d02fc43f6a50ebe5d5af4f338a79.jpg
# Processing filename: 000000004057_jpg.rf.87c00be45e4de7b2f5794e9a7eb25ea6.jpg
# Processing filename: 000000005213_jpg.rf.02594faf63e4a71fb8594b9b6d42d83d.jpg
# Processing filename: 000000003464_jpg.rf.5b88fbd0d662ce03f5d308c0f80b52c2.jpg
# Processing filename: 000000000086_jpg.rf.87aa8da61f0be4ce7abd4159feba5950.jpg
# Processing filename: 000000003361_jpg.rf.025d84093e34985a33b23af7f74364a2.jpg
# Processing filename: 000000004140_jpg.rf.5ba67213e5f5251abaa212d90c474b78.jpg
# Processing filename: 000000002963_jpg.rf.b4f39339e4fef73c5f2aefd6d6b538ce.jpg
# Processing filename: 000000002279_jpg.rf.e24fa0beeb24da0d70a2bd5bc0810574.jpg
# Processing filename: 000000001053_jpg.rf.5c36d2950fdb2936e56d8dbd6ae4ecb2.jpg
# Processing filename: 000000000772_jpg.rf.b5731eabf5632d7217cc9e6b4c00db50.jpg
# Processing filename: 000000000308_jpg.rf.0317f56b1181aa1a40b53aedcf32ed2d.jpg
# Processing filename: 000000004125_jpg.rf.e28dafeb57ef6007493ef63b82c45988.jpg
# Processing filename: 000000003145_jpg.rf.88a1be42250e3be35077c1f69edcac17.jpg
# Processing filename: 000000003008_jpg.rf.88ba921e43dad102f8c50283b8d722b5.jpg
# Processing filename: 000000004796_jpg.rf.b5ff9cb8401f6796ea9825c97f0dde78.jpg
# Processing filename: 000000001025_jpg.rf.3072bf5ee003d877b10cae66459ea421.jpg
# Processing filename: 000000004108_jpg.rf.036dd068a714c3c8edd6dd1cc9f768a8.jpg
# Processing filename: 000000000321_jpg.rf.88dd15fb5fd34d7ae279bf042f8fe3db.jpg
# Processing filename: 000000002585_jpg.rf.b631179d83a1fc8c1afc20f4aa8c59b4.jpg
# Processing filename: 000000001667_jpg.rf.5cdaa4d7d5c9c6c1b7df0d27a62e6d12.jpg
# Processing filename: 000000001204_jpg.rf.e30734f2a8f1bed6b5f6f21dc2aa59d8.jpg
# Processing filename: 000000004093_jpg.rf.b64d57974e3de164301ecdebe2b48fe3.jpg
# Processing filename: 000000001579_jpg.rf.896df7ccc7a58d96f6fb09ed871c4a3f.jpg
# Processing filename: 000000001290_jpg.rf.893be55d5a11bcacde03f0e632522b99.jpg
# Processing filename: 000000001271_jpg.rf.b695b17d7caaea045ce3d9b5d1b9b0d7.jpg
# Processing filename: 000000002536_jpg.rf.043ff1b52896c83cb0223e73b40b7b93.jpg
# Processing filename: 000000004138_jpg.rf.0429c4c84f2ec82bf65f3444234bc6d5.jpg
# Processing filename: 000000001085_jpg.rf.5d8a7fa0a02f0379e84ea647878a54ef.jpg
# Processing filename: 000000002764_jpg.rf.5d86fa3340524abedc98bd88d7d7931c.jpg
# Processing filename: 000000000977_jpg.rf.5de712a10f822c39160a7e45b5d99599.jpg
# Processing filename: 000000001375_jpg.rf.e3b386d71f550f56be892ada4e324b78.jpg
# Processing filename: 000000000164_jpg.rf.89ef315e1c1c8cdd7e981d0a3925f53b.jpg
# Processing filename: 000000001590_jpg.rf.e3ed9e0135c9be921b33d57bc4a5bae2.jpg
# Processing filename: 000000001577_jpg.rf.e3bfec0323601041c2b7d49385a9ccbf.jpg
# Processing filename: 000000000902_jpg.rf.04e736a7147d955d481c5321dae50356.jpg
# Processing filename: 000000001757_jpg.rf.31c5fb76e7119cb920af2e3c355fd4f5.jpg
# Processing filename: 000000002374_jpg.rf.04d12a9e134c5e14fc734c7f22e57ddf.jpg
# Processing filename: 000000005324_jpg.rf.b7ca69553bf6b82b34277c52f41d2529.jpg
# Processing filename: 000000004704_jpg.rf.5eb4a743bccf48aa20d15e95c6447711.jpg
# Processing filename: 000000003478_jpg.rf.e45bb73fa4b91c9ed3d372aa59b889ab.jpg
# Processing filename: 000000004032_jpg.rf.5eb57cd34d34222e5b0451034a3ecd3a.jpg
# Processing filename: 000000003425_jpg.rf.b80cd37cfc7f4482862d72ffdabdf44b.jpg
# Processing filename: 000000002591_jpg.rf.5e83d9c34625c1396fc8011fc9a65ea8.jpg
# Processing filename: 000000001877_jpg.rf.326e76708f55dae110ad93c1f1a21157.jpg
# Processing filename: 000000002684_jpg.rf.8adf82c3d7eda59e815f0d9e63f52910.jpg
# Processing filename: 000000002179_jpg.rf.b85a4d363c0b90f4b8fdba34c0d10d71.jpg
# Processing filename: 000000001153_jpg.rf.b857055ce5a922aacc5532d813580fe4.jpg
# Processing filename: 000000004260_jpg.rf.05da1739268c5b4d21c2e2002dd5ae7c.jpg
# Processing filename: 000000004092_jpg.rf.5f8259f34a789e22ef794f700ecaafe2.jpg
# Processing filename: 000000002114_jpg.rf.8b5ff273e09a0a9380528f6c04374bcc.jpg
# Processing filename: 000000002164_jpg.rf.0609677ce78e6ed96a88825acc2217b9.jpg
# Processing filename: 000000001063_jpg.rf.e5349844721557ed0d48cd752361dca8.jpg
# Processing filename: 000000002703_jpg.rf.b8f250b610ce400ebeb0a3379fbb2eb7.jpg
# Processing filename: 000000002972_jpg.rf.8bbd38509bcb1e415963ed98347e49e9.jpg
# Processing filename: 000000004219_jpg.rf.e5981d95ddefc3b436ed489713e52cb0.jpg
# Processing filename: 000000000813_jpg.rf.0634a1099351ebef0b41f1b1022a6d91.jpg
# Processing filename: 000000003326_jpg.rf.3376e86a616591d6b0f7ff03dd394667.jpg
# Processing filename: 000000000542_jpg.rf.335b8968c9fbb3a9507106817ba675a2.jpg
# Processing filename: 000000001138_jpg.rf.b90680a0acb6405feca76d9112ef9daf.jpg
# Processing filename: 000000001668_jpg.rf.e5b474017304bcc4cccd5f4ca927dff6.jpg
# Processing filename: 000000000873_jpg.rf.33bd1046408bd8c1a22ca7b38928913f.jpg
# Processing filename: 000000000544_jpg.rf.e5a4375080347aed5db4fb4138d2b3e8.jpg
# Processing filename: 000000004731_jpg.rf.60155f59bf623b34a61dcb7f8ae246c3.jpg
# Processing filename: 000000003849_jpg.rf.b93d61fb7f8cd2f8adc3ba47b4c89c05.jpg
# Processing filename: 000000003160_jpg.rf.33bb12f97fdcfe528475a1a91716ca9c.jpg
# Processing filename: 000000005355_jpg.rf.33a3ef9fb47603369f77f820a7f02541.jpg
# Processing filename: 000000005099_jpg.rf.06b80790308007733eef5ca3d24a1698.jpg
# Processing filename: 000000004011_jpg.rf.8c1e9914e2a6aa32bd758bf8db0ce39e.jpg
# Processing filename: 000000001523_jpg.rf.06d9f48193aa3f12766fb9d71a65ea25.jpg
# Processing filename: 000000004891_jpg.rf.e65cd300bb0ebc569d5638fd8a1e8d14.jpg
# Processing filename: 000000005169_jpg.rf.e66f619974d2953527893912c91b0a78.jpg
# Processing filename: 000000000716_jpg.rf.b9f7d2dbbc9b76df53058b5073631a2f.jpg
# Processing filename: 000000001006_jpg.rf.6085228d9c2f751a8231237301c17758.jpg
# Processing filename: 000000003692_jpg.rf.0700689792dabc99b8ae61e49a7372a1.jpg
# Processing filename: 000000004227_jpg.rf.b9b970ec2aecefb1a542d32895dcbe32.jpg
# Processing filename: 000000001011_jpg.rf.072ef251bfd86e065c93493e9a2e3cc4.jpg
# Processing filename: 000000004421_jpg.rf.60fd812c2699bea2eef4e53bf162080c.jpg
# Processing filename: 000000002496_jpg.rf.60da41d166b9beda41ab02062bf2a829.jpg
# Processing filename: 000000004963_jpg.rf.e6aa75f51961e32e8e546612f04622da.jpg
# Processing filename: 000000004830_jpg.rf.345509c8d7ecb845e671854954da0f5b.jpg
# Processing filename: 000000000034_jpg.rf.e68a5f5d35ae1b039413a9114f27f7b9.jpg
# Processing filename: 000000000532_jpg.rf.e69c4150807c359eecd91d862b5a2878.jpg
# Processing filename: 000000004931_jpg.rf.8cd503ea5f04a99ba0a176b5e64b8b28.jpg
# Processing filename: 000000004936_jpg.rf.8d2fb8108073eb6c3019689f59f580a1.jpg
# Processing filename: 000000000939_jpg.rf.07bab3243705237a1f07c1ce1d77ff81.jpg
# Processing filename: 000000004904_jpg.rf.34e7b820c8219f86d631e35171652669.jpg
# Processing filename: 000000005356_jpg.rf.34cdbf6a654cf0f0bf86a2f7d75c91d1.jpg
# Processing filename: 000000003305_jpg.rf.8d53d881d6737e04e3dae75541318734.jpg
# Processing filename: 000000001431_jpg.rf.6152856e6d24767218efc0d545c29145.jpg
# Processing filename: 000000005174_jpg.rf.e753273b359a9c245dcdf8076f21aa46.jpg
# Processing filename: 000000005360_jpg.rf.07ed226c55a93a90ac44560f847f298d.jpg
# Processing filename: 000000001548_jpg.rf.baa693b327cbf305df61a9e590b258c6.jpg
# Processing filename: 000000002639_jpg.rf.ba8949e6121fd6d14cc60d4fdebec22d.jpg
# Processing filename: 000000005225_jpg.rf.616b292465273026ce69d427c04654b4.jpg
# Processing filename: 000000004673_jpg.rf.ba95d591d4de1cd5a5fd94a4232d5ad6.jpg
# Processing filename: 000000004736_jpg.rf.34f4e83a8e53526f019de22c67d09f1b.jpg
# Processing filename: 000000001098_jpg.rf.61467772215abab3a421636d3f66c48e.jpg
# Processing filename: 000000004762_jpg.rf.6199d0226a36f6dfe41755cb0c514f61.jpg
# Processing filename: 000000001216_jpg.rf.61aafac8919150469e28151de8ac4ed4.jpg
# Processing filename: 000000001064_jpg.rf.61a936033f178b1e9a4de6db32d21c58.jpg
# Processing filename: 000000004749_jpg.rf.08494f1ac3517bcb0c328c6a96caca46.jpg
# ...
# Processing filename: 20230209_125154_000999.jpg
# Processing filename: 20230209_125154_001016.jpg
# Processing filename: 20230209_125154_001040.jpg
# Processing filename: 20230209_125154_001010.jpg
# Processing filename: 20230209_124819_000818.jpg
# Processing filename: 20230209_125154_001035.jpg
# Processing filename: 20230209_125154_001043.jpg
# Processing filename: 20230209_125154_001014.jpg
# Processing filename: 20230209_124819_000823.jpg
# Processing filename: 20230209_125154_000998.jpg
# Processing filename: 20230209_124819_000802.jpg
# Processing filename: 20230209_125154_001042.jpg
# Processing filename: 20230209_125154_001032.jpg
# Processing filename: 20230209_124819_000803.jpg
# Processing filename: 20230209_125154_001000.jpg
# Processing filename: 20230209_124819_000808.jpg
# Processing filename: 20230209_125154_001012.jpg
# Processing filename: 20230209_125154_001015.jpg
# Processing filename: 20230209_124819_000807.jpg
# Processing filename: 20230209_125154_001036.jpg
# Processing filename: 20230209_125154_001004.jpg
# Processing filename: 20230209_125154_001033.jpg
# Processing filename: 20230209_125154_001002.jpg
# Processing filename: 20230209_124819_000809.jpg
# Processing filename: 20230209_124819_000806.jpg
# Processing filename: 20230209_124819_000816.jpg
# Processing filename: 20230209_124819_000805.jpg
# Processing filename: 20230209_125154_001005.jpg
# Processing filename: 20230209_125154_001011.jpg
# Processing filename: 20230209_125154_000996.jpg
# Processing filename: VID_20231001_123842_000001.jpg
# Processing filename: VID_20231001_123842_000000.jpg
# Processing filename: VID_20231001_123842_000002.jpg
# Processing filename: VID_20231001_123842_000003.jpg
# Processing filename: VID_20231001_123842_000032.jpg
# Processing filename: VID_20231001_123842_001262.jpg
# Processing filename: 1_000026.jpg
# Processing filename: 1_000040.jpg
# Processing filename: 1_000020.jpg
# Processing filename: 1_000025.jpg
# Processing filename: 1_000037.jpg
# Processing filename: 1_000041.jpg
# Processing filename: 1_000030.jpg
# Processing filename: 1_000004.jpg
# Processing filename: 1_000005.jpg
# Processing filename: 1_000022.jpg
# Processing filename: 1_000017.jpg
# Processing filename: 1_000038.jpg
# Processing filename: 1_000010.jpg
# Processing filename: 1_000042.jpg
# Processing filename: 1_000039.jpg
# Processing filename: 1_000009.jpg
# Processing filename: 1_000034.jpg
# Processing filename: 1_000035.jpg
# Processing filename: 1_000023.jpg
# Processing filename: 1_000031.jpg
# Processing filename: 1_000001.jpg
# Processing filename: 1_000027.jpg
# Processing filename: 1_000028.jpg
# Processing filename: 1_000011.jpg
# Processing filename: 1_000019.jpg
# Processing filename: 1_000000.jpg
# Processing filename: 1_000006.jpg
# Processing filename: 1_000021.jpg
# Processing filename: 1_000024.jpg
# Processing filename: 1_000007.jpg
# Processing filename: 1_000012.jpg
# Processing filename: 1_000014.jpg
# Processing filename: 1_000055.jpg
# Processing filename: 1_000102.jpg
# Processing filename: 1_000145.jpg
# Processing filename: 1_000054.jpg
# Processing filename: 1_000133.jpg
# Processing filename: 1_000045.jpg
# Processing filename: 1_000085.jpg
# Processing filename: 1_000108.jpg
# Processing filename: 1_000065.jpg
# Processing filename: 1_000124.jpg
# Processing filename: 1_000061.jpg
# Processing filename: 1_000155.jpg
# Processing filename: 1_000071.jpg
# Processing filename: 1_000077.jpg
# Processing filename: 1_000132.jpg
# Processing filename: 1_000149.jpg
# Processing filename: 1_000130.jpg
# Processing filename: 1_000075.jpg
# Processing filename: 1_000153.jpg
# Processing filename: 1_000097.jpg
# Processing filename: 1_000088.jpg
# Processing filename: 1_000115.jpg
# Processing filename: 1_000136.jpg
# Processing filename: 1_000123.jpg
# Processing filename: 1_000073.jpg
# Processing filename: 1_000148.jpg
# Processing filename: 1_000092.jpg
# Processing filename: 1_000084.jpg
# Processing filename: 1_000113.jpg
# Processing filename: 1_000126.jpg
# Processing filename: 1_000128.jpg
# Processing filename: 1_000069.jpg
# Processing filename: 1_000087.jpg
# Processing filename: 1_000080.jpg
# Processing filename: 1_000093.jpg
# Processing filename: 1_000122.jpg
# Processing filename: 1_000096.jpg
# Processing filename: 1_000078.jpg
# Processing filename: 1_000121.jpg
# Processing filename: 1_000076.jpg
# Processing filename: 1_000109.jpg
# Processing filename: 1_000137.jpg
# Processing filename: 1_000063.jpg
# Processing filename: 1_000053.jpg
# Processing filename: 1_000091.jpg
# Processing filename: 1_000118.jpg
# Processing filename: 1_000060.jpg
# Processing filename: 1_000095.jpg
# Processing filename: 1_000052.jpg
# Processing filename: 1_000099.jpg
# Processing filename: 1_000116.jpg
# Processing filename: 1_000127.jpg
# Processing filename: 1_000106.jpg
# Processing filename: 1_000086.jpg
# Processing filename: 1_000135.jpg
# Processing filename: 1_000051.jpg
# Processing filename: 1_000129.jpg
# Processing filename: 1_000094.jpg
# Processing filename: 1_000125.jpg
# Processing filename: 1_000104.jpg
# Processing filename: 1_000064.jpg
# Processing filename: 1_000048.jpg
# Processing filename: 1_000098.jpg
# Processing filename: 1_000067.jpg
# Processing filename: 1_000110.jpg
# Processing filename: 1_000154.jpg
# Processing filename: 1_000083.jpg
# Processing filename: 1_000134.jpg
# Processing filename: 1_000139.jpg
# Processing filename: 1_000050.jpg
# Processing filename: 1_000143.jpg
# Processing filename: 1_000107.jpg
# Processing filename: 1_000151.jpg
# Processing filename: 1_000070.jpg
# Processing filename: 1_000081.jpg
# Processing filename: 1_000190.jpg
# Processing filename: 1_000161.jpg
# Processing filename: 1_000193.jpg
# Processing filename: 1_000299.jpg
# Processing filename: 1_000225.jpg
# Processing filename: 1_000178.jpg
# Processing filename: 1_000286.jpg
# Processing filename: 1_000235.jpg
# Processing filename: 1_000280.jpg
# Processing filename: 1_000195.jpg
# Processing filename: 1_000175.jpg
# Processing filename: 1_000275.jpg
# Processing filename: 1_000281.jpg
# Processing filename: 1_000300.jpg
# Processing filename: 1_000197.jpg
# Processing filename: 1_000205.jpg
# Processing filename: 1_000258.jpg
# Processing filename: 1_000222.jpg
# Processing filename: 1_000240.jpg
# Processing filename: 1_000249.jpg
# Processing filename: 1_000251.jpg
# Processing filename: 1_000158.jpg
# Processing filename: 1_000297.jpg
# Processing filename: 1_000200.jpg
# Processing filename: 1_000291.jpg
# Processing filename: 1_000292.jpg
# Processing filename: 1_000203.jpg
# Processing filename: 1_000179.jpg
# Processing filename: 1_000230.jpg
# Processing filename: 1_000234.jpg
# Processing filename: 1_000246.jpg
# Processing filename: 1_000233.jpg
# Processing filename: 1_000239.jpg
# Processing filename: 1_000199.jpg
# Processing filename: 1_000293.jpg
# Processing filename: 1_000252.jpg
# Processing filename: 1_000241.jpg
# Processing filename: 1_000248.jpg
# Processing filename: 1_000170.jpg
# Processing filename: 1_000224.jpg
# Processing filename: 1_000287.jpg
# Processing filename: 1_000226.jpg
# Processing filename: 1_000167.jpg
# Processing filename: 1_000176.jpg
# Processing filename: 1_000231.jpg
# Processing filename: 1_000253.jpg
# Processing filename: 1_000259.jpg
# Processing filename: 1_000184.jpg
# Processing filename: 1_000242.jpg
# Processing filename: 1_000276.jpg
# Processing filename: 1_000236.jpg
# Processing filename: 1_000198.jpg
# Processing filename: 1_000194.jpg
# Processing filename: 1_000270.jpg
# Processing filename: 1_000273.jpg
# Processing filename: 1_000186.jpg
# Processing filename: 1_000238.jpg
# Processing filename: 1_000232.jpg
# Processing filename: 1_000255.jpg
# Processing filename: 1_000171.jpg
# Processing filename: 1_000201.jpg
# Processing filename: 1_000256.jpg
# Processing filename: 1_000285.jpg
# Processing filename: 1_000220.jpg
# Processing filename: 1_000263.jpg
# Processing filename: 1_000250.jpg
# Processing filename: 1_000157.jpg
# Processing filename: 1_000295.jpg
# Processing filename: 1_000243.jpg
# Processing filename: 1_000277.jpg
# Processing filename: 1_000191.jpg
# Processing filename: 1_000206.jpg
# Processing filename: 1_000260.jpg
# Processing filename: 1_000209.jpg
# Processing filename: 1_000156.jpg
# Processing filename: 1_000261.jpg
# Processing filename: 1_000212.jpg
# Processing filename: 1_000183.jpg
# Processing filename: 1_000169.jpg
# Processing filename: 1_000196.jpg
# Processing filename: 1_000160.jpg
# Processing filename: 1_000188.jpg
# Processing filename: 1_000294.jpg
# Processing filename: 1_000177.jpg
# Processing filename: 1_000272.jpg
# Processing filename: 1_000165.jpg
# Processing filename: 1_000264.jpg
# Processing filename: 1_000290.jpg
# Processing filename: 1_000278.jpg
# Processing filename: 1_000267.jpg
# Processing filename: 1_000172.jpg
# Processing filename: 1_000211.jpg
# Processing filename: 1_000162.jpg
# Processing filename: PXL_20240625_125208078.jpg
# Processing filename: PXL_20240625_125213023.jpg
# Processing filename: IMG-20210226-WA0062.jpg
# Processing filename: IMG-20201227-WA0009.jpg
# Processing filename: Sin título.jpeg
# Warning: Image or label file not found:
# Image: ./dataset/images/train/Sin título.jpeg
# Label: ./dataset/labels/train/Sin título.txt
# Processing filename: Virginia.jpeg
# Processing filename: Persons.jpeg
# Processing filename: PersonImg.jpeg
# Processing filename: Screenshot from 2024-09-26 10-29-54.png
# Processing filename: Screenshot from 2024-09-26 10-30-11.png
# Processing filename: Screenshot from 2024-09-26 10-30-20.png
# Processing filename: Screenshot from 2024-09-26 10-30-50.png
# Processing filename: Screenshot from 2024-09-26 10-30-58.png
# Processing filename: Screenshot from 2024-09-26 10-31-35.png
# Processing filename: Screenshot from 2024-09-26 10-31-35(1).png
# Processing filename: Screenshot from 2024-09-26 10-31-43.png
# Processing filename: Screenshot from 2024-09-26 10-32-15.png
# Processing filename: Screenshot from 2024-09-26 10-32-22.png
# Processing filename: Screenshot from 2024-09-26 10-32-38.png
# Processing filename: Screenshot from 2024-09-26 10-32-49.png
# Processing filename: Screenshot from 2024-09-26 10-32-57.png
# Processing filename: Screenshot from 2024-09-26 10-33-05.png
# Processing filename: Screenshot from 2024-09-26 10-33-20.png
# Processing filename: Screenshot from 2024-09-26 10-33-26.png
# Processing filename: Screenshot from 2024-09-26 10-33-32.png
# Processing filename: Screenshot from 2024-09-26 10-33-56.png
# Processing filename: Screenshot from 2024-09-26 10-34-27.png
# Processing filename: Screenshot from 2024-09-26 10-34-33.png
# Processing filename: Screenshot from 2024-09-26 10-34-37.png
# Processing filename: Screenshot from 2024-09-26 10-34-39.png
# Processing filename: Screenshot from 2024-09-26 10-34-55.png
# Processing filename: Screenshot from 2024-09-26 10-42-58.png
# Processing filename: Screenshot from 2024-09-26 10-44-02.png
# Processing filename: Screenshot from 2024-09-26 10-44-27.png
# Processing filename: Screenshot from 2024-09-26 10-45-12.png
# Processing filename: Screenshot from 2024-09-26 14-35-10.png
# Processing filename: Screenshot from 2024-09-26 14-35-39.png
# Processing filename: Screenshot from 2024-09-26 14-35-59.png
# Processing filename: Screenshot from 2024-09-26 14-36-22.png
# Processing filename: PXL_20240625_124735893.MP.jpg
# Processing filename: PXL_20240625_124641137.MP.jpg
# Processing filename: PXL_20240625_124701179.MP.jpg
# Processing filename: PXL_20240625_124710499.MP.jpg
# Processing filename: PXL_20240625_124638442.jpg
# Processing filename: PXL_20240625_124700084.MP.jpg
# Processing filename: PXL_20240625_124642349.jpg
# Processing filename: PXL_20240625_124758740.jpg
# Processing filename: PXL_20240625_130358554.jpg
# Processing filename: PXL_20240625_130440844.jpg
# Processing filename: PXL_20240625_144505677.jpg
# Processing filename: PXL_20240625_130437968.jpg
# Processing filename: Screenshot from 2024-10-11 10-56-42.png
# Processing filename: Screenshot from 2024-10-11 10-59-16.png
# Processing filename: Screenshot from 2024-10-11 10-59-29.png
# Processing filename: Screenshot from 2024-10-11 11-04-56.png
# Processing filename: Screenshot from 2024-10-11 11-05-12.png
# Processing filename: Screenshot from 2024-10-11 11-06-18.png
# Processing filename: Screenshot from 2024-10-11 11-06-23.png
# Processing filename: Screenshot from 2024-10-11 11-06-44.png
# Processing filename: Screenshot from 2024-10-11 11-06-54.png
# Processing filename: Screenshot from 2024-10-11 11-07-20.png
# Processing filename: Screenshot from 2024-10-11 11-07-29.png
# Processing filename: Screenshot from 2024-10-11 11-07-54.png
# Processing filename: Screenshot from 2024-10-11 11-09-36.png
# Processing filename: Screenshot from 2024-10-11 11-09-52.png
# Processing filename: Screenshot from 2024-10-11 11-10-12.png
# Processing filename: Screenshot from 2024-10-11 11-10-23.png
# Processing filename: Screenshot from 2024-10-11 11-10-34.png
# Processing filename: Screenshot from 2024-10-11 11-10-44.png
# Processing filename: Screenshot from 2024-10-11 11-10-59.png
# Processing filename: Screenshot from 2024-10-11 11-11-14.png
# Processing filename: Screenshot from 2024-10-11 11-11-33.png
# Processing filename: Screenshot from 2024-10-11 11-12-32.png
# Processing filename: Screenshot from 2024-10-11 11-12-41.png
# Processing filename: Screenshot from 2024-10-11 11-12-56.png
# Processing filename: Screenshot from 2024-10-11 11-13-08.png
# Processing filename: Screenshot from 2024-10-11 11-13-17.png
# Processing filename: Screenshot from 2024-10-11 11-15-21.png
# Processing filename: Screenshot from 2024-10-11 11-28-36.png
# Processing filename: 000000001813_jpg.rf.bdb2f481f90ec51a0954e5894e50eaa1.jpg
# Processing filename: 000000000315_jpg.rf.bdb978cc93a6caf0f715642f699cbbfb.jpg
# Processing filename: 000000000984_jpg.rf.909b52a57acaecdd782cec82af53253d.jpg
# Processing filename: 000000000731_jpg.rf.37cf59d0a75cc6249791d10677c05f5a.jpg
# Processing filename: 000000003272_jpg.rf.0ae922b5d5506a5c76282bf291ab6b6d.jpg
# Processing filename: 000000000761_jpg.rf.bdef8dd6c3edf66303a3340bb337c020.jpg
# Processing filename: 000000002402_jpg.rf.383e543105c8d99db4ff6e6a5e66ef97.jpg
# Processing filename: 000000005107_jpg.rf.eb8f9529df81d1863f8c5634f52de389.jpg
# Processing filename: 000000001799_jpg.rf.0b820ceb8520a0d493a5a36dc0bc8132.jpg
# Processing filename: 000000001166_jpg.rf.eb8a3fd9f13bc7f67122f352f6118828.jpg
# Processing filename: 000000000690_jpg.rf.eb9f8d40c1d8cf8a9b8533e015848f70.jpg
# Processing filename: 000000001781_jpg.rf.0bab519a7f94ebe9d160d60a62ef8f0a.jpg
# Processing filename: 000000001562_jpg.rf.ebd36cfc47ab56bce434767de12ad45b.jpg
# Processing filename: 000000004760_jpg.rf.be737ff9b9b2eb454a061b807db41347.jpg
# Processing filename: 000000002544_jpg.rf.65a09071e350b7325de2705ccdeab35d.jpg
# Processing filename: 000000001183_jpg.rf.9166671c01605e666a0a4c7f8fe899d8.jpg
# Processing filename: 000000003535_jpg.rf.0bbd712eebbe1564bbdb052f35bfcb96.jpg
# Processing filename: 000000001139_jpg.rf.38913d50dfed9c1450dae988be7045d4.jpg
# Processing filename: 000000000250_jpg.rf.0bf9c5de161689cee94781527125c4db.jpg
# Processing filename: 000000001264_jpg.rf.bed14d32dc09cb65520a2c276a15124d.jpg
# Processing filename: 000000004508_jpg.rf.65cfbaa4ae10ca712108937eac9e7949.jpg
# Processing filename: 000000002178_jpg.rf.38b09b64b1a461b7bca1f7375f4cf62a.jpg
# Processing filename: 000000004424_jpg.rf.bebe02bcb7eecc25dadf9d8e799a42a2.jpg
# Processing filename: 000000004130_jpg.rf.bf213bf1c730e177858e78fd58334570.jpg
# Processing filename: 000000000839_jpg.rf.0c470f50bd85093b9551d58d49d10434.jpg
# Processing filename: 000000000723_jpg.rf.9200f27d68dfe916798dcb0aaaded93e.jpg
# Processing filename: 000000000722_jpg.rf.ec400c3571c1cbb1b1794af001d806a5.jpg
# Processing filename: 000000000395_jpg.rf.662d1159a86b0dcd834bcd6483c02368.jpg
# Processing filename: 000000002154_jpg.rf.39234664e29c23308ac3dc2d02c62d81.jpg
# Processing filename: 000000000757_jpg.rf.0c4c0248799a5ade7615e690e46f6352.jpg
# Processing filename: 000000000781_jpg.rf.ecb32a0a9b42cb322753092f8e35ae84.jpg
# Processing filename: 000000002621_jpg.rf.ecfdcd15f1ee60b16b448331a0e563d5.jpg
# Processing filename: 000000004688_jpg.rf.0cc48c60714388d0abad8fc597e731f4.jpg
# Processing filename: 000000004173_jpg.rf.0cca545bb264648ff23aa008562744b7.jpg
# Processing filename: 000000002270_jpg.rf.66ee19da24a1d3d9853e13350abf228d.jpg
# Found 1033 image-label pairs.

# %%
import yaml
import os
import torch.utils.data as data
from utils import *
#from utils.newDataset import *

# get params from yaml file
with open('utils/args.yaml', errors='ignore') as f:
    params_dict = yaml.safe_load(f)  # Store original params in params_dict

# Access label names using params_dict
params_names = params_dict["names"]
# **Check if 'mosaic' key exists and handle it**
if 'mosaic' not in params_dict:
    # If 'mosaic' key is missing, set it to a default value (e.g., False)
    params_dict['mosaic'] = False  # Or any other default value you prefer
    print("Warning: 'mosaic' key not found in YAML. Setting it to False.")

labelnames = []
imagenames = []
image_label_pairs = images_labels
#print(f"Image-label pairs: {image_label_pairs}")  # Print the output of setNewPath

# Check if image_label_pairs is empty and handle the case
if not image_label_pairs:
    print("Error: No image-label pairs found. Check data_dir and setNewPath function.")
    # You might want to raise an exception here to stop execution
    raise ValueError("No image-label pairs found.") # Raise a ValueError to halt execution
else:
    for image_path, label_path in image_label_pairs:
        labelnames.append(label_path)
        imagenames.append(image_path)

print(f"Number of image names: {len(imagenames)}")
print(f"Number of label names: {len(labelnames)}")
input_size = 640
# Ensure that 'filenames' is being correctly assigned within your Mydataset class
train_data = Dataset(input_size=input_size, params=params_dict, augment=False, filenames=imagenames)
# Assuming 'filenames' is an attribute of Mydataset, make sure it's initialized

# Print the value of train_data.filenames to check if it's empty  -- Changed from train_datas to train_data
print(f"train_data.filenames: {train_data.filenames}")

# Check if the 'filenames' attribute of train_data is empty -- Changed from train_datas to train_data
if not train_data.filenames:
    print("Error: 'filenames' in train_data is empty. Check setNewPath or Dataset initialization.")
    # This will help pinpoint if the issue is with the file paths themselves
    # Print the first few elements of 'imagenames' for debugging
    print(f"First few imagenames: {imagenames[:5]}")  # Print first 5 for brevity
    raise ValueError("'filenames' in train_data is empty")

# Check if train_data has any samples before creating DataLoader -- Changed from train_datas to train_data
if len(train_data) == 0:
    print("Error: train_data is empty. Check your Dataset implementation.")
    # Consider raising an exception or fixing the Mydataset class
    raise ValueError("train_data is empty") # Raise a ValueError to halt execution if the dataset is empty
else:
    train_loader = data.DataLoader(train_data, batch_size=64, shuffle=True, num_workers=0, pin_memory=True, collate_fn=Dataset.collate_fn)
    print(f"Train_loader : {len(train_loader)} batches")
# Out:
# Number of image names: 1033
# Number of label names: 1033
# Warning: Invalid line in label file: ./dataset/labels/train/000000005340_jpg.rf.930ac45b0b9e7103562167dc8e408e1b.txt, Line: 73 0.198875 0.39971875 0.0033750000000000004 0.386234375 0.0016875000000000002 0.6693749999999999 0.40112500000000006 0.666015625 0.42978125 0.6811875 0.45337500000000003 0.660953125 0.4483125 0.660953125 0.45337500000000003 0.657578125 0.49381250000000004 0.65253125 0.561234375 0.65421875 0.6101093750000001 0.662640625 0.6505625 0.659265625 0.6539375 0.623875 0.7398906249999999 0.62725 0.7971874999999999 0.6205 0.7870781250000001 0.581734375 0.792140625 0.5733125 0.69775 0.49578125 0.57303125 0.4300625 0.43314062499999995 0.40309375000000003 0.198875 0.39971875
# Warning: Invalid line in label file: ./dataset/labels/train/000000004244_jpg.rf.672775c4b8cf6a8d540dbb51f307e443.txt, Line: 13 0.9038888890625 0.3696895421875 0.9042156859375 0.36704248359374997 0.90818627421875 0.36571895390625003 0.9068627453125 0.36406862734375 0.9032189539062501 0.3624019609375 0.8959477124999999 0.36339869296875 0.8946241828125 0.36472222187500003 0.8946241828125 0.36771241796875 0.8975980390625 0.36869281015625 0.89660130703125 0.3723366015625 0.8923039218750001 0.37366013046875 0.8913071898437501 0.37630718984375 0.8916503265625 0.3862418296875 0.90653594765625 0.3862418296875 0.9058823531250001 0.37498366015625 0.9062091499999999 0.37133986953125003 0.9038888890625 0.3696895421875
# Warning: Invalid line in label file: ./dataset/labels/train/000000004282_jpg.rf.0d469aaa6297b76cfa848b651b54ee27.txt, Line: 20 0.51014 0.50422 0.55574 0.50422 0.61486 0.50084 0.64358 0.50084 0.64696 0.50422 0.64864 0.51942 0.67736 0.5227999999999999 0.69764 0.50422 0.70608 0.5093 0.72466 0.5093 0.7381800000000001 0.5093 0.75844 0.51604 0.7652 0.5245 0.77196 0.52956 0.78548 0.52956 0.7973 0.51942 0.79898 0.51098 0.7804 0.49916 0.7618199999999999 0.48563999999999996 0.8057399999999999 0.4772 0.80744 0.47382 0.8057399999999999 0.46538 0.80236 0.44848 0.77196 0.43666 0.75676 0.45354 0.73648 0.45524 0.7212799999999999 0.44509999999999994 0.6925600000000001 0.43328 0.65202 0.42146 0.61486 0.40625999999999995 0.5793999999999999 0.40456000000000003 0.5473 0.40456000000000003 0.52196 0.39780000000000004 0.49832 0.39442 0.47804 0.39780000000000004 0.47128 0.36402 0.45608000000000004 0.34544 0.45946 0.33361999999999997 0.46114 0.31334 0.45608000000000004 0.31334 0.44088000000000005 0.32686000000000004 0.4375 0.32686000000000004 0.40878 0.32686000000000004 0.39527999999999996 0.33192 0.38006 0.32348 0.36656 0.31334 0.36994 0.32854 0.37838 0.35388000000000003 0.36824 0.36234 0.35642 0.37922 0.35304 0.39274 0.34965999999999997 0.40962 0.3429 0.41638000000000003 0.3429 0.43158 0.35136 0.44172 0.3598 0.45354 0.34628000000000003 0.4603 0.32602000000000003 0.46538 0.30912 0.46875999999999995 0.29392 0.46875999999999995 0.28378000000000003 0.4772 0.28378000000000003 0.48902 0.30068 0.48902 0.31418 0.4907 0.31082 0.49916 0.3125 0.5093 0.35304 0.51098 0.41554 0.50422 0.46114 0.50422 0.51014 0.50422
# Warning: Invalid line in label file: ./dataset/labels/train/000000002495_jpg.rf.92f50e5a3159158ec187f12bc44946ec.txt, Line: 70 0.72359477109375 0.7258496734375 0.75055555546875 0.71235294140625 0.7640522875 0.660669934375 0.7483169937499999 0.28315359453125 0.7258496734375 0.20449346406250002 0.678643790625 0.19325163437499998 0.5056209148437499 0.1955065359375 0.3303431375 0.1955065359375 0.28315359453125 0.24718954218750003 0.28988562109375 0.69437908515625 0.29663398671875 0.71235294140625 0.34382352968749996 0.7348366015625001 0.72359477109375 0.7258496734375
# Warning: Invalid line in label file: ./dataset/labels/train/000000002434_jpg.rf.675090866b8f1963557c442172004fc0.txt, Line: 21 0.7161875 0.5954843750000001 0.76153125 0.5900624999999999 0.76409375 0.5836718750000001 0.7599375 0.573453125 0.722578125 0.525875 0.6721250000000001 0.5287499999999999 0.671484375 0.537375 0.7075625 0.589421875 0.7161875 0.5954843750000001
# Warning: Invalid line in label file: ./dataset/labels/train/000000000241_jpg.rf.0dcbc0cbe7c97f092fa56eb357454ab0.txt, Line: 13 0.1895 0.95959375 0.187703125 0.9739531250000001 0.1921875 0.99640625 0.197578125 0.9982031250000001 0.20834375 1 0.22181250000000002 0.9982031250000001 0.228109375 0.9811406249999999 0.228109375 0.903921875 0.22540624999999997 0.893140625 0.21193749999999997 0.882375 0.21014062500000003 0.870703125 0.203859375 0.8653124999999999 0.19398437500000001 0.8697968749999999 0.193078125 0.8805781250000001 0.186796875 0.896734375 0.185 0.910203125 0.18140625 0.93625 0.18859375 0.941640625 0.193078125 0.947015625 0.1895 0.95959375
# Warning: Invalid line in label file: ./dataset/labels/train/000000004386_jpg.rf.6751aa49279db3e6fdec92e23883142d.txt, Line: 54 0.547546875 0.398203125 0.544625 0.38796875000000003 0.5124531250000001 0.3601875 0.51390625 0.3558125 0.5292656250000001 0.360921875 0.5292656250000001 0.352890625 0.5131875 0.338265625 0.49856249999999996 0.3316875 0.4788125 0.33387500000000003 0.46346875 0.34192187500000004 0.45689062500000005 0.3558125 0.45396875000000003 0.368234375 0.44957812500000005 0.369703125 0.43860937499999997 0.377734375 0.44079687500000003 0.396015625 0.44884375 0.40990624999999997 0.47296875 0.426 0.47296875 0.4230625 0.49270312499999996 0.42453124999999997 0.527078125 0.420140625 0.540234375 0.41503125 0.547546875 0.398203125
# Warning: Invalid line in label file: ./dataset/labels/train/000000001774_jpg.rf.c03def0de042681cb75c9809196c1185.txt, Line: 49 0.338703125 0.73203125 0.346171875 0.7305312500000001 0.35362499999999997 0.727546875 0.35362499999999997 0.714125 0.350640625 0.697703125 0.364078125 0.675328125 0.39540625 0.627578125 0.428234375 0.6022031250000001 0.45509374999999996 0.57684375 0.475984375 0.551484375 0.47748437499999996 0.5126875 0.47896875000000005 0.4649375 0.481953125 0.442546875 0.48792187499999995 0.432109375 0.504328125 0.42614062500000005 0.51328125 0.42315625 0.56103125 0.41271874999999997 0.589390625 0.390328125 0.601328125 0.378390625 0.6281875 0.3694375 0.635640625 0.366453125 0.638625 0.35303125 0.6281875 0.344078125 0.611765625 0.3470625 0.601328125 0.35750000000000004 0.5580468749999999 0.38734375 0.540140625 0.3933125 0.5311874999999999 0.40078125 0.49240625 0.391828125 0.453609375 0.38734375 0.44167187500000005 0.38734375 0.4386875 0.36198437499999997 0.43121875000000004 0.342578125 0.41481250000000003 0.33959375 0.39690625 0.348546875 0.3909375 0.367953125 0.3909375 0.390328125 0.386453125 0.396296875 0.36257812500000003 0.408234375 0.3431875 0.424640625 0.328265625 0.432109375 0.32229687500000004 0.43657812500000004 0.31632812499999996 0.438078125 0.3208125 0.424640625 0.3208125 0.415703125 0.31484375 0.4171875 0.311859375 0.41867187499999997 0.2954375 0.41867187499999997 0.287984375 0.42762500000000003 0.286484375 0.438078125 0.28946875 0.450015625 0.298421875 0.45746875 0.299921875 0.45896875000000004 0.31334375 0.46343750000000006 0.33721875 0.45746875 0.35362499999999997 0.453 0.3655625 0.45149999999999996 0.374515625 0.45896875000000004 0.38496874999999997 0.49328125 0.380484375 0.5126875 0.370046875 0.532078125 0.352140625 0.549984375 0.310359375 0.6425 0.307375 0.667859375 0.299921875 0.68278125 0.2954375 0.697703125 0.27156250000000004 0.70665625 0.256640625 0.712625 0.252171875 0.7260625 0.262609375 0.73203125 0.287984375 0.740984375 0.307375 0.74396875 0.334234375 0.74396875 0.338703125 0.73203125
# Warning: Invalid line in label file: ./dataset/labels/train/000000005154_jpg.rf.3a54bcd90ded80c23814a7774a3168d8.txt, Line: 7 0.25 0.373046875 0.58203125 0.865234375 0.8125 0.85546875 0.935546875 0.7734375 0.908203125 0.734375 0.8828125 0.6796875 1 0.62109375 0.9921875 0.369140625 0.869140625 0.375 0.822265625 0.35546875 0.783203125 0.3203125 0.626953125 0.267578125 0.515625 0.203125 0.44140625 0.1796875 0.287109375 0.20703125 0.220703125 0.244140625 0.21875 0.2421875 0.228515625 0.31640625 0.25 0.373046875
# Warning: Invalid line in label file: ./dataset/labels/train/000000005180_jpg.rf.3a809a4d32cdfdf4b8178d2f59d6d5c0.txt, Line: 55 0.21403124999999998 0.33346875 0.2148125 0.326703125 0.22131249999999997 0.324609375 0.241359375 0.299375 0.259578125 0.273859375 0.27728125000000003 0.2535625 0.29159375 0.218421875 0.29367187499999997 0.199421875 0.294453125 0.18146875 0.287421875 0.15909374999999998 0.27337500000000003 0.144 0.2593125 0.138265625 0.249171875 0.13670312499999998 0.2463125 0.13279687499999998 0.242921875 0.126296875 0.23875000000000002 0.127328125 0.23459375 0.131765625 0.22912499999999997 0.129421875 0.22939062500000001 0.12265625 0.23329687500000001 0.1125 0.23771874999999998 0.10287500000000001 0.24006249999999998 0.092203125 0.230171875 0.08803125 0.22209374999999998 0.0885625 0.2210625 0.08985937499999999 0.22053124999999998 0.09896875000000001 0.218203125 0.124734375 0.21637499999999998 0.13540625 0.21246874999999998 0.159609375 0.21065625 0.171578125 0.207 0.202546875 0.20284375 0.211140625 0.20232812500000003 0.221296875 0.20414062500000002 0.234296875 0.19815624999999998 0.276984375 0.19165625 0.28584375 0.18853124999999998 0.307953125 0.181234375 0.318109375 0.176296875 0.321234375 0.165890625 0.31759375 0.16328125 0.31525 0.157296875 0.299375 0.15053125 0.292609375 0.147671875 0.286359375 0.12892187500000002 0.246015625 0.129453125 0.240296875 0.128671875 0.22675 0.12059375000000001 0.21973437499999998 0.11695312499999999 0.212703125 0.108109375 0.192140625 0.08546875000000001 0.13853125 0.06932812499999999 0.106515625 0.061 0.10989062499999999 0.05682812499999999 0.11484375 0.05682812499999999 0.12290625 0.061 0.164546875 0.057609375 0.164296875 0.039921875 0.17365625 0.0295 0.184078125 0.019359375 0.20437500000000003 0.019609375000000002 0.218171875 0.027421875000000002 0.24706250000000002 0.034453125 0.261375 0.044859375 0.275171875 0.06646875 0.295734375 0.08156250000000001 0.306140625 0.12345312500000001 0.330609375 0.142203125 0.342046875 0.144796875 0.34465625 0.151046875 0.35584375 0.160765625 0.372484375 0.15484375 0.443484375 0.15523437499999998 0.5046406250000001 0.16115625 0.5357968750000001 0.164703125 0.530671875 0.17259375 0.506609375 0.189953125 0.45532812500000003 0.197046875 0.421 0.212828125 0.44546875 0.2250625 0.46399999999999997 0.228609375 0.46637500000000004 0.24203125 0.46125 0.23650000000000002 0.43875000000000003 0.21440625 0.38273437499999996 0.21012499999999998 0.37171875 0.20753125 0.36053125 0.21403124999999998 0.33346875
# Warning: Invalid line in label file: ./dataset/labels/train/000000002759_jpg.rf.c0a3dee4098564eac8092c6bad4302f1.txt, Line: 27 0.9991875 0.1671875 0.0015 0.170171875 0 0.8313124999999999 1 0.8313124999999999 0.9991875 0.1671875
# Warning: Invalid line in label file: ./dataset/labels/train/000000001522_jpg.rf.3a8c0c81b918a3071981e79484eafa3c.txt, Line: 23 0.79812 0.12678 0.7923 0.12969999999999998 0.7874399999999999 0.13552 0.78406 0.14668 0.78502 0.15345999999999999 0.79278 0.16655999999999999 0.80152 0.1685 0.80928 0.16898 0.81606 0.16462000000000002 0.8209199999999999 0.15832 0.8243199999999999 0.14958 0.8262600000000001 0.14423999999999998 0.82528 0.13552 0.8223800000000001 0.13066 0.81946 0.12532000000000001 0.81462 0.12582 0.8054 0.12582 0.79812 0.12678
# Warning: Invalid line in label file: ./dataset/labels/train/000000000699_jpg.rf.67a8c76d738a9e1111acd34b5f685efe.txt, Line: 72 0.238475 0.59180625 0.22440000000000002 0.35285625 0.074475 0.35753124999999997 0.0733 0.57308125 0.238475 0.59180625
# Warning: Invalid line in label file: ./dataset/labels/train/000000000897_jpg.rf.6777908a16c4f75cbb4fb7cb5b198c36.txt, Line: 49 0.43029687499999997 0.45137499999999997 0.45728125000000003 0.463359375 0.46628125000000004 0.482859375 0.44529687500000004 0.51884375 0.419796875 0.562328125 0.41231249999999997 0.599796875 0.41829687499999996 0.64178125 0.42279687499999996 0.70625 0.439296875 0.7377343749999999 0.46778125 0.76471875 0.500765625 0.77371875 0.53225 0.748234375 0.53825 0.71675 0.514265625 0.691265625 0.515765625 0.6702656250000001 0.581734375 0.683765625 0.646203125 0.679265625 0.6716875 0.695765625 0.7046718750000001 0.742234375 0.760140625 0.733234375 0.754140625 0.680765625 0.74065625 0.614796875 0.802125 0.5713125 0.844109375 0.493359375 0.8471093749999999 0.43937499999999996 0.8590937500000001 0.409390625 0.886078125 0.43637499999999996 0.9115781249999999 0.437875 0.916078125 0.39290625 0.8875781249999999 0.350921875 0.8411093749999999 0.30293749999999997 0.812625 0.3209375 0.7796406250000001 0.41089062500000006 0.73165625 0.50984375 0.685171875 0.52184375 0.6671875 0.50684375 0.6506875 0.485859375 0.60721875 0.449875 0.60421875 0.442375 0.59671875 0.43187499999999995 0.572734375 0.398890625 0.52325 0.38090625 0.512765625 0.3134375 0.49626562500000004 0.29693749999999997 0.47828125000000005 0.3074375 0.45578124999999997 0.340421875 0.44529687500000004 0.38390625 0.433296875 0.412390625 0.43029687499999997 0.45137499999999997
# Warning: Invalid line in label file: ./dataset/labels/train/000000005394_jpg.rf.ee0eddf483df75f35628ab3bc9a1bcad.txt, Line: 11 0.097890625 0.5310625 0.10860937500000001 0.543734375 0.20309375 0.56515625 0.26253125 0.562234375 0.28590625 0.5534687500000001 0.289796875 0.539828125 0.316109375 0.5534687500000001 0.429109375 0.533984375 0.4446875 0.5193749999999999 0.462234375 0.509625 0.473921875 0.5261875 0.49048437500000003 0.523265625 0.49535937499999994 0.50184375 0.49437499999999995 0.4648125 0.474890625 0.455078125 0.428140625 0.4463125 0.39696875 0.44923437499999996 0.35215625 0.4463125 0.343375 0.42975 0.316109375 0.41903125 0.26545312499999996 0.424875 0.23135937499999998 0.41415625 0.230375 0.424875 0.20407812500000003 0.456046875 0.193359375 0.459953125 0.20407812500000003 0.470671875 0.17776562499999998 0.47553124999999996 0.120296875 0.50184375 0.11737500000000001 0.5057343750000001 0.11737500000000001 0.509625 0.097890625 0.5310625
# Warning: Invalid line in label file: ./dataset/labels/train/000000001554_jpg.rf.67acc5ee43e961d100b956d50a1b947e.txt, Line: 56 0.2935 0.7992343749999999 0.296375 0.774890625 0.306390625 0.762 0.30924999999999997 0.7634375 0.320703125 0.782046875 0.329296875 0.782046875 0.33215625000000004 0.7791875 0.336453125 0.7720312500000001 0.327859375 0.753421875 0.33359375 0.730515625 0.33503125 0.72478125 0.343609375 0.713328125 0.34934375 0.71046875 0.367953125 0.7219218749999999 0.3708125 0.730515625 0.36509375 0.746265625 0.35935937500000004 0.762 0.3550625 0.783484375 0.360796875 0.806390625 0.362234375 0.8092499999999999 0.3708125 0.797796875 0.3708125 0.782046875 0.37225 0.764875 0.377984375 0.746265625 0.388 0.729078125 0.390859375 0.7204843750000001 0.4051875 0.690421875 0.40660937500000005 0.67896875 0.40660937500000005 0.667515625 0.40660937500000005 0.654625 0.400890625 0.6403125000000001 0.400890625 0.6116718750000001 0.4023125 0.603078125 0.40374999999999994 0.590203125 0.4051875 0.573015625 0.40660937500000005 0.5701562499999999 0.4180625 0.558703125 0.42951562499999996 0.558703125 0.43810937499999997 0.55584375 0.446703125 0.5486718749999999 0.446703125 0.54009375 0.44526562500000005 0.53721875 0.43525 0.52434375 0.4338125 0.518609375 0.43239062500000003 0.50859375 0.4338125 0.50715625 0.45242187500000003 0.48998437499999997 0.43525 0.49140625 0.420921875 0.49284375 0.390859375 0.495703125 0.367953125 0.495703125 0.36365625 0.495703125 0.35078125 0.494265625 0.34075 0.49284375 0.33215625000000004 0.48998437499999997 0.320703125 0.48998437499999997 0.313546875 0.497140625 0.34075 0.512890625 0.3579375 0.520046875 0.360796875 0.52434375 0.36509375 0.541515625 0.36509375 0.55584375 0.36365625 0.574453125 0.337890625 0.5644218750000001 0.307828125 0.563 0.30209375 0.563 0.27203125 0.573015625 0.259140625 0.5859062500000001 0.24626562500000002 0.604515625 0.24626562500000002 0.621703125 0.24626562500000002 0.6403125000000001 0.250546875 0.66178125 0.25484375 0.673234375 0.25771875 0.6846875 0.25771875 0.701875 0.25198437500000004 0.711890625 0.24912499999999999 0.736234375 0.25484375 0.744828125 0.25771875 0.75484375 0.2634375 0.7791875 0.2634375 0.78778125 0.276328125 0.7992343749999999 0.2935 0.7992343749999999
# Warning: Invalid line in label file: ./dataset/labels/train/000000004157_jpg.rf.ee5e47170e7585421fac70223a1e3295.txt, Line: 13 0.7888235296875 0.7734150328125 0.78089869296875 0.7655065359375001 0.78089869296875 0.755604575 0.7690196078125 0.7397712421875 0.8026633984375 0.7318627453125 0.79673202578125 0.6645588234375001 0.7611111109375 0.6645588234375001 0.7551633984375 0.6843627453125001 0.74330065390625 0.7753921570312501 0.7888235296875 0.7734150328125
# Warning: Invalid line in label file: ./dataset/labels/train/000000002555_jpg.rf.0e23195b581858e5673e7f95aa3de415.txt, Line: 49 0.632068965625 0.25241379296875 0.6521674875000001 0.26405582890625 0.67121510703125 0.23655172421874998 0.757996715625 0.22172413828124998 0.77492610859375 0.21114942499999997 0.79397372734375 0.2005582921875 0.82254515625 0.23548440078125 0.8299507390624999 0.22702791484375 0.89238095234375 0.21750410546875001 0.89238095234375 0.24183908046874997 0.89238095234375 0.25876847265624997 0.90931034453125 0.29050903125 0.925188834375 0.2915763546875 0.925188834375 0.2831034484375 0.92413793125 0.24712643671875 0.9230706078124999 0.1984564859375 0.915665025 0.16669950703125 0.9262561578125 0.15929392421875 0.9304761906250001 0.14660098515625 0.9167323484375001 0.13495894921875 0.89766830859375 0.1169622328125 0.8870935960937499 0.11484400624999999 0.87968801328125 0.12860426953124998 0.8574712640625 0.12119868671875 0.77704433515625 0.13812807890625 0.7675205257812501 0.16246305390625 0.7643349749999999 0.1836289 0.74847290625 0.18893267656249998 0.7273070609375 0.19210180625 0.70825944140625 0.1984564859375 0.68285714296875 0.20586206875 0.6458128078125001 0.22067323515625 0.6489983578125 0.21750410546875001 0.6310016421875 0.23336617421875 0.632068965625 0.25241379296875
# Warning: Invalid line in label file: ./dataset/labels/train/000000001739_jpg.rf.3a9e43306052bfa6af273b13bf14b6d5.txt, Line: 74 0.61121875 0.73846875 0.7268125000000001 0.75271875 0.791734375 0.74796875 0.7854062500000001 0.646625 0.65396875 0.5785312499999999 0.6318125 0.55003125 0.22643749999999999 0.55478125 0.2026875 0.580125 0.185265625 0.538953125 0.166265625 0.641875 0.161515625 0.7226250000000001 0.180515625 0.740046875 0.362609375 0.735296875 0.61121875 0.73846875
# Warning: Invalid line in label file: ./dataset/labels/train/000000000828_jpg.rf.93e4a8c6b56ac879a30103dd6f433874.txt, Line: 49 0.570921875 0.47748437499999996 0.567359375 0.466796875 0.568078125 0.45753125 0.5730625 0.44542187499999997 0.58090625 0.43187499999999995 0.588734375 0.42546875 0.5951562499999999 0.42903125 0.606546875 0.43259375 0.6094062499999999 0.4283125 0.6136874999999999 0.42190625 0.62365625 0.41690625 0.632921875 0.4140625 0.63434375 0.4211875 0.628640625 0.42973437499999995 0.6072656249999999 0.45112500000000005 0.5873125 0.47748437499999996 0.5787656250000001 0.500296875 0.585890625 0.5166875 0.599421875 0.543765625 0.6115468749999999 0.56728125 0.6115468749999999 0.576546875 0.600859375 0.5879531250000001 0.5873125 0.5965 0.5980000000000001 0.5965 0.6208125 0.59365625 0.63434375 0.58509375 0.637203125 0.579390625 0.63434375 0.569421875 0.629359375 0.55659375 0.625078125 0.54234375 0.625796875 0.5309375000000001 0.61225 0.5159687500000001 0.6208125 0.52025 0.630078125 0.5280781250000001 0.632921875 0.52025 0.63934375 0.51953125 0.6507343750000001 0.548046875 0.651453125 0.568 0.647171875 0.5801093749999999 0.636484375 0.587234375 0.6421875 0.59221875 0.654296875 0.590796875 0.67425 0.5843906249999999 0.6813906249999999 0.579390625 0.6813906249999999 0.572265625 0.67140625 0.562296875 0.664984375 0.51271875 0.6564375 0.5013124999999999 0.66071875 0.49328125 0.6756875 0.48045312500000004 0.6899375 0.46690624999999997 0.7041875 0.4519375 0.709890625 0.436265625 0.6984843749999999 0.39453125 0.691359375 0.37671875 0.67853125 0.359609375 0.664984375 0.3439375 0.65359375 0.33609374999999997 0.640046875 0.32682812499999997 0.621515625 0.32610937500000003 0.614390625 0.322546875 0.6115468749999999 0.311859375 0.607984375 0.30403125000000003 0.600140625 0.29190625 0.5873125 0.286203125 0.5730625 0.287640625 0.56165625 0.30971875 0.5538125 0.315421875 0.5523906249999999 0.3246875 0.5602343750000001 0.322546875 0.566640625 0.321125 0.570203125 0.331109375 0.571640625 0.33965625 0.57234375 0.3439375 0.567359375 0.353203125 0.5695 0.376 0.5695 0.39525 0.563796875 0.411640625 0.56165625 0.42659375 0.559515625 0.44085937499999994 0.5538125 0.455109375 0.548828125 0.465796875 0.5452656250000001 0.47434374999999995 0.5516875 0.48146875 0.5545312499999999 0.481765625 0.56521875 0.48246874999999995 0.570921875 0.47748437499999996
# Warning: Invalid line in label file: ./dataset/labels/train/000000001360_jpg.rf.93fb98149b84679542d39f394139ab56.txt, Line: 28 0.5746241828125 0.8291993460937499 0.5676633984375 0.8048366015624999 0.548513071875 0.79555555546875 0.53982026171875 0.79960784296875 0.5375 0.80599673203125 0.5415522875 0.81120915 0.5415522875 0.814117646875 0.5386601304687499 0.82049019609375 0.5450326796875 0.8297712421875 0.54562091484375 0.8326797382812501 0.53923202578125 0.8291993460937499 0.5345915031249999 0.82687908515625 0.5282189539062501 0.828039215625 0.5206699343750001 0.8309313726562501 0.5206699343750001 0.83789215703125 0.516617646875 0.8419607843750001 0.51486928125 0.83964052265625 0.51545751640625 0.8309313726562501 0.5113888890625 0.82687908515625 0.50906862734375 0.8257189539062499 0.51254901953125 0.8216503265625 0.5102287578125 0.8187581703125 0.5044281046875 0.8164379085937499 0.49630718984375 0.81700980390625 0.4887581703125 0.8239705882812499 0.4875980390625 0.8332516343749999 0.48527777812500006 0.8448692812499999 0.48470588203125003 0.8541503265625 0.47831699375000003 0.8634313726562499 0.470196078125 0.8790849671875 0.4696241828125 0.8889542484374999 0.47194444453125 0.9034640523437499 0.4667156859375 0.92434640546875 0.467303921875 0.9452287578125 0.4638235296875 0.9568300656250001 0.453382353125 0.96669934609375 0.60710784296875 0.96669934609375 0.610604575 0.9521895421875 0.60944444453125 0.9347875820312501 0.610604575 0.91970588203125 0.59782679765625 0.88663398671875 0.5850653593749999 0.85995098046875 0.5705718953125001 0.8483496734375 0.5746241828125 0.8291993460937499
# Warning: Invalid line in label file: ./dataset/labels/train/000000002752_jpg.rf.ee747ec531edbbe5856cfd6240737eb0.txt, Line: 75 0.7819 0.51078 0.80748 0.51998 0.82284 0.50054 0.85456 0.49644000000000005 0.87912 0.50976 0.8944599999999999 0.53124 0.92516 0.5353399999999999 0.9282199999999999 0.3839 0.7819 0.39004 0.786 0.48826 0.7819 0.51078
# Warning: Invalid line in label file: ./dataset/labels/train/000000003935_jpg.rf.94112bfcfd0044af0d3af4c753cdae35.txt, Line: 20 0.415125 0.59715625 0.44678125 0.582265625 0.49517187500000004 0.574828125 0.5175156249999999 0.5524843749999999 0.543578125 0.5413125 0.524953125 0.51153125 0.5454375 0.505953125 0.6347968749999999 0.50221875 0.720421875 0.50221875 0.8712031250000001 0.479890625 0.919609375 0.46126562499999996 0.95684375 0.40542187500000004 0.994078125 0.325375 0.94009375 0.24904687499999997 0.8674843750000001 0.072203125 0.21779687499999997 0.068484375 0.1824375 0.10198437499999999 0.13960937499999998 0.1355 0.11356250000000001 0.20623437500000003 0.10610937499999999 0.187625 0.070734375 0.21926562500000002 0.0595625 0.2639375 0.052125 0.301171875 0.07446875 0.35143749999999996 0.08190625 0.412875 0.10610937499999999 0.45568749999999997 0.17684375000000002 0.50221875 0.18615625 0.52828125 0.21593749999999998 0.5487656249999999 0.24571874999999999 0.5580625 0.243859375 0.565515625 0.353703125 0.5952968750000001 0.415125 0.59715625
# Warning: Invalid line in label file: ./dataset/labels/train/000000000531_jpg.rf.ee9d89e649144b7d9bb0172001c7c77c.txt, Line: 9 0.077359375 0.566515625 0.07821875 0.5685625 0.07975 0.5704374999999999 0.082140625 0.571296875 0.08590624999999999 0.571125 0.089140625 0.57078125 0.091703125 0.56975 0.093921875 0.567015625 0.094609375 0.564125 0.094953125 0.561390625 0.093921875 0.5586562500000001 0.092390625 0.55678125 0.090515625 0.555078125 0.091875 0.553703125 0.097515625 0.5607031250000001 0.097 0.56240625 0.097859375 0.563609375 0.098703125 0.563609375 0.10040625 0.563609375 0.1014375 0.564125 0.10246875 0.565484375 0.10365625 0.567875 0.10501562499999999 0.5685625 0.109625 0.5685625 0.11253125 0.567359375 0.11492187499999999 0.56496875 0.11595312499999999 0.561046875 0.11560937499999999 0.5560937499999999 0.11390625000000001 0.553359375 0.11100000000000002 0.5526875 0.1084375 0.5525156250000001 0.10604687500000001 0.55353125 0.10400000000000001 0.552171875 0.10484374999999999 0.550125 0.10604687500000001 0.548921875 0.10774999999999998 0.54875 0.10860937500000001 0.5472187500000001 0.102125 0.547046875 0.10092187500000001 0.54790625 0.102125 0.5504687500000001 0.096828125 0.550640625 0.09478125 0.54978125 0.09614062500000001 0.547734375 0.0925625 0.547734375 0.09221875 0.5451718750000001 0.09 0.545 0.089140625 0.5465312499999999 0.09034375 0.5475625 0.09034375 0.548921875 0.088296875 0.551828125 0.088125 0.55353125 0.084703125 0.553703125 0.08078125 0.555078125 0.078046875 0.557640625 0.07634375 0.5601875 0.07634375 0.5634375 0.076515625 0.562578125 0.076515625 0.563609375 0.077359375 0.566515625
# Warning: Invalid line in label file: ./dataset/labels/train/000000002782_jpg.rf.3b1797cd25dd1a3afb838fe4b232cb84.txt, Line: 49 0.557671875 0.39853125 0.566515625 0.376390625 0.553234375 0.36753125 0.5488125 0.36421875 0.5510312500000001 0.35203125 0.5510312500000001 0.342078125 0.5510312500000001 0.337640625 0.5543437499999999 0.33321875 0.544390625 0.303328125 0.53553125 0.293359375 0.52334375 0.28340624999999997 0.5211406249999999 0.27896875 0.52225 0.26015625 0.518921875 0.25129687500000003 0.508953125 0.24465625000000002 0.5023125 0.24465625000000002 0.49678125 0.2501875 0.49235937500000004 0.26237499999999997 0.49235937500000004 0.274546875 0.48792187499999995 0.28118750000000003 0.4835 0.28340624999999997 0.476859375 0.28671875 0.46578125000000004 0.297796875 0.45804687499999996 0.324359375 0.448078125 0.33875 0.4525 0.35425 0.45804687499999996 0.36310937499999996 0.4414375 0.366421875 0.43921875000000005 0.3775 0.4525 0.389671875 0.459140625 0.40295312499999997 0.463578125 0.42067187500000003 0.46578125000000004 0.43395312500000005 0.480171875 0.428421875 0.49235937500000004 0.423984375 0.490140625 0.40959375 0.48571875000000003 0.39853125 0.49456249999999996 0.40184375 0.499 0.416234375 0.507859375 0.42176562500000003 0.50675 0.422875 0.5211406249999999 0.431734375 0.5288906250000001 0.431734375 0.52778125 0.42067187500000003 0.557671875 0.39853125
# Warning: Invalid line in label file: ./dataset/labels/train/000000000061_jpg.rf.eeaf447e1d2e603c13a451bdbaadf6cd.txt, Line: 49 0.4174375 0.5299375000000001 0.42601562499999995 0.5285 0.43317187500000004 0.527796875 0.4381875 0.517765625 0.444625 0.506328125 0.446765625 0.50203125 0.47109375 0.49917187500000004 0.47681250000000003 0.49989062500000003 0.48324999999999996 0.48271875 0.47753125 0.45695312499999996 0.46965625 0.444078125 0.4639375 0.4405 0.45821875 0.4419375 0.454640625 0.44837499999999997 0.454640625 0.45625 0.458921875 0.46482812500000004 0.46107812499999995 0.46984375 0.44890625 0.48414062500000005 0.440328125 0.484859375 0.43103125000000003 0.48915625 0.43103125000000003 0.498453125 0.426734375 0.506328125 0.42387499999999995 0.5091875 0.418859375 0.512765625 0.41528124999999994 0.512046875 0.40884375000000006 0.510625 0.40812499999999996 0.512046875 0.42315625 0.5235000000000001 0.42959375 0.5235000000000001 0.41814062500000004 0.5256406250000001 0.4174375 0.5299375000000001
# Warning: Invalid line in label file: ./dataset/labels/train/000000001626_jpg.rf.688ccd0dcac9d9fc068a9ad37b571f16.txt, Line: 51 0.9916 0.44684 0.97826 0.45686 0.95268 0.42684 0.92154 0.41459999999999997 0.87928 0.43018 0.84816 0.4324 0.83592 0.46464 0.81146 0.4524 0.79478 0.46352000000000004 0.7681 0.48019999999999996 0.78144 0.51356 0.7781 0.5258 0.75698 0.55138 0.75586 0.58362 0.77922 0.5969599999999999 0.77032 0.62032 0.77032 0.63144 0.78366 0.65144 0.79034 0.66368 0.8103400000000001 0.6670200000000001 0.8103400000000001 0.6848 0.83036 0.69482 0.82814 0.74486 0.84816 0.75264 0.9304399999999999 0.7548600000000001 0.99938 0.75042 0.99938 0.7281799999999999 0.9982599999999999 0.74708 1 0.44573999999999997 0.9916 0.44684
# Warning: Invalid line in label file: ./dataset/labels/train/000000000982_jpg.rf.3b792be6ff75b543d9d0ae8c35a96677.txt, Line: 17 0.740734375 0.3505625 0.740734375 0.33034375 0.7834218749999999 0.307859375 0.8036562500000001 0.211234375 0.790171875 0.141578125 0.760953125 0.089890625 0.69578125 0.089890625 0.617140625 0.12809375 0.5699375 0.1955 0.5699375 0.21798437499999998 0.50253125 0.22921874999999997 0.45982812500000003 0.139328125 0.3744375 0.10112499999999999 0.318265625 0.094375 0.23960937499999999 0.1505625 0.223875 0.2 0.25309375 0.307859375 0.331734375 0.37528125 0.30253125000000003 0.4494375 0.316015625 0.46517187499999996 0.228375 0.505625 0.228375 0.588765625 0.307015625 0.7325781250000001 0.3699375 0.77753125 0.408140625 0.8516875 0.4755625 0.8898906249999999 0.52725 0.8876406250000001 0.52275 0.9011250000000001 0.760953125 0.6494375 0.7834218749999999 0.568546875 0.785671875 0.42471875 0.740734375 0.3505625
# Warning: Invalid line in label file: ./dataset/labels/train/000000003947_jpg.rf.eed31184de003f46e5ce3835d258da84.txt, Line: 56 0.3609803921875 0.86120915 0.3641503265625 0.862777778125 0.3641503265625 0.86356209140625 0.375196078125 0.86356209140625 0.38071895390625 0.8619934640625001 0.37993464062500004 0.85410130703125 0.37441176484375 0.847777778125 0.3736111109375 0.8367320257812499 0.382303921875 0.8367320257812499 0.390196078125 0.8343627453125 0.39254901953125 0.84383986953125 0.39571895390625 0.8643627453124999 0.4004411765625 0.8643627453124999 0.39808823515624997 0.84147058828125 0.40361111093749996 0.8398856210937501 0.4028104578125 0.82883986953125 0.4000326796875 0.80276143828125 0.38424836562500003 0.7861764703125 0.3850326796875 0.77986928125 0.38109477109375 0.77986928125 0.37004901953124997 0.7782843140625 0.358986928125 0.7814542484375 0.34952614375 0.79643790859375 0.34241830078125 0.80906862734375 0.34241830078125 0.8209150328125 0.3479411765625 0.8343300656249999 0.35583333359374997 0.83826797421875 0.35741830078125003 0.8580065359375 0.35704248359375 0.8548856210937499 0.35704248359375 0.860408496875 0.3609803921875 0.86120915
# Warning: Invalid line in label file: ./dataset/labels/train/000000003378_jpg.rf.c19f9280904836d6cad8f8841e2d1393.txt, Line: 49 0.7182031249999999 0.6824375 0.72496875 0.6869375 0.740734375 0.6824375 0.779015625 0.6824375 0.7835156249999999 0.6801875 0.78578125 0.675671875 0.801546875 0.5563125 0.7970312500000001 0.48423437500000005 0.79478125 0.47071874999999996 0.799296875 0.44820312500000004 0.7902812499999999 0.4301875 0.76325 0.42567187500000003 0.7519843749999999 0.4346875 0.749734375 0.450453125 0.738484375 0.47973437499999994 0.73171875 0.5 0.73171875 0.542796875 0.73171875 0.59684375 0.73171875 0.646390625 0.713703125 0.666671875 0.715953125 0.677921875 0.7182031249999999 0.6824375
# Warning: Invalid line in label file: ./dataset/labels/train/000000003862_jpg.rf.68adb2e862c41e366349f6f3d17e0e2f.txt, Line: 28 0.341984375 0.8299218749999999 0.386265625 0.8299218749999999 0.399671875 0.801734375 0.407734375 0.749421875 0.4090625 0.710515625 0.42517187500000003 0.710515625 0.5875 0.6890468750000001 0.6344531250000001 0.734671875 0.6465156249999999 0.729296875 0.677375 0.726609375 0.722984375 0.756125 0.782015625 0.7789375 0.8249531250000001 0.805765625 0.9161718750000001 0.83125 0.9295937500000001 0.8191875 0.9295937500000001 0.796375 0.9067812500000001 0.7869843750000001 0.88396875 0.7789375 0.842390625 0.765515625 0.79409375 0.74271875 0.744125 0.7149062500000001 0.661421875 0.691453125 0.639203125 0.6741718750000001 0.6404375 0.61615625 0.6404375 0.60875 0.6404375 0.597640625 0.63796875 0.56925 0.644140625 0.55690625 0.6700625 0.528515625 0.6737656249999999 0.49146875 0.6355000000000001 0.46678125000000004 0.6206875000000001 0.45196875 0.60709375 0.43962500000000004 0.57253125 0.40629687499999995 0.55278125 0.4050625 0.521921875 0.403828125 0.45403125 0.4050625 0.43428125 0.4050625 0.39978125000000003 0.4305 0.3984375 0.44659375 0.389046875 0.45465625000000004 0.367578125 0.48014062500000004 0.370265625 0.48550000000000004 0.3635625 0.500265625 0.371609375 0.5270937499999999 0.3635625 0.539171875 0.34478125 0.560625 0.331359375 0.572703125 0.3179375 0.588796875 0.31928125 0.608921875 0.352828125 0.60221875 0.3581875 0.614296875 0.355515625 0.63978125 0.35148437499999996 0.709546875 0.35148437499999996 0.743078125 0.331359375 0.79540625 0.325890625 0.7936875 0.325890625 0.8299218749999999 0.341984375 0.8299218749999999
# Warning: Invalid line in label file: ./dataset/labels/train/000000000996_jpg.rf.948d5879e50e29db84a608b24d1ba8e9.txt, Line: 34 0.397453125 0.80753125 0.38090625 0.9088593749999999 0.3705625 0.9336718749999999 0.40365624999999994 0.9316093750000001 0.40571875 0.8571562500000001 0.409859375 0.788921875 0.424328125 0.704140625 0.42846875000000006 0.642109375 0.445015625 0.6524375 0.457421875 0.6751875 0.46362500000000006 0.75584375 0.469828125 0.795125 0.473953125 0.8840468749999999 0.44914062499999996 0.92540625 0.482234375 0.9316093750000001 0.4925625 0.921265625 0.48429687499999996 0.8282187499999999 0.4925625 0.7434375 0.49050000000000005 0.66278125 0.49670312499999997 0.66071875 0.531859375 0.693796875 0.5566718749999999 0.75790625 0.567015625 0.8695625 0.540125 0.910921875 0.571140625 0.913 0.579421875 0.8881718749999999 0.583546875 0.83234375 0.57734375 0.7868593749999999 0.558734375 0.6813906249999999 0.569078125 0.666921875 0.602171875 0.72275 0.6166406249999999 0.7703125 0.6331875 0.799265625 0.6517968749999999 0.87990625 0.64971875 0.9088593749999999 0.67040625 0.90265625 0.668328125 0.8675 0.639390625 0.778578125 0.618703125 0.695875 0.6104375 0.627625 0.5959531250000001 0.596609375 0.5744374999999999 0.539328125 0.50478125 0.48989062499999997 0.45982812500000003 0.42021875 0.39690625 0.32584375 0.360953125 0.206734375 0.35196875 0.182015625 0.39242187500000003 0.12584375 0.358703125 0.139328125 0.336234375 0.098875 0.325 0.103375 0.340734375 0.11909375 0.325 0.12359374999999999 0.316015625 0.105625 0.309265625 0.132578125 0.2710625 0.11909375 0.286796875 0.1550625 0.307015625 0.159546875 0.309265625 0.18426562500000002 0.3205 0.2045 0.358703125 0.334828125 0.38342187499999997 0.46067187499999995 0.39690625 0.501125 0.3766875 0.557296875 0.372640625 0.559390625 0.37884375000000003 0.61109375 0.395375 0.691734375 0.39125 0.762046875 0.397453125 0.80753125
# Warning: Invalid line in label file: ./dataset/labels/train/000000001790_jpg.rf.0efcae09659157f3e0c5ed85936c38e1.txt, Line: 71 0.42604687500000005 0.482234375 0.429 0.4833125 0.437875 0.48815625 0.477125 0.488953125 0.47443749999999996 0.48410937499999995 0.466640625 0.48410937499999995 0.45776562500000006 0.48384375 0.45562500000000006 0.476859375 0.451046875 0.475515625 0.43089062499999997 0.47578125 0.42578125 0.473625 0.41609375000000004 0.47228125 0.401578125 0.47228125 0.40265625 0.48492187500000006 0.41314062500000004 0.485453125 0.42604687500000005 0.482234375
# Warning: Invalid line in label file: ./dataset/labels/train/000000001424_jpg.rf.0ee19759b4c1f2c760d7d62ee6362e70.txt, Line: 22 0.23542187499999997 0.547078125 0.255609375 0.552125 0.26568749999999997 0.56221875 0.26568749999999997 0.585765625 0.2841875 0.622765625 0.299328125 0.647984375 0.306046875 0.639578125 0.26568749999999997 0.48990625000000004 0.26232812499999997 0.48990625000000004 0.21356250000000002 0.49831250000000005 0.21525 0.5016875 0.21525 0.54371875 0.23542187499999997 0.547078125
# Warning: Invalid line in label file: ./dataset/labels/train/000000001912_jpg.rf.68e9df689e3dbdf9e49bd8240356b612.txt, Line: 10 0.383609375 0.708890625 0.383140625 0.71075 0.38546874999999997 0.715875 0.397109375 0.7182031249999999 0.40131249999999996 0.723328125 0.412015625 0.7326406249999999 0.416671875 0.731703125 0.42459375 0.73915625 0.42737499999999995 0.7517343750000001 0.42925 0.766625 0.43296875 0.766625 0.43296875 0.7615000000000001 0.430640625 0.737296875 0.4325 0.731703125 0.436234375 0.731703125 0.439484375 0.74009375 0.44275000000000003 0.742875 0.45345312499999996 0.7438125 0.45531249999999995 0.751265625 0.46090625 0.7535937500000001 0.46323437500000003 0.746140625 0.458578125 0.7363593749999999 0.44507812500000005 0.7363593749999999 0.44460937500000003 0.731234375 0.45531249999999995 0.72890625 0.466484375 0.7219218749999999 0.47487500000000005 0.7075 0.476265625 0.695390625 0.476265625 0.680484375 0.48465625 0.6818906250000001 0.47859375000000004 0.672578125 0.47440625000000003 0.66465625 0.466953125 0.653484375 0.45671875 0.65021875 0.45065625000000004 0.6544218749999999 0.444140625 0.659078125 0.4418125 0.6744375 0.434359375 0.675828125 0.42878125 0.67815625 0.397578125 0.699578125 0.390125 0.6958593750000001 0.38221875 0.69771875 0.38268749999999996 0.6981875 0.379421875 0.703296875 0.383609375 0.708890625
# Warning: Invalid line in label file: ./dataset/labels/train/000000003192_jpg.rf.68f2a65598679eebafdd88e9e2f3deb6.txt, Line: 26 0.10389062499999999 0.3403125 0.131515625 0.314734375 0.058875 0.127484375 0 0.126453125 0.0005468749999999999 0.20421874999999998 0.0036249999999999998 0.36690625 0.013843749999999998 0.364859375 0.047609374999999995 0.3628125 0.052734375 0.36384375 0.072171875 0.356671875 0.10389062499999999 0.3403125
# Warning: Invalid line in label file: ./dataset/labels/train/000000005215_jpg.rf.68d90d7c6b8b4a65d6f12c1d833ac64d.txt, Line: 49 0.50928125 0.645625 0.525921875 0.627328125 0.53590625 0.6006875 0.54090625 0.5723906249999999 0.525921875 0.56240625 0.512609375 0.5524218750000001 0.49096875000000006 0.5524218750000001 0.479328125 0.5723906249999999 0.46934375 0.570734375 0.454359375 0.534125 0.44604687500000006 0.49251562499999996 0.422734375 0.47253125 0.40609375 0.45423437499999997 0.35950000000000004 0.435921875 0.31621875 0.43093750000000003 0.18640625 0.440921875 0.138140625 0.43093750000000003 0.13646875 0.404296875 0.13314062499999998 0.366015625 0.124828125 0.34771874999999997 0.11151562500000001 0.31442187499999996 0.09153125 0.301109375 0.061578125 0.30278125 0.044937500000000005 0.33273437499999997 0.03828125 0.33773437500000003 0.03328125 0.35603125 0.034953125 0.376 0.03328125 0.415953125 0.021640625 0.46920312500000005 0.01165625 0.5773906249999999 0.0399375 0.610671875 0.13314062499999998 0.698890625 0.048265625 0.788765625 0.0016718750000000002 0.848671875 0.003328125 0.8686406249999999 0.066578125 0.860328125 0.22135937499999997 0.8619843749999999 0.39778125000000003 0.860328125 0.5741875000000001 0.860328125 0.577515625 0.8386875 0.54090625 0.7421562500000001 0.50928125 0.645625
# Warning: Invalid line in label file: ./dataset/labels/train/000000005482_jpg.rf.3bcbccd1734d4e1214456fbaae93b95d.txt, Line: 0 0.671890625 0.690390625 0.693890625 0.719171875 0.7243593749999999 0.712390625 0.731125 0.697171875 0.7294375 0.68025 0.702359375 0.6582343749999999 0.792046875 0.67009375 0.812359375 0.687015625 0.8580625 0.71746875 0.8648281250000001 0.742859375 0.8800625 0.7462500000000001 0.8766718750000001 0.71578125 0.930828125 0.719171875 0.9392968749999999 0.67346875 0.907140625 0.62946875 0.88175 0.610859375 0.7954375 0.58378125 0.810671875 0.5803906249999999 0.76496875 0.5719218749999999 0.749734375 0.5719218749999999 0.72096875 0.49068750000000005 0.704046875 0.494078125 0.715890625 0.570234375 0.717578125 0.582078125 0.6905 0.593921875 0.727734375 0.6345468750000001 0.47387499999999994 0.617625 0.467109375 0.6193125 0.67528125 0.6480937499999999 0.6888124999999999 0.665015625 0.67696875 0.67178125 0.671890625 0.690390625
# Warning: Invalid line in label file: ./dataset/labels/train/000000001144_jpg.rf.c1d97adaca756dea43c1c36953904a8a.txt, Line: 54 0.208953125 0.722 0.224453125 0.7164531249999999 0.242171875 0.72309375 0.29862500000000003 0.7363906250000001 0.341796875 0.75409375 0.39603125 0.749671875 0.404890625 0.734171875 0.459140625 0.7131406250000001 0.48903125000000003 0.682140625 0.493453125 0.643390625 0.5023125 0.629 0.4868125 0.598015625 0.428140625 0.563703125 0.3949375 0.5548437500000001 0.341796875 0.548203125 0.290875 0.5548437500000001 0.24548437500000003 0.57365625 0.216703125 0.5946875 0.192359375 0.619046875 0.1835 0.6367499999999999 0.18903125 0.643390625 0.16578125 0.65446875 0.17021875 0.661109375 0.17575000000000002 0.672171875 0.1835 0.679921875 0.18903125 0.697640625 0.18682812499999998 0.708703125 0.208953125 0.722
# Warning: Invalid line in label file: ./dataset/labels/train/000000004741_jpg.rf.ef275f652b57e299236e9d51c60beaec.txt, Line: 37 0.725703125 0.7057187500000001 0.71921875 0.690609375 0.6932968749999999 0.6862812500000001 0.671703125 0.6862812500000001 0.665234375 0.690609375 0.617703125 0.697078125 0.589640625 0.7251562500000001 0.572359375 0.7575624999999999 0.5464375 0.7942812499999999 0.537796875 0.805078125 0.518359375 0.75540625 0.537796875 0.712203125 0.542109375 0.694921875 0.537796875 0.684125 0.518359375 0.6862812500000001 0.49243750000000003 0.7057187500000001 0.47300000000000003 0.74028125 0.47300000000000003 0.746765625 0.462203125 0.770515625 0.460046875 0.789953125 0.460046875 0.8137187499999999 0.45571875000000006 0.843953125 0.44925 0.8741875 0.444921875 0.8914687499999999 0.444921875 0.9130625 0.47515625000000006 0.9065937500000001 0.47515625000000006 0.8914687499999999 0.47515625000000006 0.87634375 0.498921875 0.83315625 0.5248437499999999 0.802921875 0.535640625 0.805078125 0.535640625 0.8158749999999999 0.52915625 0.83746875 0.518359375 0.9065937500000001 0.5248437499999999 0.917390625 0.5313125000000001 0.9281874999999999 0.54859375 0.934671875 0.54859375 0.9303437499999999 0.54859375 0.9238593749999999 0.5464375 0.9022656250000001 0.5464375 0.8893125 0.539953125 0.8741875 0.542109375 0.8525937499999999 0.54859375 0.8310000000000001 0.5637187499999999 0.8266718750000001 0.581 0.83315625 0.581 0.8461093749999999 0.581 0.8633906250000001 0.581 0.8698750000000001 0.5701875000000001 0.8893125 0.559390625 0.9238593749999999 0.574515625 0.9454687500000001 0.5853125 0.9519375 0.593953125 0.9454687500000001 0.593953125 0.9389843750000001 0.593953125 0.934671875 0.593953125 0.9238593749999999 0.5961093749999999 0.8914687499999999 0.5961093749999999 0.8461093749999999 0.6155468749999999 0.8353125 0.632828125 0.8245156250000001 0.64578125 0.8310000000000001 0.647953125 0.8633906250000001 0.647953125 0.8849843749999999 0.6565937500000001 0.9130625 0.6565937500000001 0.917390625 0.66090625 0.9281874999999999 0.671703125 0.9519375 0.6825 0.96490625 0.688984375 0.96490625 0.69978125 0.96490625 0.704109375 0.96490625 0.701609375 0.9406874999999999 0.699921875 0.93228125 0.68140625 0.9137656249999999 0.676359375 0.898625 0.674671875 0.88684375 0.669625 0.868328125 0.669625 0.8515 0.669625 0.83971875 0.664578125 0.8296250000000001 0.6662656250000001 0.81953125 0.673 0.801015625 0.676359375 0.785875 0.68309375 0.7791406249999999 0.689828125 0.792609375 0.699921875 0.8043906249999999 0.7032812500000001 0.811109375 0.711703125 0.81784375 0.7184375000000001 0.81953125 0.723484375 0.81953125 0.7343437500000001 0.7381249999999999 0.723546875 0.712203125 0.725703125 0.7057187500000001
# Warning: Invalid line in label file: ./dataset/labels/train/000000002614_jpg.rf.3bd36d56d520662d8550ef343aeec307.txt, Line: 49 0.3563125 0.488671875 0.35357812499999997 0.511421875 0.345390625 0.532359375 0.34721875 0.54146875 0.35176562499999997 0.575140625 0.34265625 0.59425 0.35085937500000003 0.595171875 0.359046875 0.573328125 0.3645 0.604265625 0.360859375 0.6115468749999999 0.337203125 0.6770937499999999 0.34084375 0.6798124999999999 0.35085937500000003 0.681640625 0.36178125 0.67890625 0.359046875 0.673453125 0.36178125 0.65615625 0.37725 0.62703125 0.381796875 0.624296875 0.39454687499999996 0.596078125 0.40182812500000004 0.595171875 0.441875 0.617015625 0.451890625 0.648875 0.45734375 0.6543281249999999 0.4691875 0.6861875000000001 0.477375 0.688015625 0.5074062500000001 0.683453125 0.511046875 0.676171875 0.501046875 0.675265625 0.48101562500000006 0.667984375 0.4564375 0.59971875 0.44278125 0.57878125 0.44096875 0.567859375 0.44370312500000003 0.567859375 0.44642187499999997 0.574234375 0.450984375 0.574234375 0.453703125 0.5669531250000001 0.45006250000000003 0.5569375 0.43459375 0.542375 0.42184375 0.506875 0.425484375 0.475015625 0.42731250000000004 0.46135937499999996 0.419125 0.454078125 0.419125 0.448625 0.41820312499999995 0.43678125 0.417296875 0.43042187500000006 0.42093749999999996 0.431328125 0.42640625 0.4295 0.41820312499999995 0.42221875000000003 0.40728125000000004 0.411296875 0.386359375 0.411296875 0.37907812500000004 0.432234375 0.387265625 0.45317187499999995 0.3854375 0.451359375 0.37634375000000003 0.45864062499999997 0.3563125 0.488671875
# Warning: Invalid line in label file: ./dataset/labels/train/000000001622_jpg.rf.c22463ecbaf9a4d024a49201c0936a50.txt, Line: 28 0.2560675 0.50448 0.24596749999999998 0.51458 0.24596749999999998 0.5287200000000001 0.2500075 0.5368 0.2702275 0.55094 0.30860750000000003 0.557 0.33890750000000003 0.56508 0.3591075 0.57114 0.3873875 0.57114 0.3853675 0.5489200000000001 0.3853675 0.52266 0.3833475 0.49640000000000006 0.4015275 0.50246 0.4197075 0.5065000000000001 0.4318275 0.53276 0.4338475 0.55094 0.4419275 0.5873 0.4479875 0.61558 0.4540475 0.63176 0.4702275 0.63984 0.47224750000000004 0.66004 0.49244750000000004 0.6863 0.5166875 0.7065 0.5328475 0.7065 0.5591075 0.7024600000000001 0.5752675 0.68832 0.5712275 0.6681199999999999 0.5570875 0.6458999999999999 0.5368875 0.61154 0.5348675 0.5792200000000001 0.5166875 0.5388200000000001 0.5308275 0.53074 0.5550675 0.5267000000000001 0.5873875 0.52064 0.6035475 0.52266 0.6116275 0.5287200000000001 0.6277874999999999 0.54286 0.6378874999999999 0.5671 0.6560675 0.5772 0.6722475 0.59134 0.6843675 0.59336 0.6985075000000001 0.59336 0.7166875 0.59134 0.7288075 0.57114 0.7227475 0.557 0.6742675 0.5267000000000001 0.6702275 0.50044 0.6762875 0.44792 0.6944675 0.42973999999999996 0.6944675 0.40144 0.7187075 0.40144 0.7490075 0.38932 0.7692075 0.31054 0.7671875 0.2661 0.7510275 0.20952 0.7510275 0.18326 0.7490075 0.16508 0.7389075 0.14084000000000002 0.7166875 0.12265999999999999 0.6783075000000001 0.09034 0.6520275 0.0762 0.6176875 0.08024 0.5873875 0.06812 0.5752675 0.09236 0.5449675 0.10246 0.5025475 0.13074 0.4985075 0.14892 0.4742675 0.1772 0.4580875 0.20346000000000003 0.4702275 0.21558000000000002 0.4540475 0.23984 0.44596749999999996 0.25802 0.4075875 0.26206 0.3712275 0.2762 0.3530475 0.29438 0.3005275 0.34084 0.28234750000000003 0.36507999999999996 0.26212749999999996 0.39740000000000003 0.25808749999999997 0.42164 0.2641475 0.49034000000000005 0.2560675 0.50448
# ...
# Warning: Invalid line in label file: ./dataset/labels/train/000000000839_jpg.rf.0c470f50bd85093b9551d58d49d10434.txt, Line: 49 0.5788593750000001 0.47821875 0.590921875 0.468171875 0.6311093750000001 0.42195312500000004 0.65725 0.38978125 0.675328125 0.3696875 0.7075 0.38778125 0.731609375 0.40989062499999995 0.749703125 0.429984375 0.75371875 0.44204687500000006 0.7718125 0.458125 0.719546875 0.506359375 0.729609375 0.524453125 0.719546875 0.52846875 0.675328125 0.58475 0.675328125 0.610875 0.7476875 0.795796875 0.711515625 0.811875 0.733625 0.8239375000000001 0.7718125 0.8199062500000001 0.818046875 0.79178125 0.8039687499999999 0.761625 0.75371875 0.65309375 0.725578125 0.610875 0.81603125 0.5345 0.8321093749999999 0.53853125 0.850203125 0.5224375 0.836125 0.52646875 0.8863749999999999 0.500328125 0.90446875 0.45610937500000004 0.9145156249999999 0.448078125 0.9245625000000001 0.44204687500000006 0.91853125 0.403859375 0.920546875 0.377734375 0.932609375 0.335515625 0.91653125 0.291296875 0.8682812500000001 0.231 0.8723124999999999 0.229 0.8863749999999999 0.200859375 0.87834375 0.17271875 0.836125 0.158640625 0.8099999999999999 0.170703125 0.79190625 0.194828125 0.7959375 0.21090625 0.785875 0.2189375 0.781859375 0.229 0.7979375 0.23703124999999997 0.7959375 0.24909374999999997 0.7095 0.200859375 0.667296875 0.168703125 0.6451875 0.176734375 0.661265625 0.182765625 0.65925 0.188796875 0.661265625 0.19684375 0.6713125 0.204875 0.681359375 0.22296875 0.6954374999999999 0.22296875 0.717546875 0.23703124999999997 0.7979375 0.291296875 0.807984375 0.34959375000000004 0.7577499999999999 0.3315 0.66328125 0.2933125 0.63915625 0.301359375 0.5708125 0.434 0.546703125 0.41792187500000005 0.5386562500000001 0.43200000000000005 0.480375 0.39782812500000003 0.47434374999999995 0.411890625 0.5487031250000001 0.5144062500000001 0.5688125 0.506359375 0.57684375 0.49431250000000004 0.5788593750000001 0.47821875
# Warning: Invalid line in label file: ./dataset/labels/train/000000000723_jpg.rf.9200f27d68dfe916798dcb0aaaded93e.txt, Line: 22 0.639390625 0.6874687500000001 0.639390625 0.712328125 0.6418437499999999 0.711921875 0.6418437499999999 0.68909375 0.660171875 0.690734375 0.660984375 0.70784375 0.66425 0.7082499999999999 0.66465625 0.6980625 0.6650625 0.68828125 0.657328125 0.682984375 0.6524375 0.673203125 0.656109375 0.658953125 0.651625 0.648765625 0.636546875 0.593765625 0.62390625 0.58928125 0.61290625 0.5929375 0.6133124999999999 0.603125 0.617796875 0.619828125 0.639390625 0.6874687500000001
# Warning: Invalid line in label file: ./dataset/labels/train/000000000722_jpg.rf.ec400c3571c1cbb1b1794af001d806a5.txt, Line: 18 0.39842187500000004 0.568734375 0.39842187500000004 0.571171875 0.3975 0.57178125 0.396890625 0.5730000000000001 0.395984375 0.576359375 0.39871875 0.582140625 0.40298437500000006 0.585796875 0.406640625 0.5855 0.411828125 0.587328125 0.419140625 0.58671875 0.42340625000000004 0.586109375 0.42553124999999997 0.588546875 0.434375 0.5882343750000001 0.43771875 0.5882343750000001 0.438640625 0.589765625 0.44107812500000004 0.590375 0.44290624999999995 0.5928125 0.44381250000000005 0.59403125 0.447484375 0.594328125 0.44778124999999996 0.597078125 0.45175 0.597375 0.45265625 0.599515625 0.45692187500000003 0.597984375 0.45906250000000004 0.5949375 0.4615 0.59128125 0.471859375 0.591890625 0.47307812499999996 0.5900624999999999 0.5215156249999999 0.5900624999999999 0.5224375 0.59525 0.5291406249999999 0.594640625 0.536453125 0.59890625 0.54040625 0.5992031250000001 0.545890625 0.59859375 0.5489375 0.5998125 0.5599062499999999 0.599515625 0.563265625 0.594640625 0.5650937500000001 0.589453125 0.566609375 0.588546875 0.56721875 0.588546875 0.570875 0.588546875 0.573015625 0.586109375 0.57515625 0.582140625 0.574234375 0.5800156249999999 0.574546875 0.577265625 0.57240625 0.575140625 0.5721093749999999 0.57178125 0.5715 0.567828125 0.569046875 0.567515625 0.5599062499999999 0.56203125 0.549546875 0.5602031249999999 0.543765625 0.559296875 0.536140625 0.5559375 0.530359375 0.554421875 0.5126875 0.539484375 0.505671875 0.5376562500000001 0.490140625 0.5352187500000001 0.44046874999999996 0.5346093749999999 0.43559374999999995 0.534921875 0.42614062500000005 0.533703125 0.41426562499999997 0.533390625 0.41334375 0.534 0.41029687499999995 0.53796875 0.40878125 0.54375 0.408171875 0.545890625 0.40725 0.546796875 0.40725 0.548328125 0.404515625 0.5489375 0.40207812499999995 0.550453125 0.400859375 0.553203125 0.39871875 0.55959375 0.39871875 0.5583750000000001 0.398109375 0.5623437499999999 0.39842187500000004 0.568734375
# Warning: Invalid line in label file: ./dataset/labels/train/000000000395_jpg.rf.662d1159a86b0dcd834bcd6483c02368.txt, Line: 21 0.462265625 0.515203125 0.485921875 0.53478125 0.485921875 0.5241875 0.48346875 0.50215625 0.46796875 0.49889062500000003 0.46470312500000005 0.50296875 0.454921875 0.5095 0.462265625 0.515203125
# Warning: Invalid line in label file: ./dataset/labels/train/000000002154_jpg.rf.39234664e29c23308ac3dc2d02c62d81.txt, Line: 18 1 0.31790625 0.9913437500000001 0.309484375 0.909546875 0.274609375 0.887890625 0.25896875 0.8542031250000001 0.242125 0.834953125 0.24693749999999998 0.8041982421875 0.24641015624999998 0.804875 0.238515625 0.778421875 0.23731249999999998 0.7767675781250001 0.3266337890625 0.72217578125 0.33956640625 0.7266874999999999 0.242125 0.715859375 0.23731249999999998 0.642484375 0.242125 0.620828125 0.27821875 0.619625 0.305875 0.61240625 0.316703125 0.60759375 0.331140625 0.6112031250000001 0.35159375000000004 0.62684375 0.357609375 0.6557031249999999 0.363625 0.674953125 0.38287499999999997 0.70021875 0.381671875 0.7030260421875 0.3784635421875 0.710565625 0.378784375 0.7118489578125 0.3752552078125 0.718746875 0.377340625 0.7206718750000001 0.372046875 0.7269281249999999 0.375896875 0.776015625 0.367234375 0.7766171875000001 0.33475390625 0.79675390625 0.33325 0.794046875 0.364828125 0.83375 0.369640625 0.934796875 0.372046875 0.9540468750000001 0.39009375 0.9769062500000001 0.3876875 0.994953125 0.37324999999999997 1 0.338359375 1 0.31790625
# Warning: Invalid line in label file: ./dataset/labels/train/000000000757_jpg.rf.0c4c0248799a5ade7615e690e46f6352.txt, Line: 30 0.265375 0.29693749999999997 0.24889062499999998 0.332921875 0.22939062500000001 0.400390625 0.23689062500000002 0.437875 0.25787499999999997 0.481359375 0.244390625 0.493359375 0.166421875 0.5803125 0.160421875 0.5938125000000001 0.172421875 0.601296875 0.233890625 0.530828125 0.256375 0.532328125 0.233890625 0.547328125 0.253375 0.554828125 0.275875 0.545828125 0.316359375 0.560828125 0.370328125 0.5653125 0.38082812499999996 0.5908125 0.4018125 0.5923125 0.4168125 0.608796875 0.446796875 0.6702656250000001 0.442296875 0.70475 0.41531250000000003 0.7692187500000001 0.3973125 0.827703125 0.45578124999999997 0.83359375 0.47678125 0.79471875 0.51725 0.745234375 0.515765625 0.78271875 0.512765625 0.829203125 0.578734375 0.8321875000000001 0.583234375 0.763234375 0.60271875 0.680765625 0.617703125 0.676265625 0.6671875 0.695765625 0.710671875 0.692765625 0.710671875 0.70175 0.74065625 0.72875 0.74665625 0.748234375 0.74515625 0.7812187500000001 0.74065625 0.8321875000000001 0.803625 0.827703125 0.8006249999999999 0.8097031250000001 0.802125 0.757234375 0.811125 0.733234375 0.820109375 0.692765625 0.842609375 0.72425 0.8515937499999999 0.77071875 0.8501093750000001 0.79171875 0.839609375 0.812703125 0.844109375 0.829203125 0.9055781250000001 0.83359375 0.9040781250000001 0.78721875 0.9055781250000001 0.77971875 0.907078125 0.7032499999999999 0.914578125 0.64328125 0.9190625000000001 0.51734375 0.8965781249999999 0.45887500000000003 0.8515937499999999 0.400390625 0.8171250000000001 0.361421875 0.811125 0.355421875 0.73915625 0.343421875 0.697171875 0.359921875 0.6581875 0.37790625 0.61621875 0.37640625 0.5847187500000001 0.37490625 0.566734375 0.37190625 0.557734375 0.36890625 0.53225 0.37040625 0.506765625 0.37790625 0.488765625 0.37790625 0.427296875 0.37640625 0.4108125 0.37640625 0.4033125 0.37640625 0.3868125 0.36740625 0.377828125 0.36890625 0.373328125 0.37490625 0.362828125 0.38240625 0.33134375 0.39140625 0.295359375 0.412390625 0.275875 0.404890625 0.281875 0.37190625 0.29685937500000004 0.332921875 0.304359375 0.292453125 0.308859375 0.275953125 0.305859375 0.25796874999999997 0.289359375 0.227984375 0.274375 0.202484375 0.254875 0.195 0.223390625 0.200984375 0.223390625 0.214484375 0.232390625 0.217484375 0.239890625 0.227984375 0.253375 0.22498437500000001 0.256375 0.23246875 0.269875 0.272953125 0.265375 0.29693749999999997
# Warning: Invalid line in label file: ./dataset/labels/train/000000000781_jpg.rf.ecb32a0a9b42cb322753092f8e35ae84.txt, Line: 49 0.4120588234375 0.90830065390625 0.402434640625 0.9079738562499999 0.40509803906249997 0.89668300625 0.40475490234375 0.889395425 0.4113888890625 0.885408496875 0.41669934609375003 0.8771078429687501 0.41901960781250003 0.874460784375 0.413382353125 0.87214052265625 0.40939542500000003 0.8767810460937501 0.40475490234375 0.8814215687500001 0.39779411796874997 0.8804248367187499 0.39348039218749997 0.8797712421874999 0.3984477125 0.8754575164062499 0.39944444453125 0.86782679765625 0.39879085000000003 0.8621895421874999 0.38517973828124996 0.85986928125 0.3832026140625 0.8665032679687499 0.38452614375 0.87181372578125 0.38552287578125 0.8757843140625001 0.37789215703125 0.8800980390625 0.3752287578125 0.88673202578125 0.3792156859375 0.8986764703125001 0.38220588203125 0.90995098046875 0.3832026140625 0.9162581703124999 0.38849673203125 0.9242156859374999 0.39547385625000003 0.92986928125 0.39879085000000003 0.9308496734375 0.41305555546874995 0.9242156859374999 0.42101307187500003 0.9235620914062499 0.43129085 0.9295261437500001 0.43859477109375 0.9208986929687499 0.43859477109375 0.91593137265625 0.43495098046875 0.9146078429687501 0.43096405234375 0.9179248367187499 0.4223366015625 0.9122875820312499 0.4120588234375 0.90830065390625
# Warning: Invalid line in label file: ./dataset/labels/train/000000002621_jpg.rf.ecfdcd15f1ee60b16b448331a0e563d5.txt, Line: 72 0.8191 0.49074 0.87134 0.48904 0.87808 0.47220000000000006 0.88314 0.39634 0.8730399999999999 0.30701999999999996 0.8730399999999999 0.29860000000000003 0.81236 0.29860000000000003 0.76348 0.29860000000000003 0.75338 0.30870000000000003 0.7651600000000001 0.46040000000000003 0.75842 0.4486 0.7736 0.49074 0.8191 0.49074
# Warning: Invalid line in label file: ./dataset/labels/train/000000004688_jpg.rf.0cc48c60714388d0abad8fc597e731f4.txt, Line: 40 0.15671875 0.232921875 0.1548125 0.256984375 0.1511875 0.259078125 0.116046875 0.261296875 0.07978125 0.266046875 0.035140624999999995 0.27475 0.046125 0.2940625 0.047 0.3143125 0.05525 0.317234375 0.067125 0.326359375 0.072109375 0.3421875 0.097921875 0.351140625 0.10885937500000001 0.364859375 0.120046875 0.374328125 0.11470312499999999 0.3765625 0.10390625 0.378609375 0.104640625 0.381484375 0.10059375 0.38309375 0.08925 0.38464062499999996 0.084375 0.389546875 0.08887500000000001 0.39340625 0.07943750000000001 0.39559375 0.07165625 0.40279687500000005 0.074484375 0.404734375 0.05709375 0.418375 0.040390625 0.42718749999999994 0.043265625 0.43060937499999996 0.032046875 0.430921875 0.02446875 0.436453125 0.0311875 0.439296875 0.025828125 0.442453125 0.018078125 0.44192187499999996 0.0111875 0.448125 0.01578125 0.45296875 0 0.45785937499999996 0.00045312499999999997 0.47640625 0.022609375 0.46440625 0.0859375 0.423328125 0.13225 0.38601562500000003 0.1449375 0.383078125 0.170296875 0.370953125 0.18462499999999998 0.375375 0.181875 0.363796875 0.15375 0.36765625 0.178046875 0.325234375 0.20832812500000003 0.32795312499999996 0.18628125 0.313625 0.2028125 0.3015 0.22951562499999997 0.299796875 0.23093750000000002 0.292671875 0.21042187499999998 0.29095312500000003 0.23203125 0.28495312500000003 0.23203125 0.27834375 0.164578125 0.268984375 0.1613125 0.2620625 0.15814062499999998 0.24321874999999998 0.15671875 0.232921875
# Warning: Invalid line in label file: ./dataset/labels/train/000000004173_jpg.rf.0cca545bb264648ff23aa008562744b7.txt, Line: 65 0.46867187499999996 0.58446875 0.48807812500000003 0.5814843749999999 0.46420312499999994 0.557609375 0.46420312499999994 0.54865625 0.46568750000000003 0.5411875 0.44628125 0.533734375 0.42985937500000004 0.5277499999999999 0.42985937500000004 0.52925 0.42090625 0.544171875 0.39553125 0.5426875 0.407484375 0.5397031250000001 0.41345312500000003 0.52925 0.42985937500000004 0.5038750000000001 0.41792187500000005 0.49640625 0.41345312500000003 0.49939062500000003 0.41046875 0.51134375 0.407484375 0.514328125 0.39851562500000004 0.5232812499999999 0.39553125 0.5158125 0.39851562500000004 0.5083593750000001 0.40598437499999995 0.494921875 0.40896875 0.48446875 0.34628125 0.453125 0.349265625 0.47103124999999996 0.35821875 0.5038750000000001 0.3895625 0.54715625 0.39254687499999996 0.544171875 0.41792187500000005 0.556109375 0.46867187499999996 0.58446875
# Warning: Invalid line in label file: ./dataset/labels/train/000000002270_jpg.rf.66ee19da24a1d3d9853e13350abf228d.txt, Line: 51 0.18367187499999998 0.8086718749999999 0.17346875 0.788265625 0.171765625 0.767859375 0.19046875000000002 0.74915625 0.192171875 0.715140625 0.178578125 0.699828125 0.1530625 0.687921875 0.15815625 0.659015625 0.139453125 0.6403125000000001 0.12415625 0.6624218749999999 0.0884375 0.635203125 0.057828124999999994 0.6335 0.057828124999999994 0.672625 0.0408125 0.6743125 0.030609375 0.66071875 0.013609375000000002 0.647109375 0 0.65390625 0.0034062500000000004 0.708328125 0 0.7695624999999999 0.0034062500000000004 0.767859375 0.0034062500000000004 0.81546875 0.013609375000000002 0.83928125 0.02890625 0.8511875 0.04421875 0.868765625 0.056125 0.8744375 0.09523437500000001 0.867625 0.11734375 0.869328125 0.13604687499999998 0.87103125 0.15815625 0.867625 0.1530625 0.85403125 0.1530625 0.852890625 0.14965625 0.8664999999999999 0.146265625 0.856296875 0.15815625 0.82228125 0.18367187499999998 0.8086718749999999
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 38
#      36 input_size = 640
#      37 # Ensure that 'filenames' is being correctly assigned within your Mydataset class
# ---> 38 train_data = NewDataset(input_size=input_size, params=params_dict, augment=False, filenames=imagenames)
#      39 # Assuming 'filenames' is an attribute of Mydataset, make sure it's initialized
#      40
#      41 # Print the value of train_data.filenames to check if it's empty  -- Changed from train_datas to train_data
#      42 print(f"train_data.filenames: {train_data.filenames}")
#
# File ~/Documents/yolov8_detection/utils/newDataset.py:52, in NewDataset.__init__(self, input_size, params, augment, filenames)
#      49     self.label_files.append(label_path)  # Add the label file path to the list
#      50 ###########################################################################################################################################
#      51 # Read labels
# ---> 52 labels = self.load_label(self.newfilenames)
#      53 self.labels = list(labels.values())
#      54 self.filenames = list(labels.keys())  # update
#
# File ~/Documents/yolov8_detection/utils/newDataset.py:303, in NewDataset.load_label(filenames)
#     301 with open(b.join(filename.rsplit(a, 1)).rsplit('.', 1)[0] + '.txt') as f:
#     302     label = [x.split() for x in f.read().strip().splitlines() if len(x)]
# --> 303     label = numpy.array(label, dtype=numpy.float32)
#     304 nl = len(label)
#     305 if nl:
#
# NameError: name 'numpy' is not defined

# %%
import yaml
from utils.dataset import *
from torch.utils import data

# get all file names
data_dir= 'coco'
filenames_train = []
with open(f'{data_dir}/train2017.txt') as reader:
    for filename in reader.readlines():
        filename = os.path.basename(filename.rstrip())
        filenames_train.append(f'{data_dir}/images/train2017/' + filename)

# input_size for the model
input_size=640

# get params from yaml file
with open('utils/args.yaml', errors='ignore') as f:
        params = yaml.safe_load(f)

train_data=Dataset(filenames_train,input_size,params,augment=True)
train_loader = data.DataLoader(train_data, batch_size=64, num_workers=0, pin_memory=True, collate_fn=Dataset.collate_fn)
print(f"Train_loader : {len(train_loader)} batches")
# Out:
# Train_loader : 1849 batches

# %%
batch=next(iter(train_loader))
print("All keys in batch      : ", batch[1].keys())
print(f"Input batch shape      : ", batch[0].shape)
print(f"Classification scores  : {batch[1]['cls'].shape}")
print(f"Box coordinates        : {batch[1]['box'].shape}")
print(f"Index identifier (which score belongs to which image): {batch[1]['idx'].shape}")
# Out:
# [ WARN:0@181.193] global loadsave.cpp:241 findDecoder imread_('coco/images/train2017/000000211830.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 batch=next(iter(train_loader))
#       2 print("All keys in batch      : ", batch[1].keys())
#       3 print(f"Input batch shape      : ", batch[0].shape)
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/yolov8custom/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/yolov8_detection/utils/dataset.py:38, in Dataset.__getitem__(self, index)
#      34 mosaic = self.mosaic and random.random() < params['mosaic']
#      36 if mosaic:
#      37     # Load MOSAIC
# ---> 38     image, label = self.load_mosaic(index, params)
#      39     # MixUp augmentation
#      40     if random.random() < params['mix_up']:
#
# File ~/Documents/yolov8_detection/utils/dataset.py:122, in Dataset.load_mosaic(self, index, params)
#     118 random.shuffle(indices)
#     120 for i, index in enumerate(indices):
#     121     # Load image
# --> 122     image, _ = self.load_image(index)
#     123     shape = image.shape
#     124     if i == 0:  # top left
#
# File ~/Documents/yolov8_detection/utils/dataset.py:100, in Dataset.load_image(self, i)
#      98 def load_image(self, i):
#      99     image = cv2.imread(self.filenames[i])
# --> 100     h, w = image.shape[:2]
#     101     r = self.input_size / max(h, w)
#     102     if r != 1:
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
from utils import util
torch.manual_seed(1337)

# model, loss and optimizer
model=MyYolo(version='n')
print(f"{sum(p.numel() for p in model.parameters())/1e6} million parameters")

criterion=util.ComputeLoss(model, params)
optimizer=torch.optim.AdamW(model.parameters(), lr=0.5)

num_epochs=5

imgs,targets=batch[0],batch[1]
imgs=imgs.float()
model.train()
for epoch in range(num_epochs):
    outputs=model(imgs)
    loss=sum(criterion(outputs,targets)) # cls_loss+box_loss+dfl_loss
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(f"Epoch : {epoch} | loss : {loss.item()}")
# Out:
# 3.1572 million parameters
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch : 0 | loss : 15265294.0
# Epoch : 1 | loss : 2260031.0
# Epoch : 2 | loss : 1407.5379638671875
# Epoch : 3 | loss : 0.0
# Epoch : 4 | loss : 0.0
